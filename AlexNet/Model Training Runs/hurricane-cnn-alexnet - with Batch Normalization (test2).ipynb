# %% [markdown]
# # Imports

# %%
import numpy as np
import glob
from PIL import Image
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from tensorflow.keras import optimizers
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import KFold
import pandas as pd
import seaborn as sn
sn.set(font_scale=1.4) # for label size
import multiprocessing as mp
import csv

# %% [markdown]
# # Load DataSet
#
# 0 means unlikely to have flood damage, 1 means likely to have flood damage
#
# [0,1] --> damage
#
# [1,0] --> no damage

# %% [markdown]
# ## Load Training Set

# %%
images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/train_another/damage/*.jpeg')
dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  dmg_img.append(im_arr)
dmg_img = np.array(dmg_img)

images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/train_another/no_damage/*.jpeg')
no_dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  no_dmg_img.append(im_arr)
no_dmg_img = np.array(no_dmg_img)

X_train = np.concatenate((dmg_img, no_dmg_img))
dmg_img_y = np.array(dmg_img.shape[0] * [[0,1]])
no_dmg_img_y = np.array(no_dmg_img.shape[0] * [[1,0]])
y_train = np.concatenate((dmg_img_y, no_dmg_img_y))

# shuffle arrays so that the array is a mix of damage and no_damage in a random order
shuffler = np.random.permutation(X_train.shape[0])
X_train = X_train[shuffler]
y_train = y_train[shuffler]

# %% [markdown]
# ## Load Validation Set

# %%
images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/validation_another/damage/*.jpeg')
dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  dmg_img.append(im_arr)
dmg_img = np.array(dmg_img)

images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/validation_another/no_damage/*.jpeg')
no_dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  no_dmg_img.append(im_arr)
no_dmg_img = np.array(no_dmg_img)

X_val = np.concatenate((dmg_img, no_dmg_img))
dmg_img_y = np.array(dmg_img.shape[0] * [[0,1]])
no_dmg_img_y = np.array(no_dmg_img.shape[0] * [[1,0]])
y_val = np.concatenate((dmg_img_y, no_dmg_img_y))

# shuffle arrays so that the array is a mix of damage and no_damage in a random order
shuffler = np.random.permutation(X_val.shape[0])
X_val = X_val[shuffler]
y_val = y_val[shuffler]

# %%
# combine training and validation data - for cross-validation
X_all = np.concatenate((X_train, X_val))
y_all = np.concatenate((y_train, y_val))

# %% [markdown]
# ## Load Test Set

# %%
images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/test/damage/*.jpeg')
dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  dmg_img.append(im_arr)
dmg_img = np.array(dmg_img)

images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/test/no_damage/*.jpeg')
no_dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  no_dmg_img.append(im_arr)
no_dmg_img = np.array(no_dmg_img)

X_test = np.concatenate((dmg_img, no_dmg_img))
dmg_img_y = np.array(dmg_img.shape[0] * [[0,1]])
no_dmg_img_y = np.array(no_dmg_img.shape[0] * [[1,0]])
y_test = np.concatenate((dmg_img_y, no_dmg_img_y))

# shuffle arrays so that the array is a mix of damage and no_damage in a random order
shuffler = np.random.permutation(X_val.shape[0])
X_test = X_test[shuffler]
y_test = y_test[shuffler]

# %% [markdown]
# # Pre-Process DataSet

# %%
# pre-process data 
def scale_pixels(train, val, test, X_all):
	# convert from integers to floats and normalize between 0-1
  train_norm = train.astype('float32') / 255.0
  val_norm = val.astype('float32') / 255.0
  test_norm = test.astype('float32') / 255.0
  X_all_norm = X_all.astype('float32') / 255.0
	# return normalized images
  return train_norm, val_norm, test_norm, X_all_norm

X_train, X_val, X_test, X_all = scale_pixels(X_train, X_val, X_test, X_all)

# %% [markdown]
# # Plot Diagnostics

# %%
# plot diagnostic learning curves
def summarize_diagnostics(history):
  # blue = training data; orange = validation data
	# plot validation loss
	plt.subplot(211)
	plt.title('Cross Entropy Loss')
	plt.plot(history.history['loss'], color='blue', label='train')
	plt.plot(history.history['val_loss'], color='orange', label='validation')
	# plot accuracy
	plt.subplot(212)
	plt.title('Classification Accuracy')
	plt.plot(history.history['accuracy'], color='blue', label='train')
	plt.plot(history.history['val_accuracy'], color='orange', label='validation')

# %% [markdown]
# # Create CNN Model

# %%
# define cnn model
def define_model(learning_rate):
  model = keras.Sequential()
  model.add(layers.Conv2D(filters=96, input_shape=(128,128,3), kernel_size=(11,11), strides=(4,4), activation='relu', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)))
  model.add(layers.Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), activation='relu', padding="same"))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)))
  model.add(layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)))
  model.add(layers.Flatten())
  model.add(layers.Dense(4096, activation='relu'))
  model.add(layers.Dropout(0.5))
  model.add(layers.Dense(4096, activation='relu'))
  model.add(layers.Dropout(0.5))
  model.add(layers.Dense(2, activation='softmax'))  # compile model
  opt = optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
  model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
  return model

# %% [markdown]
# ## CNN Model with Weight Regularization

# %%
# define cnn model
def define_model_weight_regularization(learning_rate):
  model = keras.Sequential()
  model.add(layers.Conv2D(filters=96, input_shape=(128,128,3), kernel_size=(11,11), strides=(4,4), activation='relu', kernel_regularizer=regularizers.l2(0.01), padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)))
  model.add(layers.Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), activation='relu', kernel_regularizer=regularizers.l2(0.01), padding="same"))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)))
  model.add(layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', kernel_regularizer=regularizers.l2(0.01), padding="same"))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', kernel_regularizer=regularizers.l2(0.01), padding="same"))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', kernel_regularizer=regularizers.l2(0.01), padding="same"))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)))
  model.add(layers.Flatten())
  model.add(layers.Dense(4096, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.Dropout(0.5))
  model.add(layers.Dense(4096, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.Dropout(0.5))
  model.add(layers.Dense(2, activation='softmax'))  # compile model
  opt = optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
  model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
  return model

# %% [markdown]
# # Train Data
# Hyperparameters are inputted into the function

# %%
def train(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model(learning_rate)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=10, verbose=1)
  # fit model
  history = model.fit(X_train, y_train, epochs=epochs, batch_size=64, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test, accuracy = train(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 75)
print(accuracy)
y_pred = model_test.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %% [markdown]
# ## Train Data with Data Augmentation

# %%
def train_data_augmentation(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model(learning_rate)
  # create data generator
  datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
  # prepare iterator
  it_train = datagen.flow(X_train, y_train, batch_size=64)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=10, verbose=1)
	# fit model
  steps = int(X_train.shape[0] / 64)
  history = model.fit(it_train, epochs=epochs, steps_per_epoch=steps, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_data, accuracy = train_data_augmentation(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 75)
print(accuracy)
y_pred = model_test_data.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))
# Out:
# Epoch 1/75
# 156/156 [==============================] - 335s 2s/step - loss: 0.6894 - accuracy: 0.7192 - val_loss: 0.7900 - val_accuracy: 0.5000
# Epoch 2/75
# 156/156 [==============================] - 333s 2s/step - loss: 0.3145 - accuracy: 0.8877 - val_loss: 3.6026 - val_accuracy: 0.5000
# Epoch 3/75
# 156/156 [==============================] - 333s 2s/step - loss: 0.2579 - accuracy: 0.8998 - val_loss: 4.7291 - val_accuracy: 0.5025
# Epoch 4/75
# 156/156 [==============================] - 334s 2s/step - loss: 0.2049 - accuracy: 0.9171 - val_loss: 0.3729 - val_accuracy: 0.8740
# Epoch 5/75
# 156/156 [==============================] - 333s 2s/step - loss: 0.1793 - accuracy: 0.9291 - val_loss: 1.0287 - val_accuracy: 0.5385
# Epoch 6/75
# 156/156 [==============================] - 332s 2s/step - loss: 0.2076 - accuracy: 0.9130 - val_loss: 0.5091 - val_accuracy: 0.7820
# Epoch 7/75
# 156/156 [==============================] - 332s 2s/step - loss: 0.1809 - accuracy: 0.9276 - val_loss: 12.1015 - val_accuracy: 0.5010
# Epoch 8/75
# 156/156 [==============================] - 332s 2s/step - loss: 0.1752 - accuracy: 0.9346 - val_loss: 1.1988 - val_accuracy: 0.6620
# Epoch 9/75
# 156/156 [==============================] - 331s 2s/step - loss: 0.1616 - accuracy: 0.9307 - val_loss: 4.8906 - val_accuracy: 0.5000
# Epoch 10/75
# 156/156 [==============================] - 334s 2s/step - loss: 0.1616 - accuracy: 0.9362 - val_loss: 5.2409 - val_accuracy: 0.5105
# Epoch 11/75
# 156/156 [==============================] - 331s 2s/step - loss: 0.1504 - accuracy: 0.9386 - val_loss: 10.8671 - val_accuracy: 0.5025
# Epoch 12/75
# 156/156 [==============================] - 330s 2s/step - loss: 0.1612 - accuracy: 0.9355 - val_loss: 0.4720 - val_accuracy: 0.8510
# Epoch 13/75
# 156/156 [==============================] - 330s 2s/step - loss: 0.1387 - accuracy: 0.9477 - val_loss: 2.8711 - val_accuracy: 0.6230
# Epoch 14/75
# 156/156 [==============================] - 332s 2s/step - loss: 0.1489 - accuracy: 0.9416 - val_loss: 0.8919 - val_accuracy: 0.7555
# Epoch 00014: early stopping
# 63/63 [==============================] - 15s 241ms/step - loss: 0.9583 - accuracy: 0.7480
# 0.7480000257492065
# 506 494 10 990
# TPR/Recall: 0.99
# TNR/Specificity: 0.506
# PPV/Precision: 0.6671159029649596
# NPV: 0.9806201550387597

# %%
def train_data_augmentation2(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model(learning_rate)
  # create data generator
  datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
  # prepare iterator
  it_train = datagen.flow(X_train, y_train, batch_size=64)
	# fit model
  steps = int(X_train.shape[0] / 64)
  history = model.fit(it_train, epochs=epochs, steps_per_epoch=steps, validation_data=(X_val, y_val), verbose=1)
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_data, accuracy = train_data_augmentation2(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 75)
print(accuracy)
y_pred = model_test_data.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))
# Out:
# Epoch 1/75
# 156/156 [==============================] - 303s 2s/step - loss: 0.6728 - accuracy: 0.7265 - val_loss: 0.7275 - val_accuracy: 0.5065
# Epoch 2/75
# 156/156 [==============================] - 302s 2s/step - loss: 0.2995 - accuracy: 0.8861 - val_loss: 2.4788 - val_accuracy: 0.5010
# Epoch 3/75
# 156/156 [==============================] - 300s 2s/step - loss: 0.2468 - accuracy: 0.9081 - val_loss: 6.8317 - val_accuracy: 0.5045
# Epoch 4/75
# 156/156 [==============================] - 298s 2s/step - loss: 0.2196 - accuracy: 0.9090 - val_loss: 3.3573 - val_accuracy: 0.5595
# Epoch 5/75
# 156/156 [==============================] - 297s 2s/step - loss: 0.2006 - accuracy: 0.9169 - val_loss: 0.5841 - val_accuracy: 0.8520
# Epoch 6/75
# 156/156 [==============================] - 296s 2s/step - loss: 0.1824 - accuracy: 0.9250 - val_loss: 0.8821 - val_accuracy: 0.6300
# Epoch 7/75
# 156/156 [==============================] - 299s 2s/step - loss: 0.1673 - accuracy: 0.9340 - val_loss: 2.5964 - val_accuracy: 0.5950
# Epoch 8/75
# 156/156 [==============================] - 297s 2s/step - loss: 0.1695 - accuracy: 0.9351 - val_loss: 5.3066 - val_accuracy: 0.5505
# Epoch 9/75
# 156/156 [==============================] - 295s 2s/step - loss: 0.1631 - accuracy: 0.9339 - val_loss: 0.2507 - val_accuracy: 0.9155
# Epoch 10/75
# 156/156 [==============================] - 299s 2s/step - loss: 0.1672 - accuracy: 0.9340 - val_loss: 1.1820 - val_accuracy: 0.5730
75
# 156/156 [==============================] - 300s 2s/step - loss: 0.0783 - accuracy: 0.9700 - val_loss: 0.1288 - val_accuracy: 0.9525
# Epoch 32/75
# 156/156 [==============================] - 301s 2s/step - loss: 0.0728 - accuracy: 0.9722 - val_loss: 1.2056 - val_accuracy: 0.6565
# Epoch 33/75
# 156/156 [==============================] - 300s 2s/step - loss: 0.0734 - accuracy: 0.9742 - val_loss: 0.5822 - val_accuracy: 0.7885
# Epoch 34/75
# 156/156 [==============================] - 301s 2s/step - loss: 0.0718 - accuracy: 0.9724 - val_loss: 4.2672 - val_accuracy: 0.5745
# Epoch 35/75
# 156/156 [==============================] - 301s 2s/step - loss: 0.0732 - accuracy: 0.9703 - val_loss: 0.5123 - val_accuracy: 0.8460
# Epoch 36/75
# 156/156 [==============================] - 300s 2s/step - loss: 0.0830 - accuracy: 0.9650 - val_loss: 1.8952 - val_accuracy: 0.6295
# Epoch 37/75
# 156/156 [==============================] - 300s 2s/step - loss: 0.0646 - accuracy: 0.9754 - val_loss: 2.1633 - val_accuracy: 0.6750
# Epoch 38/75
# 156/156 [==============================] - 298s 2s/step - loss: 0.0606 - accuracy: 0.9765 - val_loss: 2.5391 - val_accuracy: 0.6250
# Epoch 39/75
# 156/156 [==============================] - 301s 2s/step - loss: 0.0632 - accuracy: 0.9730 - val_loss: 0.6548 - val_accuracy: 0.8450
# Epoch 40/75
# 156/156 [==============================] - 300s 2s/step - loss: 0.0618 - accuracy: 0.9761 - val_loss: 0.2697 - val_accuracy: 0.9220
# Epoch 41/75
# 156/156 [==============================] - 298s 2s/step - loss: 0.0615 - accuracy: 0.9780 - val_loss: 1.1335 - val_accuracy: 0.7785
# Epoch 42/75
# 156/156 [==============================] - 298s 2s/step - loss: 0.0569 - accuracy: 0.9776 - val_loss: 0.6004 - val_accuracy: 0.8625
# Epoch 43/75
# 156/156 [==============================] - 298s 2s/step - loss: 0.0504 - accuracy: 0.9810 - val_loss: 1.7644 - val_accuracy: 0.6590
# Epoch 44/75
# 156/156 [==============================] - 298s 2s/step - loss: 0.0499 - accuracy: 0.9802 - val_loss: 1.0437 - val_accuracy: 0.7780
# Epoch 45/75
# 156/156 [==============================] - 298s 2s/step - loss: 0.0576 - accuracy: 0.9767 - val_loss: 0.5757 - val_accuracy: 0.8570
# Epoch 46/75
# 156/156 [==============================] - 298s 2s/step - loss: 0.0610 - accuracy: 0.9756 - val_loss: 0.7377 - val_accuracy: 0.8315
# Epoch 47/75
# 156/156 [==============================] - 298s 2s/step - loss: 0.0558 - accuracy: 0.9796 - val_loss: 0.1120 - val_accuracy: 0.9605
# Epoch 48/75
# 156/156 [==============================] - 300s 2s/step - loss: 0.0526 - accuracy: 0.9790 - val_loss: 1.1932 - val_accuracy: 0.7550
# Epoch 49/75
# 156/156 [==============================] - 300s 2s/step - loss: 0.0436 - accuracy: 0.9843 - val_loss: 2.4849 - val_accuracy: 0.6540
# Epoch 50/75
# 156/156 [==============================] - 301s 2s/step - loss: 0.0495 - accuracy: 0.9809 - val_loss: 0.2105 - val_accuracy: 0.9420
# Epoch 51/75
# 156/156 [==============================] - 302s 2s/step - loss: 0.0410 - accuracy: 0.9841 - val_loss: 1.0310 - val_accuracy: 0.7230
# Epoch 52/75
# 156/156 [==============================] - 302s 2s/step - loss: 0.0433 - accuracy: 0.9830 - val_loss: 0.6510 - val_accuracy: 0.8170
# Epoch 53/75
# 156/156 [==============================] - 303s 2s/step - loss: 0.0387 - accuracy: 0.9839 - val_loss: 0.1408 - val_accuracy: 0.9415
# Epoch 54/75
# 156/156 [==============================] - 303s 2s/step - loss: 0.0312 - accuracy: 0.9896 - val_loss: 0.1852 - val_accuracy: 0.9390
# Epoch 55/75
# 156/156 [==============================] - 302s 2s/step - loss: 0.0444 - accuracy: 0.9841 - val_loss: 0.1181 - val_accuracy: 0.9540
# Epoch 56/75
# 156/156 [==============================] - 300s 2s/step - loss: 0.0299 - accuracy: 0.9885 - val_loss: 0.1350 - val_accuracy: 0.9585
# Epoch 57/75
# 156/156 [==============================] - 301s 2s/step - loss: 0.0378 - accuracy: 0.9859 - val_loss: 4.0380 - val_accuracy: 0.6135
# Epoch 58/75
# 156/156 [==============================] - 298s 2s/step - loss: 0.0481 - accuracy: 0.9813 - val_loss: 0.6744 - val_accuracy: 0.7620
# Epoch 59/75
# 156/156 [==============================] - 298s 2s/step - loss: 0.0465 - accuracy: 0.9821 - val_loss: 0.2391 - val_accuracy: 0.9400
# Epoch 60/75
# 156/156 [==============================] - 299s 2s/step - loss: 0.0334 - accuracy: 0.9875 - val_loss: 1.4919 - val_accuracy: 0.7675
# Epoch 61/75
# 156/156 [==============================] - 298s 2s/step - loss: 0.0465 - accuracy: 0.9831 - val_loss: 0.0974 - val_accuracy: 0.9635
# Epoch 62/75
# 156/156 [==============================] - 297s 2s/step - loss: 0.0313 - accuracy: 0.9894 - val_loss: 2.2500 - val_accuracy: 0.6480
# Epoch 63/75
# 156/156 [==============================] - 297s 2s/step - loss: 0.0340 - accuracy: 0.9870 - val_loss: 0.1233 - val_accuracy: 0.9610
# Epoch 64/75
# 156/156 [==============================] - 297s 2s/step - loss: 0.0330 - accuracy: 0.9870 - val_loss: 0.1876 - val_accuracy: 0.9385
# Epoch 65/75
# 156/156 [==============================] - 297s 2s/step - loss: 0.0371 - accuracy: 0.9860 - val_loss: 9.4452 - val_accuracy: 0.5460
# Epoch 66/75
# 156/156 [==============================] - 297s 2s/step - loss: 0.0276 - accuracy: 0.9913 - val_loss: 0.5114 - val_accuracy: 0.8715
# Epoch 67/75
# 156/156 [==============================] - 298s 2s/step - loss: 0.0298 - accuracy: 0.9894 - val_loss: 0.8039 - val_accuracy: 0.7415
# Epoch 68/75
# 156/156 [==============================] - 297s 2s/step - loss: 0.0267 - accuracy: 0.9898 - val_loss: 0.9614 - val_accuracy: 0.8135
# Epoch 69/75
# 156/156 [==============================] - 299s 2s/step - loss: 0.0240 - accuracy: 0.9916 - val_loss: 0.8083 - val_accuracy: 0.7925
# Epoch 70/75
# 156/156 [==============================] - 300s 2s/step - loss: 0.0339 - accuracy: 0.9874 - val_loss: 0.1408 - val_accuracy: 0.9610
# Epoch 71/75
# 156/156 [==============================] - 299s 2s/step - loss: 0.0269 - accuracy: 0.9890 - val_loss: 3.2843 - val_accuracy: 0.6310
# Epoch 72/75
# 156/156 [==============================] - 301s 2s/step - loss: 0.0275 - accuracy: 0.9900 - val_loss: 0.0875 - val_accuracy: 0.9655
# Epoch 73/75
# 156/156 [==============================] - 300s 2s/step - loss: 0.0243 - accuracy: 0.9897 - val_loss: 0.2170 - val_accuracy: 0.9385
# Epoch 74/75
# 156/156 [==============================] - 299s 2s/step - loss: 0.0313 - accuracy: 0.9892 - val_loss: 6.1939 - val_accuracy: 0.5695
# Epoch 75/75
# 156/156 [==============================] - 299s 2s/step - loss: 0.0222 - accuracy: 0.9924 - val_loss: 0.2245 - val_accuracy: 0.9265
# 63/63 [==============================] - 14s 220ms/step - loss: 0.2193 - accuracy: 0.9370
# 0.9369999766349792
# 965 35 91 909
# TPR/Recall: 0.909
# TNR/Specificity: 0.965
# PPV/Precision: 0.9629237288135594
# NPV: 0.9138257575757576

# %% [markdown]
# ## Train Data with Weight Regularization

# %%
def train_data_weight(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model_weight_regularization(learning_rate)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
  # fit model
  history = model.fit(X_train, y_train, epochs=epochs, batch_size=64, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_weight, accuracy = train_data_weight(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 75)
print(accuracy)
y_pred = model_test_weight.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))
# Out:
# Epoch 1/75
# 157/157 [==============================] - 349s 2s/step - loss: 92.8482 - accuracy: 0.7198 - val_loss: 88.8554 - val_accuracy: 0.5000
# Epoch 2/75
# 157/157 [==============================] - 345s 2s/step - loss: 86.8912 - accuracy: 0.8996 - val_loss: 83.3639 - val_accuracy: 0.6190
# Epoch 3/75
# 157/157 [==============================] - 344s 2s/step - loss: 81.5663 - accuracy: 0.9211 - val_loss: 79.7698 - val_accuracy: 0.5685
# Epoch 4/75
# 157/157 [==============================] - 345s 2s/step - loss: 76.5814 - accuracy: 0.9249 - val_loss: 75.6691 - val_accuracy: 0.5180
# Epoch 5/75
# 157/157 [==============================] - 346s 2s/step - loss: 71.9011 - accuracy: 0.9370 - val_loss: 68.9655 - val_accuracy: 0.8415
# Epoch 6/75
# 157/157 [==============================] - 345s 2s/step - loss: 67.5332 - accuracy: 0.9346 - val_loss: 72.5770 - val_accuracy: 0.5020
# Epoch 7/75
# 157/157 [==============================] - 346s 2s/step - loss: 63.3921 - accuracy: 0.9503 - val_loss: 60.7714 - val_accuracy: 0.8710
# Epoch 8/75
# 157/157 [==============================] - 344s 2s/step - loss: 59.5191 - accuracy: 0.9583 - val_loss: 57.0721 - val_accuracy: 0.8245
# Epoch 9/75
# 157/157 [==============================] - 345s 2s/step - loss: 55.9061 - accuracy: 0.9541 - val_loss: 54.1641 - val_accuracy: 0.6625
# Epoch 10/75
# 157/157 [==============================] - 347s 2s/step - loss: 52.4977 - accuracy: 0.9615 - val_loss: 54.9506 - val_accuracy: 0.5170
# Epoch 11/75
# 157/157 [==============================] - 347s 2s/step - loss: 49.2976 - accuracy: 0.9634 - val_loss: 47.3386 - val_accuracy: 0.8480
# Epoch 12/75
# 157/157 [==============================] - 346s 2s/step - loss: 46.2791 - accuracy: 0.9763 - val_loss: 44.2464 - val_accuracy: 0.9360
# Epoch 13/75
# 157/157 [==============================] - 345s 2s/step - loss: 43.4607 - accuracy: 0.9772 - val_loss: 43.4427 - val_accuracy: 0.6270
# Epoch 14/75
# 157/157 [==============================] - 345s 2s/step - loss: 40.8166 - accuracy: 0.9746 - val_loss: 39.4768 - val_accuracy: 0.8215
# Epoch 15/75
# 157/157 [==============================] - 344s 2s/step - loss: 38.3276 - accuracy: 0.9800 - val_loss: 36.6919 - val_accuracy: 0.9300
# Epoch 16/75
# 157/157 [==============================] - 346s 2s/step - loss: 35.9880 - accuracy: 0.9840 - val_loss: 37.0464 - val_accuracy: 0.4700
# Epoch 17/75
# 157/157 [==============================] - 343s 2s/step - loss: 33.8080 - accuracy: 0.9794 - val_loss: 32.8517 - val_accuracy: 0.8215
# Epoch 18/75
# 157/157 [==============================] - 344s 2s/step - loss: 31.7308 - accuracy: 0.9914 - val_loss: 33.7945 - val_accuracy: 0.5340
# Epoch 19/75
# 157/157 [==============================] - 345s 2s/step - loss: 29.8125 - accuracy: 0.9866 - val_loss: 28.5637 - val_accuracy: 0.9445
# Epoch 20/75
# 157/157 [==============================] - 347s 2s/step - loss: 2.3281 - accuracy: 0.9971 - val_loss: 2.3922 - val_accuracy: 0.9435
# Epoch 61/75
# 157/157 [==============================] - 349s 2s/step - loss: 2.1792 - accuracy: 1.0000 - val_loss: 2.5795 - val_accuracy: 0.8625
# Epoch 62/75
# 157/157 [==============================] - 349s 2s/step - loss: 2.0471 - accuracy: 1.0000 - val_loss: 2.1307 - val_accuracy: 0.9520
# Epoch 63/75
# 157/157 [==============================] - 353s 2s/step - loss: 1.9237 - accuracy: 0.9996 - val_loss: 1.9566 - val_accuracy: 0.9640
# Epoch 64/75
# 157/157 [==============================] - 353s 2s/step - loss: 1.8057 - accuracy: 1.0000 - val_loss: 1.8508 - val_accuracy: 0.9670
# Epoch 65/75
# 157/157 [==============================] - 351s 2s/step - loss: 1.6959 - accuracy: 1.0000 - val_loss: 1.7492 - val_accuracy: 0.9645
# Epoch 66/75
# 157/157 [==============================] - 350s 2s/step - loss: 1.5926 - accuracy: 1.0000 - val_loss: 1.6485 - val_accuracy: 0.9635
# Epoch 67/75
# 157/157 [==============================] - 349s 2s/step - loss: 1.4959 - accuracy: 1.0000 - val_loss: 1.6223 - val_accuracy: 0.9315
# Epoch 68/75
# 157/157 [==============================] - 349s 2s/step - loss: 1.4050 - accuracy: 1.0000 - val_loss: 1.4601 - val_accuracy: 0.9610
# Epoch 69/75
# 157/157 [==============================] - 348s 2s/step - loss: 1.3202 - accuracy: 0.9998 - val_loss: 2.1072 - val_accuracy: 0.6915
# Epoch 70/75
# 157/157 [==============================] - 349s 2s/step - loss: 1.3332 - accuracy: 0.9661 - val_loss: 1.7180 - val_accuracy: 0.7390
# Epoch 71/75
# 157/157 [==============================] - 349s 2s/step - loss: 1.2416 - accuracy: 0.9781 - val_loss: 1.6441 - val_accuracy: 0.8290
# Epoch 72/75
# 157/157 [==============================] - 349s 2s/step - loss: 1.1379 - accuracy: 0.9925 - val_loss: 3.6226 - val_accuracy: 0.5320
# Epoch 73/75
# 157/157 [==============================] - 348s 2s/step - loss: 1.0932 - accuracy: 0.9846 - val_loss: 1.3887 - val_accuracy: 0.8645
# Epoch 74/75
# 157/157 [==============================] - 349s 2s/step - loss: 1.0543 - accuracy: 0.9789 - val_loss: 1.3375 - val_accuracy: 0.8410
# Epoch 75/75
# 157/157 [==============================] - 350s 2s/step - loss: 0.9671 - accuracy: 0.9949 - val_loss: 1.0907 - val_accuracy: 0.9395
# 63/63 [==============================] - 19s 297ms/step - loss: 1.0629 - accuracy: 0.9425
# 0.9424999952316284
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-31c208d33059> in <module>
#       1 model_test_weight, accuracy = train_data_weight(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 75)
#       2 print(accuracy)
# ----> 3 y_pred = model_test_data_weight_batch_normalization.predict(X_test)
#       4 y_pred_val = y_pred.argmax(axis=1)
#       5 y_test_val = y_test.argmax(axis=1)
#
# NameError: name 'model_test_data_weight_batch_normalization' is not defined

# %%
y_pred = model_test_weight.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))
# Out:
# 985 15 100 900
# TPR/Recall: 0.9
# TNR/Specificity: 0.985
# PPV/Precision: 0.9836065573770492
# NPV: 0.9078341013824884

# %% [markdown]
# ### Train Data with Data Augmentation and Weight Regularization

# %%
def train_data_augmentation_weight(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model_weight_regularization(learning_rate)
  # create data generator
  datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
  # prepare iterator
  it_train = datagen.flow(X_train, y_train, batch_size=64)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
	# fit model  
  steps = int(X_train.shape[0] / 64)
  history = model.fit(it_train, epochs=epochs, steps_per_epoch=steps, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_data_weight, accuracy = train_data_augmentation_weight(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 75)
print(accuracy)
y_pred = model_test_data_weight.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))
# Out:
# Epoch 1/75
# 156/156 [==============================] - 368s 2s/step - loss: 92.8702 - accuracy: 0.7273 - val_loss: 88.8623 - val_accuracy: 0.5000
# Epoch 2/75
# 156/156 [==============================] - 359s 2s/step - loss: 86.9815 - accuracy: 0.8934 - val_loss: 84.6647 - val_accuracy: 0.5105
# Epoch 3/75
# 156/156 [==============================] - 358s 2s/step - loss: 81.6877 - accuracy: 0.8973 - val_loss: 83.0409 - val_accuracy: 0.5070
# Epoch 4/75
# 156/156 [==============================] - 359s 2s/step - loss: 76.7176 - accuracy: 0.9122 - val_loss: 80.3537 - val_accuracy: 0.5000
# Epoch 5/75
# 156/156 [==============================] - 360s 2s/step - loss: 72.0623 - accuracy: 0.9267 - val_loss: 71.0728 - val_accuracy: 0.5840
# Epoch 6/75
# 156/156 [==============================] - 359s 2s/step - loss: 67.7152 - accuracy: 0.9199 - val_loss: 65.5310 - val_accuracy: 0.7120
# Epoch 7/75
# 156/156 [==============================] - 359s 2s/step - loss: 63.6128 - accuracy: 0.9259 - val_loss: 61.7905 - val_accuracy: 0.7905
# Epoch 8/75
# 156/156 [==============================] - 359s 2s/step - loss: 59.7540 - accuracy: 0.9315 - val_loss: 57.2458 - val_accuracy: 0.8570
# Epoch 9/75
# 156/156 [==============================] - 360s 2s/step - loss: 56.1470 - accuracy: 0.9292 - val_loss: 54.0333 - val_accuracy: 0.7995
# Epoch 10/75
# 156/156 [==============================] - 359s 2s/step - loss: 52.7326 - accuracy: 0.9397 - val_loss: 50.5398 - val_accuracy: 0.8675
# Epoch 11/75
# 156/156 [==============================] - 359s 2s/step - loss: 49.5438 - accuracy: 0.9424 - val_loss: 47.4307 - val_accuracy: 0.8550
# Epoch 12/75
# 156/156 [==============================] - 361s 2s/step - loss: 46.5478 - accuracy: 0.9472 - val_loss: 44.9802 - val_accuracy: 0.7015
# Epoch 13/75
# 156/156 [==============================] - 359s 2s/step - loss: 43.7438 - accuracy: 0.9435 - val_loss: 44.9636 - val_accuracy: 0.5515
# Epoch 14/75
# 156/156 [==============================] - 359s 2s/step - loss: 41.0877 - accuracy: 0.9479 - val_loss: 39.8099 - val_accuracy: 0.7180
# Epoch 15/75
# 156/156 [==============================] - 359s 2s/step - loss: 38.6052 - accuracy: 0.9489 - val_loss: 37.6242 - val_accuracy: 0.6620
# Epoch 16/75
# 156/156 [==============================] - 357s 2s/step - loss: 36.2849 - accuracy: 0.9462 - val_loss: 38.4712 - val_accuracy: 0.5185
# Epoch 17/75
