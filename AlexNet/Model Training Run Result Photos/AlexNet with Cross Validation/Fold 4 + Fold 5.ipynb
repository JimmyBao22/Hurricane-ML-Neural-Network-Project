# %% [markdown]
# # Imports

# %%
import numpy as np
import glob
from PIL import Image
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from tensorflow.keras import optimizers
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import KFold
import pandas as pd
import seaborn as sn
sn.set(font_scale=1.4) # for label size
import multiprocessing as mp
import csv

# %% [markdown]
# # Load DataSet
#
# 0 means unlikely to have flood damage, 1 means likely to have flood damage
#
# [0,1] --> damage
#
# [1,0] --> no damage

# %% [markdown]
# ## Load Training Set

# %%
images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/train_another/damage/*.jpeg')
dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  dmg_img.append(im_arr)
dmg_img = np.array(dmg_img)

images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/train_another/no_damage/*.jpeg')
no_dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  no_dmg_img.append(im_arr)
no_dmg_img = np.array(no_dmg_img)

X_train = np.concatenate((dmg_img, no_dmg_img))
dmg_img_y = np.array(dmg_img.shape[0] * [[0,1]])
no_dmg_img_y = np.array(no_dmg_img.shape[0] * [[1,0]])
y_train = np.concatenate((dmg_img_y, no_dmg_img_y))

# shuffle arrays so that the array is a mix of damage and no_damage in a random order
shuffler = np.random.permutation(X_train.shape[0])
X_train = X_train[shuffler]
y_train = y_train[shuffler]

# %% [markdown]
# ## Load Validation Set

# %%
images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/validation_another/damage/*.jpeg')
dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  dmg_img.append(im_arr)
dmg_img = np.array(dmg_img)

images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/validation_another/no_damage/*.jpeg')
no_dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  no_dmg_img.append(im_arr)
no_dmg_img = np.array(no_dmg_img)

X_val = np.concatenate((dmg_img, no_dmg_img))
dmg_img_y = np.array(dmg_img.shape[0] * [[0,1]])
no_dmg_img_y = np.array(no_dmg_img.shape[0] * [[1,0]])
y_val = np.concatenate((dmg_img_y, no_dmg_img_y))

# shuffle arrays so that the array is a mix of damage and no_damage in a random order
shuffler = np.random.permutation(X_val.shape[0])
X_val = X_val[shuffler]
y_val = y_val[shuffler]

# %%
# combine training and validation data - for cross-validation
X_all = np.concatenate((X_train, X_val))
y_all = np.concatenate((y_train, y_val))

# %% [markdown]
# ## Load Test Set

# %%
images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/test/damage/*.jpeg')
dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  dmg_img.append(im_arr)
dmg_img = np.array(dmg_img)

images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/test/no_damage/*.jpeg')
no_dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  no_dmg_img.append(im_arr)
no_dmg_img = np.array(no_dmg_img)

X_test = np.concatenate((dmg_img, no_dmg_img))
dmg_img_y = np.array(dmg_img.shape[0] * [[0,1]])
no_dmg_img_y = np.array(no_dmg_img.shape[0] * [[1,0]])
y_test = np.concatenate((dmg_img_y, no_dmg_img_y))

# shuffle arrays so that the array is a mix of damage and no_damage in a random order
shuffler = np.random.permutation(X_val.shape[0])
X_test = X_test[shuffler]
y_test = y_test[shuffler]

# %% [markdown]
# ## Input/Output

# %%
# save a dictionary as a csv file
def output_as_csv(name, a):
    path = "/kaggle/working/" + name + ".csv"
    with open(path, 'w') as csv_file:
        # create the csv writer
        writer = csv.writer(csv_file)

        # write a row to the csv file
        writer.writerow(a.keys())
        writer.writerow(a.values())

# input a csv file
def input_csv(path):
    b, keys = {}, {}
    with open(path, mode='r') as csv_file:
        csv_reader = csv.DictReader(csv_file)
        line_count = 0
        for row in csv_reader:
            keys = row
    b = dict(keys)
    return b # returns a dictionary

# %% [markdown]
# # Pre-Process DataSet

# %%
# pre-process data 
def scale_pixels(train, val, test, X_all):
	# convert from integers to floats and normalize between 0-1
  train_norm = train.astype('float32') / 255.0
  val_norm = val.astype('float32') / 255.0
  test_norm = test.astype('float32') / 255.0
  X_all_norm = X_all.astype('float32') / 255.0
	# return normalized images
  return train_norm, val_norm, test_norm, X_all_norm

X_train, X_val, X_test, X_all = scale_pixels(X_train, X_val, X_test, X_all)

# %% [markdown]
# # Plot Diagnostics

# %%
# plot diagnostic learning curves
def summarize_diagnostics(history):
  # blue = training data; orange = validation data
	# plot validation loss
	plt.subplot(211)
	plt.title('Cross Entropy Loss')
	plt.plot(history.history['loss'], color='blue', label='train')
	plt.plot(history.history['val_loss'], color='orange', label='validation')
	# plot accuracy
	plt.subplot(212)
	plt.title('Classification Accuracy')
	plt.plot(history.history['accuracy'], color='blue', label='train')
	plt.plot(history.history['val_accuracy'], color='orange', label='validation')

# %%
# returns the confusion matrix
def find_confusion_matrix(model, X_test, y_test):
    y_pred = model.predict(X_test)
    y_pred_val = y_pred.argmax(axis=1)
    y_test_val = y_test.argmax(axis=1)
    return confusion_matrix(y_test_val, y_pred_val)

# returns the confusion matrix based on tn, fn, fp, tp
def find_confusion_matrix_2(tn, fn, fp, tp):
    return [[tn, fp], [fn, tp]]

# generate heat map for confusion matrix
def heatmap(confusion_matrix):
    df = pd.DataFrame(confusion_matrix, index = ['F', 'T'], columns = ['F', 'T'])
    sn.heatmap(df, annot=True) # create a heatmap
    
# returns normalized confusion matrix
def normalize_confusion_matrix(confusion_matrix):
    confusion_matrix = np.array(confusion_matrix)
    confusion_matrix_sum = confusion_matrix.astype(np.float).sum(axis=1)
    confusion_matrix_norm = confusion_matrix.astype(np.float)
    confusion_matrix_norm[0] = confusion_matrix_norm[0] / confusion_matrix_sum[0]
    confusion_matrix_norm[1] = confusion_matrix_norm[1] / confusion_matrix_sum[1]
    return confusion_matrix_norm

def print_confusion_matrix_results(results):
    # results is a dictionary
    # calculate mean and standard deviation for each key
    for key in results:
        mean = np.mean(results[key])
        std = np.std(results[key])
        print("{} mean: {}".format(key, mean))
        print("{} std: {}".format(key, std))

# %% [markdown]
# # Create CNN Model

# %%
# define cnn model
def define_model(learning_rate):
  model = keras.Sequential()
  model.add(layers.Conv2D(filters=96, input_shape=(128,128,3), kernel_size=(11,11), strides=(4,4), activation='relu', padding='same'))
  model.add(layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)))
  model.add(layers.Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), activation='relu', padding="same"))
  model.add(layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)))
  model.add(layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"))
  model.add(layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"))
  model.add(layers.Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"))
  model.add(layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)))
  model.add(layers.Flatten())
  model.add(layers.Dense(4096, activation='relu'))
  model.add(layers.Dropout(0.5))
  model.add(layers.Dense(4096, activation='relu'))
  model.add(layers.Dropout(0.5))
  model.add(layers.Dense(2, activation='softmax'))  # compile model
  opt = optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
  model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
  return model

# %% [markdown]
# ## CNN Model with Batch Normalization

# %%
# define cnn model
def define_model_batch_normalization(learning_rate):
  model = keras.Sequential()
  model.add(layers.Conv2D(filters=96, input_shape=(128,128,3), kernel_size=(11,11), strides=(4,4), activation='relu', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)))
  model.add(layers.Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), activation='relu', padding="same"))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)))
  model.add(layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)))
  model.add(layers.Flatten())
  model.add(layers.Dense(4096, activation='relu'))
  model.add(layers.Dropout(0.5))
  model.add(layers.Dense(4096, activation='relu'))
  model.add(layers.Dropout(0.5))
  model.add(layers.Dense(2, activation='softmax'))  # compile model
  opt = optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
  model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
  return model

# %% [markdown]
# ## CNN Model with Batch Normalization and Weight Regularization

# %%
# define cnn model
def define_model_weight_regularization(learning_rate):
  model = keras.Sequential()
  model.add(layers.Conv2D(filters=96, input_shape=(128,128,3), kernel_size=(11,11), strides=(4,4), activation='relu', kernel_regularizer=regularizers.l2(0.01), padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)))
  model.add(layers.Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), activation='relu', kernel_regularizer=regularizers.l2(0.01), padding="same"))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)))
  model.add(layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', kernel_regularizer=regularizers.l2(0.01), padding="same"))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', kernel_regularizer=regularizers.l2(0.01), padding="same"))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', kernel_regularizer=regularizers.l2(0.01), padding="same"))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)))
  model.add(layers.Flatten())
  model.add(layers.Dense(4096, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.Dropout(0.5))
  model.add(layers.Dense(4096, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.Dropout(0.5))
  model.add(layers.Dense(2, activation='softmax'))  # compile model
  opt = optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
  model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
  return model

# %% [markdown]
# # Train Data
# Hyperparameters are inputted into the function

# %%
def train(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model(learning_rate)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=10, verbose=1)
  # fit model
  history = model.fit(X_train, y_train, epochs=epochs, batch_size=64, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test, accuracy = train(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 75)
print(accuracy)
y_pred = model_test.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test, accuracy = train(X_train, X_val, X_test, y_train, y_val, y_test, 1e-4, 75)
print(accuracy)
y_pred = model_test.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test, accuracy = train(X_train, X_val, X_test, y_train, y_val, y_test,1e-5, 75)
print(accuracy)
y_pred = model_test.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test, accuracy = train(X_train, X_val, X_test, y_train, y_val, y_test,1e-6, 75)
print(accuracy)
y_pred = model_test.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test, accuracy = train(X_train, X_val, X_test, y_train, y_val, y_test,5e-5, 75)
print(accuracy)
y_pred = model_test.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %% [markdown]
# ## Train Data w/ Cross Validation

# %%
def benchmark_model(X_all, y_all, split):
    X_train_cv, y_train_cv = X_all[split[0]], y_all[split[0]]
    X_val_cv, y_val_cv = X_all[split[1]], y_all[split[1]]
    model, accuracy = train(X_train_cv, X_val_cv, X_val_cv, y_train_cv, y_val_cv, y_val_cv, 0.001, 75) 
    results = {}
#     results["model"] = model
    results["accuracy"] = accuracy
    results["confusion_matrix"] = find_confusion_matrix(model, X_val_cv, y_val_cv)
    tn, fp, fn, tp = results["confusion_matrix"].ravel()
    results["tn"] = tn
    results["fp"] = fp
    results["fn"] = fn
    results["tp"] = tp
    results["TPR/Recall"] = tp/(tp+fn)
    results["TNR/Specificity"] = tn/(tn+fp)
    results["PPV/Precision"] = tp/(tp+fp)
    results["NPV"] = tn/(tn+fn)
    return results

# %%
kf = KFold(n_splits=5)
folds = list(kf.split(X_all, y_all))

# %%
output_as_csv("normal_fold_1", benchmark_model(X_all, y_all, folds[0]))

# %%
output_as_csv("normal_fold_2", benchmark_model(X_all, y_all, folds[1]))

# %%
output_as_csv("normal_fold_3", benchmark_model(X_all, y_all, folds[2]))

# %%
output_as_csv("normal_fold_4", benchmark_model(X_all, y_all, folds[3]))
# Out:
# Epoch 1/75
# 150/150 [==============================] - 13s 34ms/step - loss: 0.6931 - accuracy: 0.4985 - val_loss: 0.6924 - val_accuracy: 0.4842
# Epoch 2/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.6913 - accuracy: 0.5101 - val_loss: 0.6914 - val_accuracy: 0.4842
# Epoch 3/75
# 150/150 [==============================] - 4s 27ms/step - loss: 0.6902 - accuracy: 0.5061 - val_loss: 0.6899 - val_accuracy: 0.4846
# Epoch 4/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.6877 - accuracy: 0.5124 - val_loss: 0.6868 - val_accuracy: 0.4983
# Epoch 5/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.6857 - accuracy: 0.5346 - val_loss: 0.6819 - val_accuracy: 0.5033
# Epoch 6/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.6793 - accuracy: 0.5599 - val_loss: 0.6705 - val_accuracy: 0.5200
# Epoch 7/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.6622 - accuracy: 0.6455 - val_loss: 0.6210 - val_accuracy: 0.7696
# Epoch 8/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.6178 - accuracy: 0.7356 - val_loss: 0.5424 - val_accuracy: 0.8100
# Epoch 9/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.5464 - accuracy: 0.7695 - val_loss: 0.4669 - val_accuracy: 0.8217
# Epoch 10/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.5009 - accuracy: 0.7808 - val_loss: 0.4531 - val_accuracy: 0.8075
# Epoch 11/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.4536 - accuracy: 0.8077 - val_loss: 0.4352 - val_accuracy: 0.8154
# Epoch 12/75
# 150/150 [==============================] - 4s 28ms/step - loss: 0.4182 - accuracy: 0.8251 - val_loss: 0.4218 - val_accuracy: 0.8238
# Epoch 13/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.3901 - accuracy: 0.8434 - val_loss: 0.4000 - val_accuracy: 0.8321
# Epoch 14/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.3663 - accuracy: 0.8484 - val_loss: 0.3737 - val_accuracy: 0.8388
# Epoch 15/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.3628 - accuracy: 0.8512 - val_loss: 0.3408 - val_accuracy: 0.8596
# Epoch 16/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.3247 - accuracy: 0.8664 - val_loss: 0.3421 - val_accuracy: 0.8537
# Epoch 17/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.3174 - accuracy: 0.8715 - val_loss: 0.3352 - val_accuracy: 0.8675
# Epoch 18/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.3231 - accuracy: 0.8648 - val_loss: 0.3060 - val_accuracy: 0.8671
# Epoch 19/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.3132 - accuracy: 0.8724 - val_loss: 0.3126 - val_accuracy: 0.8746
# Epoch 20/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.2895 - accuracy: 0.8838 - val_loss: 0.2916 - val_accuracy: 0.8783
# Epoch 21/75
# 150/150 [==============================] - 4s 27ms/step - loss: 0.2965 - accuracy: 0.8782 - val_loss: 0.3156 - val_accuracy: 0.8604
# Epoch 22/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.3023 - accuracy: 0.8771 - val_loss: 0.3538 - val_accuracy: 0.8529
# Epoch 23/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.3002 - accuracy: 0.8750 - val_loss: 0.2833 - val_accuracy: 0.8792
# Epoch 24/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.2837 - accuracy: 0.8885 - val_loss: 0.2934 - val_accuracy: 0.8842
# Epoch 25/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.2790 - accuracy: 0.8843 - val_loss: 0.3677 - val_accuracy: 0.8667
# Epoch 26/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.3019 - accuracy: 0.8781 - val_loss: 0.3035 - val_accuracy: 0.8838
# Epoch 27/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.2612 - accuracy: 0.8918 - val_loss: 0.2628 - val_accuracy: 0.8883
# Epoch 28/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.2751 - accuracy: 0.8921 - val_loss: 0.3076 - val_accuracy: 0.8687
# Epoch 29/75
# 150/150 [==============================] - 4s 26ms/step - loss: 0.2548 - accuracy: 0.8954 - val_loss: 0.2460 - val_accuracy: 0.8946
# Epoch 30/75
# 150/150 [==============================] - 4s 27ms/step - loss: 0.2497 - accuracy: 0.8978 - val_loss: 0.2454 - val_accuracy: 0.8975
# Epoch 31/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.2337 - accuracy: 0.9032 - val_loss: 0.2311 - val_accuracy: 0.9054
# Epoch 32/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.2304 - accuracy: 0.9064 - val_loss: 0.2288 - val_accuracy: 0.9025
# Epoch 33/75
# 150/150 [==============================] - 4s 26ms/step - loss: 0.2296 - accuracy: 0.9052 - val_loss: 0.2391 - val_accuracy: 0.8971
# Epoch 34/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.2267 - accuracy: 0.9064 - val_loss: 0.3244 - val_accuracy: 0.8908
# Epoch 35/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.2324 - accuracy: 0.9062 - val_loss: 0.2338 - val_accuracy: 0.9075
# Epoch 36/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.2095 - accuracy: 0.9165 - val_loss: 0.2355 - val_accuracy: 0.9000
# Epoch 37/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.2094 - accuracy: 0.9144 - val_loss: 0.1860 - val_accuracy: 0.9237
# Epoch 38/75
# 150/150 [==============================] - 4s 27ms/step - loss: 0.1928 - accuracy: 0.9206 - val_loss: 0.1950 - val_accuracy: 0.9262
# Epoch 39/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.2031 - accuracy: 0.9185 - val_loss: 0.1913 - val_accuracy: 0.9179
# Epoch 40/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.1956 - accuracy: 0.9169 - val_loss: 0.2137 - val_accuracy: 0.9171
# Epoch 41/75
# 150/150 [==============================] - 4s 26ms/step - loss: 0.2083 - accuracy: 0.9112 - val_loss: 0.3950 - val_accuracy: 0.8637
# Epoch 42/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.2123 - accuracy: 0.9166 - val_loss: 0.1855 - val_accuracy: 0.9271
# Epoch 43/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.1797 - accuracy: 0.9275 - val_loss: 0.2020 - val_accuracy: 0.9167
# Epoch 44/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.1760 - accuracy: 0.9292 - val_loss: 0.1716 - val_accuracy: 0.9342
# Epoch 45/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.1715 - accuracy: 0.9321 - val_loss: 0.2032 - val_accuracy: 0.9212
# Epoch 46/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.1591 - accuracy: 0.9353 - val_loss: 0.2105 - val_accuracy: 0.9183
# Epoch 47/75
# 150/150 [==============================] - 4s 27ms/step - loss: 0.1664 - accuracy: 0.9326 - val_loss: 0.1537 - val_accuracy: 0.9350
# Epoch 48/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.1481 - accuracy: 0.9381 - val_loss: 0.1542 - val_accuracy: 0.9371
# Epoch 49/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.1595 - accuracy: 0.9337 - val_loss: 0.1622 - val_accuracy: 0.9321
# Epoch 50/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.1747 - accuracy: 0.9278 - val_loss: 0.1510 - val_accuracy: 0.9383
# Epoch 51/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.1632 - accuracy: 0.9346 - val_loss: 0.2099 - val_accuracy: 0.9196
# Epoch 52/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.1467 - accuracy: 0.9428 - val_loss: 0.1568 - val_accuracy: 0.9342
# Epoch 53/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.1523 - accuracy: 0.9401 - val_loss: 0.1503 - val_accuracy: 0.9375
# Epoch 54/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.1481 - accuracy: 0.9444 - val_loss: 0.1377 - val_accuracy: 0.9463
# Epoch 55/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.1274 - accuracy: 0.9486 - val_loss: 0.1341 - val_accuracy: 0.9496
# Epoch 56/75
# 150/150 [==============================] - 4s 27ms/step - loss: 0.1381 - accuracy: 0.9445 - val_loss: 0.1351 - val_accuracy: 0.9500
# Epoch 57/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.1381 - accuracy: 0.9469 - val_loss: 0.1456 - val_accuracy: 0.9379
# Epoch 58/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.1390 - accuracy: 0.9420 - val_loss: 0.1393 - val_accuracy: 0.9421
# Epoch 59/75
# 150/150 [==============================] - 4s 26ms/step - loss: 0.1210 - accuracy: 0.9513 - val_loss: 0.1740 - val_accuracy: 0.9300
# Epoch 60/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.1281 - accuracy: 0.9493 - val_loss: 0.1809 - val_accuracy: 0.9304
# Epoch 61/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.1128 - accuracy: 0.9571 - val_loss: 0.1377 - val_accuracy: 0.9392
# Epoch 62/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.1290 - accuracy: 0.9478 - val_loss: 0.1173 - val_accuracy: 0.9533
# Epoch 63/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.1162 - accuracy: 0.9547 - val_loss: 0.1246 - val_accuracy: 0.9529
# Epoch 64/75
# 150/150 [==============================] - 4s 26ms/step - loss: 0.1079 - accuracy: 0.9586 - val_loss: 0.1275 - val_accuracy: 0.9504
# Epoch 65/75
# 150/150 [==============================] - 4s 26ms/step - loss: 0.1239 - accuracy: 0.9512 - val_loss: 0.1404 - val_accuracy: 0.9492
# Epoch 66/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.1159 - accuracy: 0.9558 - val_loss: 0.1188 - val_accuracy: 0.9488
# Epoch 67/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.1130 - accuracy: 0.9578 - val_loss: 0.1418 - val_accuracy: 0.9429
# Epoch 68/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.1059 - accuracy: 0.9583 - val_loss: 0.1573 - val_accuracy: 0.9375
# Epoch 69/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.1210 - accuracy: 0.9546 - val_loss: 0.1163 - val_accuracy: 0.9542
# Epoch 70/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.0990 - accuracy: 0.9618 - val_loss: 0.1257 - val_accuracy: 0.9454
# Epoch 71/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.1011 - accuracy: 0.9635 - val_loss: 0.1391 - val_accuracy: 0.9496
# Epoch 72/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.1041 - accuracy: 0.9582 - val_loss: 0.1538 - val_accuracy: 0.9388
# Epoch 73/75
# 150/150 [==============================] - 4s 26ms/step - loss: 0.1077 - accuracy: 0.9615 - val_loss: 0.1181 - val_accuracy: 0.9588
# Epoch 74/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.1107 - accuracy: 0.9546 - val_loss: 0.1201 - val_accuracy: 0.9542
# Epoch 75/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.0956 - accuracy: 0.9636 - val_loss: 0.1123 - val_accuracy: 0.9579
# 75/75 [==============================] - 1s 7ms/step - loss: 0.1123 - accuracy: 0.9579

# %%
output_as_csv("normal_fold_5", benchmark_model(X_all, y_all, folds[4]))
# Out:
# Epoch 1/75
# 150/150 [==============================] - 13s 34ms/step - loss: 0.6927 - accuracy: 0.4985 - val_loss: 0.6916 - val_accuracy: 0.4992
# Epoch 2/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.6918 - accuracy: 0.5020 - val_loss: 0.6901 - val_accuracy: 0.4996
# Epoch 3/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.6899 - accuracy: 0.5067 - val_loss: 0.6879 - val_accuracy: 0.5021
# Epoch 4/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.6881 - accuracy: 0.5089 - val_loss: 0.6843 - val_accuracy: 0.5071
# Epoch 5/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.6842 - accuracy: 0.5556 - val_loss: 0.6773 - val_accuracy: 0.6150
# Epoch 6/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.6765 - accuracy: 0.6468 - val_loss: 0.6645 - val_accuracy: 0.7588
# Epoch 7/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.6561 - accuracy: 0.6896 - val_loss: 0.6024 - val_accuracy: 0.7675
# Epoch 8/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.6132 - accuracy: 0.7168 - val_loss: 0.5553 - val_accuracy: 0.7937
# Epoch 9/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.5606 - accuracy: 0.7644 - val_loss: 0.5854 - val_accuracy: 0.7475
# Epoch 10/75
# 150/150 [==============================] - 4s 26ms/step - loss: 0.4913 - accuracy: 0.7932 - val_loss: 0.4697 - val_accuracy: 0.7875
# Epoch 11/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.4431 - accuracy: 0.8161 - val_loss: 0.4083 - val_accuracy: 0.8392
# Epoch 12/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.4366 - accuracy: 0.8186 - val_loss: 0.3896 - val_accuracy: 0.8404
# Epoch 13/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.4162 - accuracy: 0.8310 - val_loss: 0.3801 - val_accuracy: 0.8425
# Epoch 14/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.3968 - accuracy: 0.8339 - val_loss: 0.4436 - val_accuracy: 0.8183
# Epoch 15/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.3731 - accuracy: 0.8510 - val_loss: 0.3536 - val_accuracy: 0.8537
# Epoch 16/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.3520 - accuracy: 0.8560 - val_loss: 0.3474 - val_accuracy: 0.8617
# Epoch 17/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.3601 - accuracy: 0.8442 - val_loss: 0.3587 - val_accuracy: 0.8467
# Epoch 18/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.3441 - accuracy: 0.8561 - val_loss: 0.3262 - val_accuracy: 0.8650
# Epoch 19/75
# 150/150 [==============================] - 4s 26ms/step - loss: 0.3290 - accuracy: 0.8640 - val_loss: 0.4390 - val_accuracy: 0.8146
# Epoch 20/75
# 150/150 [==============================] - 4s 26ms/step - loss: 0.3382 - accuracy: 0.8594 - val_loss: 0.2633 - val_accuracy: 0.8967
# Epoch 21/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.2991 - accuracy: 0.8790 - val_loss: 0.2855 - val_accuracy: 0.8833
# Epoch 22/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.2939 - accuracy: 0.8801 - val_loss: 0.3411 - val_accuracy: 0.8587
# Epoch 23/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.2673 - accuracy: 0.8945 - val_loss: 0.2500 - val_accuracy: 0.8942
# Epoch 24/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.2632 - accuracy: 0.8929 - val_loss: 0.2355 - val_accuracy: 0.8975
# Epoch 25/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.2722 - accuracy: 0.8914 - val_loss: 0.2239 - val_accuracy: 0.9067
# Epoch 26/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.2646 - accuracy: 0.8938 - val_loss: 0.2218 - val_accuracy: 0.9058
# Epoch 27/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.2301 - accuracy: 0.9059 - val_loss: 0.2222 - val_accuracy: 0.9092
# Epoch 28/75
# 150/150 [==============================] - 4s 26ms/step - loss: 0.2587 - accuracy: 0.8938 - val_loss: 0.2694 - val_accuracy: 0.8904
# Epoch 29/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.2049 - accuracy: 0.9198 - val_loss: 0.2221 - val_accuracy: 0.9121
# Epoch 30/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.2180 - accuracy: 0.9118 - val_loss: 0.2281 - val_accuracy: 0.9104
# Epoch 31/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.2210 - accuracy: 0.9125 - val_loss: 0.2485 - val_accuracy: 0.8996
# Epoch 32/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.2043 - accuracy: 0.9186 - val_loss: 0.1871 - val_accuracy: 0.9233
# Epoch 33/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.2113 - accuracy: 0.9127 - val_loss: 0.3273 - val_accuracy: 0.8746
# Epoch 34/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.1951 - accuracy: 0.9219 - val_loss: 0.3390 - val_accuracy: 0.8729
# Epoch 35/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.2247 - accuracy: 0.9095 - val_loss: 0.2433 - val_accuracy: 0.9046
# Epoch 36/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.1911 - accuracy: 0.9206 - val_loss: 0.1961 - val_accuracy: 0.9212
# Epoch 37/75
# 150/150 [==============================] - 4s 26ms/step - loss: 0.1987 - accuracy: 0.9186 - val_loss: 0.1934 - val_accuracy: 0.9233
# Epoch 38/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.1903 - accuracy: 0.9248 - val_loss: 0.1704 - val_accuracy: 0.9321
# Epoch 39/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.1582 - accuracy: 0.9354 - val_loss: 0.2622 - val_accuracy: 0.8958
# Epoch 40/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.1819 - accuracy: 0.9269 - val_loss: 0.1601 - val_accuracy: 0.9392
# Epoch 41/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.1878 - accuracy: 0.9253 - val_loss: 0.1601 - val_accuracy: 0.9304
# Epoch 42/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.1525 - accuracy: 0.9421 - val_loss: 0.1809 - val_accuracy: 0.9333
# Epoch 43/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.1465 - accuracy: 0.9433 - val_loss: 0.2599 - val_accuracy: 0.8950
# Epoch 44/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.1887 - accuracy: 0.9242 - val_loss: 0.2319 - val_accuracy: 0.9112
# Epoch 45/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.1390 - accuracy: 0.9430 - val_loss: 0.1519 - val_accuracy: 0.9425
# Epoch 46/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.1599 - accuracy: 0.9352 - val_loss: 0.2700 - val_accuracy: 0.9013
# Epoch 47/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.1702 - accuracy: 0.9348 - val_loss: 0.1413 - val_accuracy: 0.9450
# Epoch 48/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.1498 - accuracy: 0.9434 - val_loss: 0.1385 - val_accuracy: 0.9471
# Epoch 49/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.1348 - accuracy: 0.9478 - val_loss: 0.2002 - val_accuracy: 0.9183
# Epoch 50/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.1704 - accuracy: 0.9333 - val_loss: 0.1676 - val_accuracy: 0.9333
# Epoch 51/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.1583 - accuracy: 0.9354 - val_loss: 0.1532 - val_accuracy: 0.9375
# Epoch 52/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.1288 - accuracy: 0.9493 - val_loss: 0.1398 - val_accuracy: 0.9458
# Epoch 53/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.1149 - accuracy: 0.9567 - val_loss: 0.1522 - val_accuracy: 0.9392
# Epoch 54/75
# 150/150 [==============================] - 4s 26ms/step - loss: 0.1190 - accuracy: 0.9536 - val_loss: 0.1260 - val_accuracy: 0.9508
# Epoch 55/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.1148 - accuracy: 0.9554 - val_loss: 0.1282 - val_accuracy: 0.9517
# Epoch 56/75
# 150/150 [==============================] - 4s 26ms/step - loss: 0.1380 - accuracy: 0.9459 - val_loss: 0.1335 - val_accuracy: 0.9471
# Epoch 57/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.1096 - accuracy: 0.9579 - val_loss: 0.1800 - val_accuracy: 0.9279
# Epoch 58/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.1080 - accuracy: 0.9605 - val_loss: 0.1570 - val_accuracy: 0.9463
# Epoch 59/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.1163 - accuracy: 0.9538 - val_loss: 0.2116 - val_accuracy: 0.9179
# Epoch 60/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.1103 - accuracy: 0.9605 - val_loss: 0.1637 - val_accuracy: 0.9417
# Epoch 61/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.1185 - accuracy: 0.9549 - val_loss: 0.1455 - val_accuracy: 0.9450
# Epoch 62/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.1055 - accuracy: 0.9606 - val_loss: 0.1199 - val_accuracy: 0.9529
# Epoch 63/75
# 150/150 [==============================] - 4s 26ms/step - loss: 0.0978 - accuracy: 0.9642 - val_loss: 0.1325 - val_accuracy: 0.9517
# Epoch 64/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.0934 - accuracy: 0.9624 - val_loss: 0.1435 - val_accuracy: 0.9471
# Epoch 65/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.1148 - accuracy: 0.9525 - val_loss: 0.1729 - val_accuracy: 0.9396
# Epoch 66/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.0981 - accuracy: 0.9616 - val_loss: 0.1107 - val_accuracy: 0.9596
# Epoch 67/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.0905 - accuracy: 0.9678 - val_loss: 0.1115 - val_accuracy: 0.9554
# Epoch 68/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.0971 - accuracy: 0.9639 - val_loss: 0.1195 - val_accuracy: 0.9542
# Epoch 69/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.0861 - accuracy: 0.9677 - val_loss: 0.1444 - val_accuracy: 0.9442
# Epoch 70/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.1010 - accuracy: 0.9644 - val_loss: 0.1208 - val_accuracy: 0.9517
# Epoch 71/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.0985 - accuracy: 0.9626 - val_loss: 0.1362 - val_accuracy: 0.9533
# Epoch 72/75
# 150/150 [==============================] - 4s 26ms/step - loss: 0.0830 - accuracy: 0.9704 - val_loss: 0.1210 - val_accuracy: 0.9558
# Epoch 73/75
# 150/150 [==============================] - 4s 26ms/step - loss: 0.0779 - accuracy: 0.9711 - val_loss: 0.1218 - val_accuracy: 0.9571
# Epoch 74/75
# 150/150 [==============================] - 4s 24ms/step - loss: 0.0868 - accuracy: 0.9672 - val_loss: 0.1065 - val_accuracy: 0.9617
# Epoch 75/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.0741 - accuracy: 0.9716 - val_loss: 0.1221 - val_accuracy: 0.9533
# 75/75 [==============================] - 1s 7ms/step - loss: 0.1221 - accuracy: 0.9533

# %%
# results_list is a list of dictionaries
results_list = []
for i in range(1,6):
    path = "../input/hurricane-alex-normal-cv/normal_fold_" + str(i) + ".csv"
    results_list.append(input_csv(path))

# results_dict is a dictionary of lists
results_dict = {}
results_dict["accuracy"] = [(float)(i["accuracy"]) for i in results_list]
results_dict["TPR/Recall"] = [(float)(i["TPR/Recall"]) for i in results_list]
results_dict["TNR/Specificity"] = [(float)(i["TNR/Specificity"]) for i in results_list]
results_dict["PPV/Precision"] = [(float)(i["PPV/Precision"]) for i in results_list]
results_dict["NPV"] = [(float)(i["NPV"]) for i in results_list]

print_confusion_matrix_results(results_dict)

# %%
# find confusion matrices
results_dict["tn"] = [(int)(i["tn"]) for i in results_list]
results_dict["fp"] = [(int)(i["fp"]) for i in results_list]
results_dict["fn"] = [(int)(i["fn"]) for i in results_list]
results_dict["tp"] = [(int)(i["tp"]) for i in results_list]
results_dict["confusion_matrix"] = []
# append confusion matrix for each cross-validation fold
for i in range(len(folds)):
    results_dict["confusion_matrix"].append(find_confusion_matrix_2(results_dict["tn"][i], results_dict["fp"][i], results_dict["fn"][i], results_dict["tp"][i]))
                                            
# total confusion matrix summed together
confusion_matrix_list = []
confusion_matrix_list = results_dict["confusion_matrix"]
confusion_matrix_comb = np.sum(confusion_matrix_list, axis=0)
heatmap(confusion_matrix_comb)

# %%
# normalized confusion matrix
confusion_matrix_norm = normalize_confusion_matrix(confusion_matrix_comb)
heatmap(confusion_matrix_norm)

# %% [markdown]
# ## Train Data with Batch Normalization

# %%
def train_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model_batch_normalization(learning_rate)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=10, verbose=1)
  # fit model
  history = model.fit(X_train, y_train, epochs=epochs, batch_size=64, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %% [markdown]
# ### Train Data with Batch Normalization and Cross Validation

# %%
def benchmark_model_batch_normalization(X_all, y_all, split):
    X_train_cv, y_train_cv = X_all[split[0]], y_all[split[0]]
    X_val_cv, y_val_cv = X_all[split[1]], y_all[split[1]]
    model, accuracy = train_batch_normalization(X_train_cv, X_val_cv, X_val_cv, y_train_cv, y_val_cv, y_val_cv, 0.001, 75) 
    results = {}
    results["model"] = model
    results["accuracy"] = accuracy
    results["confusion_matrix"] = find_confusion_matrix(model, X_val_cv, y_val_cv)
    tn, fp, fn, tp = results["confusion_matrix"].ravel()
    results["tn"] = tn
    results["fp"] = fp
    results["fn"] = fn
    results["tp"] = tp
    results["TPR/Recall"] = tp/(tp+fn)
    results["TNR/Specificity"] = tn/(tn+fp)
    results["PPV/Precision"] = tp/(tp+fp)
    results["NPV"] = tn/(tn+fn)
    return results

# %%
kf = KFold(n_splits=5)
folds = list(kf.split(X_all, y_all))

# %%
output_as_csv("batch normalization fold 1", benchmark_model_batch_normalization(X_all, y_all, folds[0]))

# %%
output_as_csv("batch normalization fold 2", benchmark_model_batch_normalization(X_all, y_all, folds[1]))

# %%
output_as_csv("batch normalization fold 3", benchmark_model_batch_normalization(X_all, y_all, folds[2]))

# %%
output_as_csv("batch normalization fold 4", benchmark_model_batch_normalization(X_all, y_all, folds[3]))

# %%
output_as_csv("batch normalization fold 5", benchmark_model_batch_normalization(X_all, y_all, folds[4]))

# %%
# results_list is a list of dictionaries
results_list = []
for i in range(1,6):
    path = "../input/hurricane-alex-batch-cv/batch normalization fold " + str(i) + ".csv"
    results_list.append(input_csv(path))

# results_dict is a dictionary of lists
results_dict = {}
results_dict["accuracy"] = [(float)(i["accuracy"]) for i in results_list]
results_dict["TPR/Recall"] = [(float)(i["TPR/Recall"]) for i in results_list]
results_dict["TNR/Specificity"] = [(float)(i["TNR/Specificity"]) for i in results_list]
results_dict["PPV/Precision"] = [(float)(i["PPV/Precision"]) for i in results_list]
results_dict["NPV"] = [(float)(i["NPV"]) for i in results_list]

print_confusion_matrix_results(results_dict)

# %%
# find confusion matrices
results_dict["tn"] = [(int)(i["tn"]) for i in results_list]
results_dict["fp"] = [(int)(i["fp"]) for i in results_list]
results_dict["fn"] = [(int)(i["fn"]) for i in results_list]
results_dict["tp"] = [(int)(i["tp"]) for i in results_list]
results_dict["confusion_matrix"] = []
# append confusion matrix for each cross-validation fold
for i in range(len(folds)):
    results_dict["confusion_matrix"].append(find_confusion_matrix_2(results_dict["tn"][i], results_dict["fp"][i], results_dict["fn"][i], results_dict["tp"][i]))
                                            
# total confusion matrix summed together
confusion_matrix_list = []
confusion_matrix_list = results_dict["confusion_matrix"]
confusion_matrix_comb = np.sum(confusion_matrix_list, axis=0)
heatmap(confusion_matrix_comb)

# %%
# normalized confusion matrix
confusion_matrix_norm = normalize_confusion_matrix(confusion_matrix_comb)
heatmap(confusion_matrix_norm)

# %% [markdown]
# ## Train Data with Data Augmentation

# %%
def train_data_augmentation(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model(learning_rate)
  # create data generator
  datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
  # prepare iterator
  it_train = datagen.flow(X_train, y_train, batch_size=64)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=10, verbose=1)
	# fit model
  steps = int(X_train.shape[0] / 64)
  history = model.fit(it_train, epochs=epochs, steps_per_epoch=steps, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_data, accuracy = train_data_augmentation(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 75)
print(accuracy)
y_pred = model_test_data.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_data, accuracy = train_data_augmentation(X_train, X_val, X_test, y_train, y_val, y_test, 1e-5, 75)
print(accuracy)
y_pred = model_test_data.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_data, accuracy = train_data_augmentation(X_train, X_val, X_test, y_train, y_val, y_test, 1e-6, 75)
print(accuracy)
y_pred = model_test_data.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))=
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_data, accuracy = train_data_augmentation(X_train, X_val, X_test, y_train, y_val, y_test, 5e-6, 75)
print(accuracy)
y_pred = model_test_data.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_data, accuracy = train_data_augmentation(X_train, X_val, X_test, y_train, y_val, y_test, 8e-6, 75)
print(accuracy)
y_pred = model_test_data.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %% [markdown]
# ## Train Data with Weight Regularization

# %%
def train_data_weight(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model_weight_regularization(learning_rate)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
  # fit model
  history = model.fit(X_train, y_train, epochs=epochs, batch_size=64, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_weight, accuracy = train_data_weight(X_train, X_val, X_test, y_train, y_val, y_test, 1e-5, 75)
print(accuracy)
y_pred = model_test_weight.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_weight, accuracy = train_data_weight(X_train, X_val, X_test, y_train, y_val, y_test, 1e-6, 75)
print(accuracy)
y_pred = model_test_weight.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_weight, accuracy = train_data_weight(X_train, X_val, X_test, y_train, y_val, y_test, 5e-5, 75)
print(accuracy)
y_pred = model_test_weight.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_weight, accuracy = train_data_weight(X_train, X_val, X_test, y_train, y_val, y_test, 1e-5, 75)
print(accuracy)
y_pred = model_test_weight.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_weight, accuracy = train_data_weight(X_train, X_val, X_test, y_train, y_val, y_test, 2e-5, 75)
print(accuracy)
y_pred = model_test_weight.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %% [markdown]
# ### Train Data with Data Augmentation and Weight Regularization

# %%
def train_data_augmentation_weight(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model_weight_regularization(learning_rate)
  # create data generator
  datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
  # prepare iterator
  it_train = datagen.flow(X_train, y_train, batch_size=64)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
	# fit model  
  steps = int(X_train.shape[0] / 64)
  history = model.fit(it_train, epochs=epochs, steps_per_epoch=steps, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_data_weight, accuracy = train_data_augmentation_weight(X_train, X_val, X_test, y_train, y_val, y_test, 1e-5, 75)
print(accuracy)
y_pred = model_test_data_weight.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_data_weight, accuracy = train_data_augmentation_weight(X_train, X_val, X_test, y_train, y_val, y_test, 1e-6, 75)
print(accuracy)
y_pred = model_test_data_weight.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_data_weight, accuracy = train_data_augmentation_weight(X_train, X_val, X_test, y_train, y_val, y_test, 5e-5, 75)
print(accuracy)
y_pred = model_test_data_weight.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_data_weight, accuracy = train_data_augmentation_weight(X_train, X_val, X_test, y_train, y_val, y_test, 5e-6, 75)
print(accuracy)
y_pred = model_test_data_weight.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))
