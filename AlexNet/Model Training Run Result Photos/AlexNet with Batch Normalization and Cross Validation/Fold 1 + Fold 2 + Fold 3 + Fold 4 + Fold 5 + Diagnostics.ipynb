# %% [markdown]
# # Imports

# %%
import numpy as np
import glob
from PIL import Image
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from tensorflow.keras import optimizers
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import KFold
import pandas as pd
import seaborn as sn
sn.set(font_scale=1.4) # for label size
import multiprocessing as mp
import csv

# %% [markdown]
# # Load DataSet
#
# 0 means unlikely to have flood damage, 1 means likely to have flood damage
#
# [0,1] --> damage
#
# [1,0] --> no damage

# %% [markdown]
# ## Load Training Set

# %%
images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/train_another/damage/*.jpeg')
dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  dmg_img.append(im_arr)
dmg_img = np.array(dmg_img)

images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/train_another/no_damage/*.jpeg')
no_dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  no_dmg_img.append(im_arr)
no_dmg_img = np.array(no_dmg_img)

X_train = np.concatenate((dmg_img, no_dmg_img))
dmg_img_y = np.array(dmg_img.shape[0] * [[0,1]])
no_dmg_img_y = np.array(no_dmg_img.shape[0] * [[1,0]])
y_train = np.concatenate((dmg_img_y, no_dmg_img_y))

# shuffle arrays so that the array is a mix of damage and no_damage in a random order
shuffler = np.random.permutation(X_train.shape[0])
X_train = X_train[shuffler]
y_train = y_train[shuffler]

# %% [markdown]
# ## Load Validation Set

# %%
images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/validation_another/damage/*.jpeg')
dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  dmg_img.append(im_arr)
dmg_img = np.array(dmg_img)

images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/validation_another/no_damage/*.jpeg')
no_dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  no_dmg_img.append(im_arr)
no_dmg_img = np.array(no_dmg_img)

X_val = np.concatenate((dmg_img, no_dmg_img))
dmg_img_y = np.array(dmg_img.shape[0] * [[0,1]])
no_dmg_img_y = np.array(no_dmg_img.shape[0] * [[1,0]])
y_val = np.concatenate((dmg_img_y, no_dmg_img_y))

# shuffle arrays so that the array is a mix of damage and no_damage in a random order
shuffler = np.random.permutation(X_val.shape[0])
X_val = X_val[shuffler]
y_val = y_val[shuffler]

# %%
# combine training and validation data - for cross-validation
X_all = np.concatenate((X_train, X_val))
y_all = np.concatenate((y_train, y_val))

# %% [markdown]
# ## Load Test Set

# %%
images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/test/damage/*.jpeg')
dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  dmg_img.append(im_arr)
dmg_img = np.array(dmg_img)

images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/test/no_damage/*.jpeg')
no_dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  no_dmg_img.append(im_arr)
no_dmg_img = np.array(no_dmg_img)

X_test = np.concatenate((dmg_img, no_dmg_img))
dmg_img_y = np.array(dmg_img.shape[0] * [[0,1]])
no_dmg_img_y = np.array(no_dmg_img.shape[0] * [[1,0]])
y_test = np.concatenate((dmg_img_y, no_dmg_img_y))

# shuffle arrays so that the array is a mix of damage and no_damage in a random order
shuffler = np.random.permutation(X_val.shape[0])
X_test = X_test[shuffler]
y_test = y_test[shuffler]

# %% [markdown]
# ## Input/Output

# %%
# save a dictionary as a csv file
def output_as_csv(name, a):
    path = "/kaggle/working/" + name + ".csv"
    with open(path, 'w') as csv_file:
        # create the csv writer
        writer = csv.writer(csv_file)

        # write a row to the csv file
        writer.writerow(a.keys())
        writer.writerow(a.values())

# input a csv file
def input_csv(path):
    b, keys = {}, {}
    with open(path, mode='r') as csv_file:
        csv_reader = csv.DictReader(csv_file)
        line_count = 0
        for row in csv_reader:
            keys = row
    b = dict(keys)
    return b # returns a dictionary

# %% [markdown]
# # Pre-Process DataSet

# %%
# pre-process data 
def scale_pixels(train, val, test, X_all):
	# convert from integers to floats and normalize between 0-1
  train_norm = train.astype('float32') / 255.0
  val_norm = val.astype('float32') / 255.0
  test_norm = test.astype('float32') / 255.0
  X_all_norm = X_all.astype('float32') / 255.0
	# return normalized images
  return train_norm, val_norm, test_norm, X_all_norm

X_train, X_val, X_test, X_all = scale_pixels(X_train, X_val, X_test, X_all)

# %% [markdown]
# # Plot Diagnostics

# %%
# plot diagnostic learning curves
def summarize_diagnostics(history):
  # blue = training data; orange = validation data
	# plot validation loss
	plt.subplot(211)
	plt.title('Cross Entropy Loss')
	plt.plot(history.history['loss'], color='blue', label='train')
	plt.plot(history.history['val_loss'], color='orange', label='validation')
	# plot accuracy
	plt.subplot(212)
	plt.title('Classification Accuracy')
	plt.plot(history.history['accuracy'], color='blue', label='train')
	plt.plot(history.history['val_accuracy'], color='orange', label='validation')

# %%
# returns the confusion matrix
def find_confusion_matrix(model, X_test, y_test):
    y_pred = model.predict(X_test)
    y_pred_val = y_pred.argmax(axis=1)
    y_test_val = y_test.argmax(axis=1)
    return confusion_matrix(y_test_val, y_pred_val)

# returns the confusion matrix based on tn, fn, fp, tp
def find_confusion_matrix_2(tn, fn, fp, tp):
    return [[tn, fp], [fn, tp]]

# generate heat map for confusion matrix
def heatmap(confusion_matrix):
    df = pd.DataFrame(confusion_matrix, index = ['F', 'T'], columns = ['F', 'T'])
    sn.heatmap(df, annot=True) # create a heatmap
    
# returns normalized confusion matrix
def normalize_confusion_matrix(confusion_matrix):
    confusion_matrix = np.array(confusion_matrix)
    confusion_matrix_sum = confusion_matrix.astype(np.float).sum(axis=1)
    confusion_matrix_norm = confusion_matrix.astype(np.float)
    confusion_matrix_norm[0] = confusion_matrix_norm[0] / confusion_matrix_sum[0]
    confusion_matrix_norm[1] = confusion_matrix_norm[1] / confusion_matrix_sum[1]
    return confusion_matrix_norm

def print_confusion_matrix_results(results):
    # results is a dictionary
    # calculate mean and standard deviation for each key
    for key in results:
        mean = np.mean(results[key])
        std = np.std(results[key])
        print("{} mean: {}".format(key, mean))
        print("{} std: {}".format(key, std))

# %% [markdown]
# # Create CNN Model

# %%
# define cnn model
def define_model(learning_rate):
  model = keras.Sequential()
  model.add(layers.Conv2D(filters=96, input_shape=(128,128,3), kernel_size=(11,11), strides=(4,4), activation='relu', padding='same'))
  model.add(layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)))
  model.add(layers.Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), activation='relu', padding="same"))
  model.add(layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)))
  model.add(layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"))
  model.add(layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"))
  model.add(layers.Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"))
  model.add(layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)))
  model.add(layers.Flatten())
  model.add(layers.Dense(4096, activation='relu'))
  model.add(layers.Dropout(0.5))
  model.add(layers.Dense(4096, activation='relu'))
  model.add(layers.Dropout(0.5))
  model.add(layers.Dense(2, activation='softmax'))  # compile model
  opt = optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
  model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
  return model

# %% [markdown]
# ## CNN Model with Batch Normalization

# %%
# define cnn model
def define_model_batch_normalization(learning_rate):
  model = keras.Sequential()
  model.add(layers.Conv2D(filters=96, input_shape=(128,128,3), kernel_size=(11,11), strides=(4,4), activation='relu', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)))
  model.add(layers.Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), activation='relu', padding="same"))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)))
  model.add(layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)))
  model.add(layers.Flatten())
  model.add(layers.Dense(4096, activation='relu'))
  model.add(layers.Dropout(0.5))
  model.add(layers.Dense(4096, activation='relu'))
  model.add(layers.Dropout(0.5))
  model.add(layers.Dense(2, activation='softmax'))  # compile model
  opt = optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
  model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
  return model

# %% [markdown]
# ## CNN Model with Batch Normalization and Weight Regularization

# %%
# define cnn model
def define_model_weight_regularization_batch_normalization(learning_rate):
  model = keras.Sequential()
  model.add(layers.Conv2D(filters=96, input_shape=(128,128,3), kernel_size=(11,11), strides=(4,4), activation='relu', kernel_regularizer=regularizers.l2(0.01), padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)))
  model.add(layers.Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), activation='relu', kernel_regularizer=regularizers.l2(0.01), padding="same"))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)))
  model.add(layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', kernel_regularizer=regularizers.l2(0.01), padding="same"))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', kernel_regularizer=regularizers.l2(0.01), padding="same"))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', kernel_regularizer=regularizers.l2(0.01), padding="same"))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)))
  model.add(layers.Flatten())
  model.add(layers.Dense(4096, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.Dropout(0.5))
  model.add(layers.Dense(4096, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.Dropout(0.5))
  model.add(layers.Dense(2, activation='softmax'))  # compile model
  opt = optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
  model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
  return model

# %%
# define cnn model
def define_model_weight_regularization_batch_normalization2(learning_rate, regularization_lambda):
  model = keras.Sequential()
  model.add(layers.Conv2D(filters=96, input_shape=(128,128,3), kernel_size=(11,11), strides=(4,4), activation='relu', kernel_regularizer=regularizers.l2(regularization_lambda), padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)))
  model.add(layers.Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), activation='relu', kernel_regularizer=regularizers.l2(regularization_lambda), padding="same"))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)))
  model.add(layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', kernel_regularizer=regularizers.l2(regularization_lambda), padding="same"))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', kernel_regularizer=regularizers.l2(regularization_lambda), padding="same"))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', kernel_regularizer=regularizers.l2(regularization_lambda), padding="same"))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)))
  model.add(layers.Flatten())
  model.add(layers.Dense(4096, activation='relu', kernel_regularizer=regularizers.l2(regularization_lambda)))
  model.add(layers.Dropout(0.5))
  model.add(layers.Dense(4096, activation='relu', kernel_regularizer=regularizers.l2(regularization_lambda)))
  model.add(layers.Dropout(0.5))
  model.add(layers.Dense(2, activation='softmax'))  # compile model
  opt = optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
  model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
  return model

# %% [markdown]
# # Train Data
# Hyperparameters are inputted into the function

# %%
def train(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model(learning_rate)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=10, verbose=1)
  # fit model
  history = model.fit(X_train, y_train, epochs=epochs, batch_size=64, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test, accuracy = train(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 75)
print(accuracy)
y_pred = model_test.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test, accuracy = train(X_train, X_val, X_test, y_train, y_val, y_test, 1e-4, 75)
print(accuracy)
y_pred = model_test.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test, accuracy = train(X_train, X_val, X_test, y_train, y_val, y_test,1e-5, 75)
print(accuracy)
y_pred = model_test.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test, accuracy = train(X_train, X_val, X_test, y_train, y_val, y_test,1e-6, 75)
print(accuracy)
y_pred = model_test.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test, accuracy = train(X_train, X_val, X_test, y_train, y_val, y_test,5e-5, 75)
print(accuracy)
y_pred = model_test.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %% [markdown]
# ## Train Data w/ Cross Validation

# %%
def benchmark_model(X_all, y_all, split):
    X_train_cv, y_train_cv = X_all[split[0]], y_all[split[0]]
    X_val_cv, y_val_cv = X_all[split[1]], y_all[split[1]]
    model, accuracy = train(X_train_cv, X_val_cv, X_val_cv, y_train_cv, y_val_cv, y_val_cv, 0.001, 75) 
    results = {}
#     results["model"] = model
    results["accuracy"] = accuracy
    results["confusion_matrix"] = find_confusion_matrix(model, X_val_cv, y_val_cv)
    tn, fp, fn, tp = results["confusion_matrix"].ravel()
    results["tn"] = tn
    results["fp"] = fp
    results["fn"] = fn
    results["tp"] = tp
    results["TPR/Recall"] = tp/(tp+fn)
    results["TNR/Specificity"] = tn/(tn+fp)
    results["PPV/Precision"] = tp/(tp+fp)
    results["NPV"] = tn/(tn+fn)
    return results

# %%
kf = KFold(n_splits=5)
folds = list(kf.split(X_all, y_all))

# %%
output_as_csv("normal_fold_1", benchmark_model(X_all, y_all, folds[0]))

# %%
output_as_csv("normal_fold_2", benchmark_model(X_all, y_all, folds[1]))

# %%
output_as_csv("normal_fold_3", benchmark_model(X_all, y_all, folds[2]))

# %%
output_as_csv("normal_fold_4", benchmark_model(X_all, y_all, folds[3]))

# %%
output_as_csv("normal_fold_5", benchmark_model(X_all, y_all, folds[4]))

# %%
# results_list is a list of dictionaries
results_list = []
for i in range(1,6):
    path = "../input/hurricane-alex-normal-cv/normal_fold_" + str(i) + ".csv"
    results_list.append(input_csv(path))

# results_dict is a dictionary of lists
results_dict = {}
results_dict["accuracy"] = [(float)(i["accuracy"]) for i in results_list]
results_dict["TPR/Recall"] = [(float)(i["TPR/Recall"]) for i in results_list]
results_dict["TNR/Specificity"] = [(float)(i["TNR/Specificity"]) for i in results_list]
results_dict["PPV/Precision"] = [(float)(i["PPV/Precision"]) for i in results_list]
results_dict["NPV"] = [(float)(i["NPV"]) for i in results_list]

print_confusion_matrix_results(results_dict)
# Out:
# accuracy mean: 0.9542500019073487
# accuracy std: 0.006430170734532239
# TPR/Recall mean: 0.9403461131912035
# TPR/Recall std: 0.015092252939317076
# TNR/Specificity mean: 0.9686053175524181
# TNR/Specificity std: 0.00839520266659357
# PPV/Precision mean: 0.9689078009906668
# PPV/Precision std: 0.00788802463827813
# NPV mean: 0.9403535399338547
# NPV std: 0.013694810740063196

# %%
# find confusion matrices
results_dict["tn"] = [(int)(i["tn"]) for i in results_list]
results_dict["fp"] = [(int)(i["fp"]) for i in results_list]
results_dict["fn"] = [(int)(i["fn"]) for i in results_list]
results_dict["tp"] = [(int)(i["tp"]) for i in results_list]
results_dict["confusion_matrix"] = []
# append confusion matrix for each cross-validation fold
for i in range(len(folds)):
    results_dict["confusion_matrix"].append(find_confusion_matrix_2(results_dict["tn"][i], results_dict["fp"][i], results_dict["fn"][i], results_dict["tp"][i]))
                                            
# total confusion matrix summed together
confusion_matrix_list = []
confusion_matrix_list = results_dict["confusion_matrix"]
confusion_matrix_comb = np.sum(confusion_matrix_list, axis=0)
heatmap(confusion_matrix_comb)

# %%
# normalized confusion matrix
confusion_matrix_norm = normalize_confusion_matrix(confusion_matrix_comb)
heatmap(confusion_matrix_norm)

# %% [markdown]
# ## Train Data with Batch Normalization

# %%
def train_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model_batch_normalization(learning_rate)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=10, verbose=1)
  # fit model
  history = model.fit(X_train, y_train, epochs=epochs, batch_size=64, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_batch_normalization, accuracy = train_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, 0.0001, 75)
print(accuracy)
y_pred = model_test_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %% [markdown]
# ### Train Data with Batch Normalization and Cross Validation

# %%
def benchmark_model_batch_normalization(X_all, y_all, split):
    X_train_cv, y_train_cv = X_all[split[0]], y_all[split[0]]
    X_val_cv, y_val_cv = X_all[split[1]], y_all[split[1]]
    model, accuracy = train_batch_normalization(X_train_cv, X_val_cv, X_val_cv, y_train_cv, y_val_cv, y_val_cv, 1e-5, 200) 
    results = {}
    results["model"] = model
    results["accuracy"] = accuracy
    results["confusion_matrix"] = find_confusion_matrix(model, X_val_cv, y_val_cv)
    tn, fp, fn, tp = results["confusion_matrix"].ravel()
    results["tn"] = tn
    results["fp"] = fp
    results["fn"] = fn
    results["tp"] = tp
    results["TPR/Recall"] = tp/(tp+fn)
    results["TNR/Specificity"] = tn/(tn+fp)
    results["PPV/Precision"] = tp/(tp+fp)
    results["NPV"] = tn/(tn+fn)
    return results

# %%
kf = KFold(n_splits=5)
folds = list(kf.split(X_all, y_all))

# %%
output_as_csv("batch normalization fold 1", benchmark_model_batch_normalization(X_all, y_all, folds[0]))
# Out:
# Epoch 1/75
# 150/150 [==============================] - 12s 33ms/step - loss: 0.9815 - accuracy: 0.5376 - val_loss: 0.6927 - val_accuracy: 0.5013
# Epoch 2/75
# 150/150 [==============================] - 4s 27ms/step - loss: 0.8109 - accuracy: 0.6476 - val_loss: 0.7195 - val_accuracy: 0.5008
# Epoch 3/75
# 150/150 [==============================] - 4s 26ms/step - loss: 0.7483 - accuracy: 0.6923 - val_loss: 0.7493 - val_accuracy: 0.5033
# Epoch 4/75
# 150/150 [==============================] - 4s 26ms/step - loss: 0.6689 - accuracy: 0.7403 - val_loss: 0.7028 - val_accuracy: 0.5713
# Epoch 5/75
# 150/150 [==============================] - 4s 26ms/step - loss: 0.6180 - accuracy: 0.7731 - val_loss: 0.4601 - val_accuracy: 0.7862
# Epoch 6/75
# 150/150 [==============================] - 4s 26ms/step - loss: 0.5888 - accuracy: 0.7916 - val_loss: 0.4581 - val_accuracy: 0.7987
# Epoch 7/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.5286 - accuracy: 0.8189 - val_loss: 0.3794 - val_accuracy: 0.8554
# Epoch 8/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.4875 - accuracy: 0.8314 - val_loss: 0.3643 - val_accuracy: 0.8621
# Epoch 9/75
# 150/150 [==============================] - 4s 27ms/step - loss: 0.4846 - accuracy: 0.8349 - val_loss: 0.3912 - val_accuracy: 0.8542
# Epoch 10/75
# 150/150 [==============================] - 4s 27ms/step - loss: 0.4665 - accuracy: 0.8433 - val_loss: 0.3501 - val_accuracy: 0.8679
# Epoch 11/75
# 150/150 [==============================] - 4s 26ms/step - loss: 0.4366 - accuracy: 0.8567 - val_loss: 0.3310 - val_accuracy: 0.8754
# Epoch 12/75
# 150/150 [==============================] - 4s 26ms/step - loss: 0.4280 - accuracy: 0.8597 - val_loss: 0.4974 - val_accuracy: 0.8004
# Epoch 13/75
# 150/150 [==============================] - 4s 26ms/step - loss: 0.4156 - accuracy: 0.8643 - val_loss: 0.3272 - val_accuracy: 0.8800
# Epoch 14/75
# 150/150 [==============================] - 4s 26ms/step - loss: 0.3914 - accuracy: 0.8712 - val_loss: 0.3627 - val_accuracy: 0.8763
# Epoch 15/75
# 150/150 [==============================] - 4s 26ms/step - loss: 0.3754 - accuracy: 0.8757 - val_loss: 0.3029 - val_accuracy: 0.8871
# Epoch 16/75
# 150/150 [==============================] - 4s 26ms/step - loss: 0.3767 - accuracy: 0.8784 - val_loss: 0.2935 - val_accuracy: 0.8871
# Epoch 17/75
# 150/150 [==============================] - 4s 26ms/step - loss: 0.3576 - accuracy: 0.8860 - val_loss: 0.3459 - val_accuracy: 0.8758
# Epoch 18/75
# 150/150 [==============================] - 4s 27ms/step - loss: 0.3538 - accuracy: 0.8822 - val_loss: 0.3166 - val_accuracy: 0.8833
# Epoch 19/75
# 150/150 [==============================] - 4s 26ms/step - loss: 0.3528 - accuracy: 0.8901 - val_loss: 0.2783 - val_accuracy: 0.8896
# Epoch 20/75
# 150/150 [==============================] - 4s 26ms/step - loss: 0.3334 - accuracy: 0.8856 - val_loss: 0.2734 - val_accuracy: 0.8929
# Epoch 21/75
# 150/150 [==============================] - 4s 25ms/step - loss: 0.3226 - accuracy: 0.8896 - val_loss: 0.2785 - val_accuracy: 0.8892
# Epoch 22/75
# 150/150 [==============================] - 4s 26ms/step - loss: 0.3295 - accuracy: 0.8923 - val_loss: 0.3287 - val_accuracy: 0.8833
# Epoch 23/75
# 150/150 [==============================] - 4s 26ms/step - loss: 0.
200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.1533 - accuracy: 0.9484 - val_loss: 0.6387 - val_accuracy: 0.7433
# Epoch 67/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.1554 - accuracy: 0.9454 - val_loss: 0.1626 - val_accuracy: 0.9433
# Epoch 68/200
# 150/150 [==============================] - 4s 27ms/step - loss: 0.1542 - accuracy: 0.9467 - val_loss: 0.1475 - val_accuracy: 0.9471
# Epoch 69/200
# 150/150 [==============================] - 4s 27ms/step - loss: 0.1502 - accuracy: 0.9480 - val_loss: 0.1609 - val_accuracy: 0.9408
# Epoch 70/200
# 150/150 [==============================] - 4s 28ms/step - loss: 0.1477 - accuracy: 0.9498 - val_loss: 0.2410 - val_accuracy: 0.9137
# Epoch 71/200
# 150/150 [==============================] - 4s 27ms/step - loss: 0.1484 - accuracy: 0.9466 - val_loss: 0.1511 - val_accuracy: 0.9479
# Epoch 00071: early stopping
# 75/75 [==============================] - 1s 7ms/step - loss: 0.1511 - accuracy: 0.9479

# %%
output_as_csv("batch normalization fold 3", benchmark_model_batch_normalization(X_all, y_all, folds[2]))
# Out:
# Epoch 1/200
# 150/150 [==============================] - 12s 33ms/step - loss: 0.9681 - accuracy: 0.5520 - val_loss: 0.6936 - val_accuracy: 0.5100
# Epoch 2/200
# 150/150 [==============================] - 4s 28ms/step - loss: 0.8118 - accuracy: 0.6447 - val_loss: 0.7112 - val_accuracy: 0.5096
# Epoch 3/200
# 150/150 [==============================] - 4s 27ms/step - loss: 0.7340 - accuracy: 0.6962 - val_loss: 0.7898 - val_accuracy: 0.5104
# Epoch 4/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.6520 - accuracy: 0.7444 - val_loss: 0.5765 - val_accuracy: 0.6467
# Epoch 5/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.5955 - accuracy: 0.7806 - val_loss: 0.4124 - val_accuracy: 0.8400
# Epoch 6/200
# 150/150 [==============================] - 4s 27ms/step - loss: 0.5436 - accuracy: 0.8031 - val_loss: 0.3729 - val_accuracy: 0.8575
# Epoch 7/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.5402 - accuracy: 0.8150 - val_loss: 0.3485 - val_accuracy: 0.8704
# Epoch 8/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.4870 - accuracy: 0.8348 - val_loss: 0.3369 - val_accuracy: 0.8788
# Epoch 9/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.4528 - accuracy: 0.8443 - val_loss: 0.3237 - val_accuracy: 0.8767
# Epoch 10/200
# 150/150 [==============================] - 4s 27ms/step - loss: 0.4718 - accuracy: 0.8417 - val_loss: 0.3212 - val_accuracy: 0.8825
# Epoch 11/200
# 150/150 [==============================] - 4s 25ms/step - loss: 0.4484 - accuracy: 0.8499 - val_loss: 0.4398 - val_accuracy: 0.8192
# Epoch 12/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.4163 - accuracy: 0.8613 - val_loss: 0.3403 - val_accuracy: 0.8758
# Epoch 13/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.4003 - accuracy: 0.8664 - val_loss: 0.3072 - val_accuracy: 0.8850
# Epoch 14/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.4044 - accuracy: 0.8635 - val_loss: 0.2931 - val_accuracy: 0.8896
# Epoch 15/200
# 150/150 [==============================] - 4s 27ms/step - loss: 0.3795 - accuracy: 0.8754 - val_loss: 0.3028 - val_accuracy: 0.8850
# Epoch 16/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.3681 - accuracy: 0.8833 - val_loss: 0.3859 - val_accuracy: 0.8512
# Epoch 17/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.3721 - accuracy: 0.8778 - val_loss: 0.3002 - val_accuracy: 0.8850
# Epoch 18/200
# 150/150 [==============================] - 4s 27ms/step - loss: 0.3533 - accuracy: 0.8832 - val_loss: 0.2874 - val_accuracy: 0.8913
# Epoch 19/200
# 150/150 [==============================] - 4s 25ms/step - loss: 0.3268 - accuracy: 0.8906 - val_loss: 0.2674 - val_accuracy: 0.8942
# Epoch 20/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.3335 - accuracy: 0.8900 - val_loss: 0.2829 - val_accuracy: 0.8929
# Epoch 21/200
# 150/150 [==============================] - 4s 25ms/step - loss: 0.3210 - accuracy: 0.8965 - val_loss: 0.2497 - val_accuracy: 0.9021
# Epoch 22/200
# 150/150 [==============================] - 4s 25ms/step - loss: 0
200
# 150/150 [==============================] - 4s 27ms/step - loss: 0.1279 - accuracy: 0.9547 - val_loss: 0.1265 - val_accuracy: 0.9483
# Epoch 84/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.1288 - accuracy: 0.9554 - val_loss: 0.4292 - val_accuracy: 0.8558
# Epoch 85/200
# 150/150 [==============================] - 4s 27ms/step - loss: 0.1118 - accuracy: 0.9624 - val_loss: 0.1690 - val_accuracy: 0.9362
# Epoch 86/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.1198 - accuracy: 0.9587 - val_loss: 0.1553 - val_accuracy: 0.9421
# Epoch 87/200
# 150/150 [==============================] - 4s 27ms/step - loss: 0.1228 - accuracy: 0.9578 - val_loss: 0.1455 - val_accuracy: 0.9446
# Epoch 88/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.1128 - accuracy: 0.9640 - val_loss: 0.3284 - val_accuracy: 0.8637
# Epoch 89/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.1107 - accuracy: 0.9607 - val_loss: 0.6054 - val_accuracy: 0.8058
# Epoch 90/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.1062 - accuracy: 0.9657 - val_loss: 0.1232 - val_accuracy: 0.9504
# Epoch 91/200
# 150/150 [==============================] - 4s 27ms/step - loss: 0.1179 - accuracy: 0.9610 - val_loss: 0.1464 - val_accuracy: 0.9400
# Epoch 92/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.1085 - accuracy: 0.9615 - val_loss: 0.2405 - val_accuracy: 0.9154
# Epoch 93/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.1076 - accuracy: 0.9628 - val_loss: 0.5669 - val_accuracy: 0.8083
# Epoch 94/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.1189 - accuracy: 0.9626 - val_loss: 0.1387 - val_accuracy: 0.9442
# Epoch 95/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.1044 - accuracy: 0.9644 - val_loss: 0.1136 - val_accuracy: 0.9479
# Epoch 96/200
# 150/150 [==============================] - 4s 27ms/step - loss: 0.0984 - accuracy: 0.9683 - val_loss: 0.1210 - val_accuracy: 0.9517
# Epoch 97/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.1173 - accuracy: 0.9625 - val_loss: 0.1407 - val_accuracy: 0.9458
# Epoch 98/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.1100 - accuracy: 0.9630 - val_loss: 0.1288 - val_accuracy: 0.9483
# Epoch 99/200
# 150/150 [==============================] - 4s 27ms/step - loss: 0.1009 - accuracy: 0.9682 - val_loss: 0.1679 - val_accuracy: 0.9342
# Epoch 100/200
# 150/150 [==============================] - 4s 27ms/step - loss: 0.1013 - accuracy: 0.9681 - val_loss: 0.1541 - val_accuracy: 0.9450
# Epoch 101/200
# 150/150 [==============================] - 4s 27ms/step - loss: 0.1082 - accuracy: 0.9624 - val_loss: 0.2713 - val_accuracy: 0.8979
# Epoch 102/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.0998 - accuracy: 0.9672 - val_loss: 0.1766 - val_accuracy: 0.9367
# Epoch 103/200
# 150/150 [==============================] - 4s 25ms/step - loss: 0.1090 - accuracy: 0.9650 - val_loss: 0.1138 - val_accuracy: 0.9525
# Epoch 104/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.0987 - accuracy: 0.9648 - val_loss: 0.1410 - val_accuracy: 0.9529
# Epoch 105/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.0935 - accuracy: 0.9715 - val_loss: 0.2706 - val_accuracy: 0.8996
# Epoch 00105: early stopping
# 75/75 [==============================] - 1s 7ms/step - loss: 0.2706 - accuracy: 0.8996

# %%
output_as_csv("batch normalization fold 4", benchmark_model_batch_normalization(X_all, y_all, folds[3]))
# Out:
# Epoch 1/200
# 150/150 [==============================] - 12s 34ms/step - loss: 0.9664 - accuracy: 0.5364 - val_loss: 0.6933 - val_accuracy: 0.5437
# Epoch 2/200
# 150/150 [==============================] - 4s 25ms/step - loss: 0.8036 - accuracy: 0.6452 - val_loss: 0.7076 - val_accuracy: 0.5017
# Epoch 3/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.7153 - accuracy: 0.7088 - val_loss: 0.7666 - val_accuracy: 0.5054
# Epoch 4/200
# 150/150 [==============================] - 4s 25ms/step - loss: 0.6597 - accuracy: 0.7377 - val_loss: 0.6135 - val_accuracy: 0.6171
# Epoch 5/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0
200
# 150/150 [==============================] - 4s 25ms/step - loss: 0.0891 - accuracy: 0.9710 - val_loss: 0.2915 - val_accuracy: 0.9029
# Epoch 97/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.1015 - accuracy: 0.9660 - val_loss: 0.1626 - val_accuracy: 0.9488
# Epoch 98/200
# 150/150 [==============================] - 4s 25ms/step - loss: 0.1006 - accuracy: 0.9682 - val_loss: 0.1900 - val_accuracy: 0.9337
# Epoch 99/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.0953 - accuracy: 0.9698 - val_loss: 0.2057 - val_accuracy: 0.9283
# Epoch 100/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.0897 - accuracy: 0.9694 - val_loss: 0.1634 - val_accuracy: 0.9400
# Epoch 00100: early stopping
# 75/75 [==============================] - 1s 7ms/step - loss: 0.1634 - accuracy: 0.9400

# %%
output_as_csv("batch normalization fold 5", benchmark_model_batch_normalization(X_all, y_all, folds[4]))
# Out:
# Epoch 1/200
# 150/150 [==============================] - 12s 31ms/step - loss: 0.9726 - accuracy: 0.5496 - val_loss: 0.7053 - val_accuracy: 0.4983
# Epoch 2/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.7959 - accuracy: 0.6541 - val_loss: 0.7748 - val_accuracy: 0.4983
# Epoch 3/200
# 150/150 [==============================] - 4s 27ms/step - loss: 0.7259 - accuracy: 0.7028 - val_loss: 0.9008 - val_accuracy: 0.4988
# Epoch 4/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.6690 - accuracy: 0.7414 - val_loss: 0.6132 - val_accuracy: 0.6183
# Epoch 5/200
# 150/150 [==============================] - 4s 28ms/step - loss: 0.6295 - accuracy: 0.7678 - val_loss: 0.4416 - val_accuracy: 0.8154
# Epoch 6/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.5737 - accuracy: 0.7863 - val_loss: 0.3722 - val_accuracy: 0.8612
# Epoch 7/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.5305 - accuracy: 0.8172 - val_loss: 0.4388 - val_accuracy: 0.8087
# Epoch 8/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.5147 - accuracy: 0.8228 - val_loss: 0.3696 - val_accuracy: 0.8550
# Epoch 9/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.5021 - accuracy: 0.8295 - val_loss: 0.3610 - val_accuracy: 0.8575
# Epoch 10/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.4771 - accuracy: 0.8357 - val_loss: 0.3239 - val_accuracy: 0.8771
# Epoch 11/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.4979 - accuracy: 0.8376 - val_loss: 0.3481 - val_accuracy: 0.8675
# Epoch 12/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.4559 - accuracy: 0.8502 - val_loss: 0.3282 - val_accuracy: 0.8725
# Epoch 13/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.4449 - accuracy: 0.8504 - val_loss: 0.3209 - val_accuracy: 0.8742
# Epoch 14/200
# 150/150 [==============================] - 4s 27ms/step - loss: 0.4427 - accuracy: 0.8499 - val_loss: 0.3328 - val_accuracy: 0.8696
# Epoch 15/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.4114 - accuracy: 0.8648 - val_loss: 0.3034 - val_accuracy: 0.8804
# Epoch 16/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.4083 - accuracy: 0.8686 - val_loss: 0.3015 - val_accuracy: 0.8783
# Epoch 17/200
# 150/150 [==============================] - 4s 27ms/step - loss: 0.4007 - accuracy: 0.8715 - val_loss: 0.3526 - val_accuracy: 0.8671
# Epoch 18/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.3711 - accuracy: 0.8754 - val_loss: 0.2996 - val_accuracy: 0.8846
# Epoch 19/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.3755 - accuracy: 0.8817 - val_loss: 0.2800 - val_accuracy: 0.8892
# Epoch 20/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.3596 - accuracy: 0.8836 - val_loss: 0.3037 - val_accuracy: 0.8825
# Epoch 21/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.3512 - accuracy: 0.8849 - val_loss: 0.3122 - val_accuracy: 0.8700
# Epoch 22/200
# 150/150 [==============================] - 4s 27ms/step - loss: 0.3460 - accuracy: 0.8900 - val_loss: 0.2497 - val_accuracy: 0.9050
# Epoch 23/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.3307 - accuracy: 0.8881 - val_loss: 0.2574 - val_accuracy: 0.8971
# Epoch 24/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.3237 - accuracy: 0.8932 - val_loss: 0.3110 - val_accuracy: 0.8804
# Epoch 25/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.3163 - accuracy: 0.8915 - val_loss: 0.2358 - val_accuracy: 0.9096
# Epoch 26/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.2984 - accuracy: 0.9013 - val_loss: 0.2600 - val_accuracy: 0.8950
# Epoch 27/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.2971 - accuracy: 0.9029 - val_loss: 0.2284 - val_accuracy: 0.9100
# Epoch 28/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.2912 - accuracy: 0.9013 - val_loss: 0.2613 - val_accuracy: 0.8971
# Epoch 29/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.2798 - accuracy: 0.9062 - val_loss: 0.2348 - val_accuracy: 0.9025
# Epoch 30/200
# 150/150 [==============================] - 4s 28ms/step - loss: 0.2859 - accuracy: 0.9001 - val_loss: 0.2145 - val_accuracy: 0.9121
# Epoch 31/200
# 150/150 [==============================] - 4s 27ms/step - loss: 0.2769 - accuracy: 0.9062 - val_loss: 0.2281 - val_accuracy: 0.9146
# Epoch 32/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.2710 - accuracy: 0.9054 - val_loss: 0.2065 - val_accuracy: 0.9229
# Epoch 33/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.2489 - accuracy: 0.9107 - val_loss: 0.2337 - val_accuracy: 0.9046
# Epoch 34/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.2584 - accuracy: 0.9160 - val_loss: 0.2174 - val_accuracy: 0.9133
# Epoch 35/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.2498 - accuracy: 0.9157 - val_loss: 0.2177 - val_accuracy: 0.9121
# Epoch 36/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.2507 - accuracy: 0.9115 - val_loss: 0.1930 - val_accuracy: 0.9262
# Epoch 37/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.2349 - accuracy: 0.9185 - val_loss: 0.2146 - val_accuracy: 0.9129
# Epoch 38/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.2317 - accuracy: 0.9224 - val_loss: 0.1965 - val_accuracy: 0.9254
# Epoch 39/200
# 150/150 [==============================] - 4s 27ms/step - loss: 0.2302 - accuracy: 0.9238 - val_loss: 0.2000 - val_accuracy: 0.9208
# Epoch 40/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.2285 - accuracy: 0.9245 - val_loss: 0.1782 - val_accuracy: 0.9312
# Epoch 41/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.2284 - accuracy: 0.9237 - val_loss: 0.1781 - val_accuracy: 0.9300
# Epoch 42/200
# 150/150 [==============================] - 4s 27ms/step - loss: 0.2155 - accuracy: 0.9291 - val_loss: 0.2453 - val_accuracy: 0.9021
# Epoch 43/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.2110 - accuracy: 0.9256 - val_loss: 0.1718 - val_accuracy: 0.9383
# Epoch 44/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.2078 - accuracy: 0.9293 - val_loss: 0.1726 - val_accuracy: 0.9354
# Epoch 45/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.2154 - accuracy: 0.9275 - val_loss: 0.2220 - val_accuracy: 0.9096
# Epoch 46/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.2139 - accuracy: 0.9261 - val_loss: 0.1694 - val_accuracy: 0.9379
# Epoch 47/200
# 150/150 [==============================] - 4s 27ms/step - loss: 0.1987 - accuracy: 0.9342 - val_loss: 0.1738 - val_accuracy: 0.9367
# Epoch 48/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.2031 - accuracy: 0.9294 - val_loss: 0.1921 - val_accuracy: 0.9283
# Epoch 49/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.2001 - accuracy: 0.9313 - val_loss: 0.1647 - val_accuracy: 0.9421
# Epoch 50/200
# 150/150 [==============================] - 4s 27ms/step - loss: 0.1949 - accuracy: 0.9401 - val_loss: 0.1680 - val_accuracy: 0.9400
# Epoch 51/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.1956 - accuracy: 0.9338 - val_loss: 0.1817 - val_accuracy: 0.9300
# Epoch 52/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.1840 - accuracy: 0.9380 - val_loss: 0.1655 - val_accuracy: 0.9358
# Epoch 53/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.1940 - accuracy: 0.9327 - val_loss: 0.1610 - val_accuracy: 0.9413
# Epoch 54/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.
200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.1233 - accuracy: 0.9590 - val_loss: 0.2735 - val_accuracy: 0.9058
# Epoch 85/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.1295 - accuracy: 0.9556 - val_loss: 0.1434 - val_accuracy: 0.9488
# Epoch 86/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.1292 - accuracy: 0.9557 - val_loss: 0.1650 - val_accuracy: 0.9383
# Epoch 87/200
# 150/150 [==============================] - 4s 27ms/step - loss: 0.1257 - accuracy: 0.9566 - val_loss: 0.1405 - val_accuracy: 0.9467
# Epoch 88/200
# 150/150 [==============================] - 4s 27ms/step - loss: 0.1234 - accuracy: 0.9563 - val_loss: 0.1609 - val_accuracy: 0.9413
# Epoch 89/200
# 150/150 [==============================] - 4s 27ms/step - loss: 0.1111 - accuracy: 0.9622 - val_loss: 0.1786 - val_accuracy: 0.9267
# Epoch 90/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.1211 - accuracy: 0.9586 - val_loss: 0.1162 - val_accuracy: 0.9554
# Epoch 91/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.1112 - accuracy: 0.9623 - val_loss: 0.1570 - val_accuracy: 0.9388
# Epoch 92/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.1190 - accuracy: 0.9601 - val_loss: 0.1841 - val_accuracy: 0.9242
# Epoch 93/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.1126 - accuracy: 0.9616 - val_loss: 0.1727 - val_accuracy: 0.9358
# Epoch 94/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.1125 - accuracy: 0.9614 - val_loss: 0.1666 - val_accuracy: 0.9337
# Epoch 95/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.1097 - accuracy: 0.9632 - val_loss: 0.1201 - val_accuracy: 0.9538
# Epoch 96/200
# 150/150 [==============================] - 4s 25ms/step - loss: 0.1123 - accuracy: 0.9629 - val_loss: 0.1901 - val_accuracy: 0.9258
# Epoch 97/200
# 150/150 [==============================] - 4s 27ms/step - loss: 0.1119 - accuracy: 0.9608 - val_loss: 0.1589 - val_accuracy: 0.9388
# Epoch 98/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.1069 - accuracy: 0.9645 - val_loss: 0.1784 - val_accuracy: 0.9287
# Epoch 99/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.1003 - accuracy: 0.9664 - val_loss: 0.1197 - val_accuracy: 0.9504
# Epoch 100/200
# 150/150 [==============================] - 4s 26ms/step - loss: 0.1136 - accuracy: 0.9635 - val_loss: 0.1965 - val_accuracy: 0.9237
# Epoch 00100: early stopping
# 75/75 [==============================] - 1s 8ms/step - loss: 0.1965 - accuracy: 0.9237

# %%
# results_list is a list of dictionaries
results_list = []
for i in range(1,6):
    path = "../input/hurricane-alex-batch-cv/batch normalization fold " + str(i) + ".csv"
    results_list.append(input_csv(path))

# results_dict is a dictionary of lists
results_dict = {}
results_dict["accuracy"] = [(float)(i["accuracy"]) for i in results_list]
results_dict["TPR/Recall"] = [(float)(i["TPR/Recall"]) for i in results_list]
results_dict["TNR/Specificity"] = [(float)(i["TNR/Specificity"]) for i in results_list]
results_dict["PPV/Precision"] = [(float)(i["PPV/Precision"]) for i in results_list]
results_dict["NPV"] = [(float)(i["NPV"]) for i in results_list]

print_confusion_matrix_results(results_dict)
# Out:
# accuracy mean: 0.9292500019073486
# accuracy std: 0.01677755095246161
# TPR/Recall mean: 0.9727096655228819
# TPR/Recall std: 0.02537117519397894
# TNR/Specificity mean: 0.8851639992773871
# TNR/Specificity std: 0.056957430328190395
# PPV/Precision mean: 0.8989722938855392
# PPV/Precision std: 0.04412818784988744
# NPV mean: 0.9717617827644375
# NPV std: 0.02447980695186277

# %%
# find confusion matrices
results_dict["tn"] = [(int)(i["tn"]) for i in results_list]
results_dict["fp"] = [(int)(i["fp"]) for i in results_list]
results_dict["fn"] = [(int)(i["fn"]) for i in results_list]
results_dict["tp"] = [(int)(i["tp"]) for i in results_list]
results_dict["confusion_matrix"] = []
# append confusion matrix for each cross-validation fold
for i in range(len(folds)):
    results_dict["confusion_matrix"].append(find_confusion_matrix_2(results_dict["tn"][i], results_dict["fp"][i], results_dict["fn"][i], results_dict["tp"][i]))
                                            
# total confusion matrix summed together
confusion_matrix_list = []
confusion_matrix_list = results_dict["confusion_matrix"]
confusion_matrix_comb = np.sum(confusion_matrix_list, axis=0)
heatmap(confusion_matrix_comb)

# %%
# normalized confusion matrix
confusion_matrix_norm = normalize_confusion_matrix(confusion_matrix_comb)
heatmap(confusion_matrix_norm)

# %% [markdown]
# ## Train Data with Data Augmentation

# %%
def train_data_augmentation(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model(learning_rate)
  # create data generator
  datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
  # prepare iterator
  it_train = datagen.flow(X_train, y_train, batch_size=64)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=10, verbose=1)
	# fit model
  steps = int(X_train.shape[0] / 64)
  history = model.fit(it_train, epochs=epochs, steps_per_epoch=steps, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_data, accuracy = train_data_augmentation(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 75)
print(accuracy)
y_pred = model_test_data.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_data, accuracy = train_data_augmentation(X_train, X_val, X_test, y_train, y_val, y_test, 1e-5, 75)
print(accuracy)
y_pred = model_test_data.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_data, accuracy = train_data_augmentation(X_train, X_val, X_test, y_train, y_val, y_test, 1e-6, 75)
print(accuracy)
y_pred = model_test_data.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))=
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_data, accuracy = train_data_augmentation(X_train, X_val, X_test, y_train, y_val, y_test, 5e-6, 75)
print(accuracy)
y_pred = model_test_data.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_data, accuracy = train_data_augmentation(X_train, X_val, X_test, y_train, y_val, y_test, 8e-6, 75)
print(accuracy)
y_pred = model_test_data.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %% [markdown]
# ## Train Data with Weight Regularization

# %%
def train_data_weight(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model_weight_regularization_batch_normalization(learning_rate)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
  # fit model
  history = model.fit(X_train, y_train, epochs=epochs, batch_size=64, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_weight, accuracy = train_data_weight(X_train, X_val, X_test, y_train, y_val, y_test, 1e-5, 75)
print(accuracy)
y_pred = model_test_weight.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_weight, accuracy = train_data_weight(X_train, X_val, X_test, y_train, y_val, y_test, 1e-6, 75)
print(accuracy)
y_pred = model_test_weight.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_weight, accuracy = train_data_weight(X_train, X_val, X_test, y_train, y_val, y_test, 5e-5, 75)
print(accuracy)
y_pred = model_test_weight.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_weight, accuracy = train_data_weight(X_train, X_val, X_test, y_train, y_val, y_test, 1e-5, 75)
print(accuracy)
y_pred = model_test_weight.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_weight, accuracy = train_data_weight(X_train, X_val, X_test, y_train, y_val, y_test, 2e-5, 75)
print(accuracy)
y_pred = model_test_weight.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
def train_data_weight_batch2(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, regularization_lambda, epochs):
  # define model
  model = define_model_weight_regularization_batch_normalization2(learning_rate, regularization_lambda)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
  # fit model
  history = model.fit(X_train, y_train, epochs=epochs, batch_size=64, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_weight_batch_normalization, accuracy = train_data_weight_batch2(X_train, X_val, X_test, y_train, y_val, y_test, 1e-5, 0.001, 40)
print(accuracy)
y_pred = model_test_weight_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_weight_batch_normalization, accuracy = train_data_weight_batch2(X_train, X_val, X_test, y_train, y_val, y_test, 1e-5, 0.0001, 75)
print(accuracy)
y_pred = model_test_weight_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_weight_batch_normalization, accuracy = train_data_weight_batch2(X_train, X_val, X_test, y_train, y_val, y_test, 1e-5, 0.1, 75)
print(accuracy)
y_pred = model_test_weight_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %% [markdown]
# ### Train Data with Data Augmentation and Weight Regularization

# %%
def train_data_augmentation_weight(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model_weight_regularization(learning_rate)
  # create data generator
  datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
  # prepare iterator
  it_train = datagen.flow(X_train, y_train, batch_size=64)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
	# fit model  
  steps = int(X_train.shape[0] / 64)
  history = model.fit(it_train, epochs=epochs, steps_per_epoch=steps, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_data_weight, accuracy = train_data_augmentation_weight(X_train, X_val, X_test, y_train, y_val, y_test, 1e-5, 75)
print(accuracy)
y_pred = model_test_data_weight.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_data_weight, accuracy = train_data_augmentation_weight(X_train, X_val, X_test, y_train, y_val, y_test, 1e-6, 75)
print(accuracy)
y_pred = model_test_data_weight.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_data_weight, accuracy = train_data_augmentation_weight(X_train, X_val, X_test, y_train, y_val, y_test, 5e-5, 75)
print(accuracy)
y_pred = model_test_data_weight.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_data_weight, accuracy = train_data_augmentation_weight(X_train, X_val, X_test, y_train, y_val, y_test, 5e-6, 75)
print(accuracy)
y_pred = model_test_data_weight.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
def train_data_augmentation_weight_batch2(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, regularization_lambda, epochs):
  # define model
  model = define_model_weight_regularization_batch_normalization2(learning_rate, regularization_lambda)
  # create data generator
  datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
  # prepare iterator
  it_train = datagen.flow(X_train, y_train, batch_size=64)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
	# fit model  
  steps = int(X_train.shape[0] / 64)
  history = model.fit(it_train, epochs=epochs, steps_per_epoch=steps, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_data_weight, accuracy = train_data_augmentation_weight_batch2(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 0.001, 75)
print(accuracy)
y_pred = model_test_data_weight.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_data_weight, accuracy = train_data_augmentation_weight_batch2(X_train, X_val, X_test, y_train, y_val, y_test, 1e-5, 0.001, 75)
print(accuracy)
y_pred = model_test_data_weight.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))
