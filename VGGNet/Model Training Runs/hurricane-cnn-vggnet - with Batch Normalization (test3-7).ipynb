# %% [markdown]
# # Imports

# %%
import numpy as np
import glob
from PIL import Image
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from tensorflow.keras import optimizers
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import KFold
import pandas as pd
import seaborn as sn
sn.set(font_scale=1.4) # for label size
import multiprocessing as mp
import csv

# %% [markdown]
# # Load DataSet
#
# 0 means unlikely to have flood damage, 1 means likely to have flood damage
#
# [0,1] --> damage
#
# [1,0] --> no damage

# %% [markdown]
# ## Load Training Set

# %%
images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/train_another/damage/*.jpeg')
dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  dmg_img.append(im_arr)
dmg_img = np.array(dmg_img)

images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/train_another/no_damage/*.jpeg')
no_dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  no_dmg_img.append(im_arr)
no_dmg_img = np.array(no_dmg_img)

X_train = np.concatenate((dmg_img, no_dmg_img))
dmg_img_y = np.array(dmg_img.shape[0] * [[0,1]])
no_dmg_img_y = np.array(no_dmg_img.shape[0] * [[1,0]])
y_train = np.concatenate((dmg_img_y, no_dmg_img_y))

# shuffle arrays so that the array is a mix of damage and no_damage in a random order
shuffler = np.random.permutation(X_train.shape[0])
X_train = X_train[shuffler]
y_train = y_train[shuffler]

# %% [markdown]
# ## Load Validation Set

# %%
images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/validation_another/damage/*.jpeg')
dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  dmg_img.append(im_arr)
dmg_img = np.array(dmg_img)

images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/validation_another/no_damage/*.jpeg')
no_dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  no_dmg_img.append(im_arr)
no_dmg_img = np.array(no_dmg_img)

X_val = np.concatenate((dmg_img, no_dmg_img))
dmg_img_y = np.array(dmg_img.shape[0] * [[0,1]])
no_dmg_img_y = np.array(no_dmg_img.shape[0] * [[1,0]])
y_val = np.concatenate((dmg_img_y, no_dmg_img_y))

# shuffle arrays so that the array is a mix of damage and no_damage in a random order
shuffler = np.random.permutation(X_val.shape[0])
X_val = X_val[shuffler]
y_val = y_val[shuffler]

# %%
# combine training and validation data - for cross-validation
X_all = np.concatenate((X_train, X_val))
y_all = np.concatenate((y_train, y_val))

# %% [markdown]
# ## Load Test Set

# %%
images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/test/damage/*.jpeg')
dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  dmg_img.append(im_arr)
dmg_img = np.array(dmg_img)

images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/test/no_damage/*.jpeg')
no_dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  no_dmg_img.append(im_arr)
no_dmg_img = np.array(no_dmg_img)

X_test = np.concatenate((dmg_img, no_dmg_img))
dmg_img_y = np.array(dmg_img.shape[0] * [[0,1]])
no_dmg_img_y = np.array(no_dmg_img.shape[0] * [[1,0]])
y_test = np.concatenate((dmg_img_y, no_dmg_img_y))

# shuffle arrays so that the array is a mix of damage and no_damage in a random order
shuffler = np.random.permutation(X_val.shape[0])
X_test = X_test[shuffler]
y_test = y_test[shuffler]

# %% [markdown]
# ## Input/Output

# %%
# save a dictionary as a csv file
def output_as_csv(name, a):
    path = "/kaggle/working/" + name + ".csv"
    with open(path, 'w') as csv_file:
        # create the csv writer
        writer = csv.writer(csv_file)

        # write a row to the csv file
        writer.writerow(a.keys())
        writer.writerow(a.values())

# input a csv file
def input_csv(path):
    b, keys = {}, {}
    with open(path, mode='r') as csv_file:
        csv_reader = csv.DictReader(csv_file)
        line_count = 0
        for row in csv_reader:
            keys = row
    b = dict(keys)
    return b # returns a dictionary

# %% [markdown]
# # Pre-Process DataSet

# %%
# pre-process data 
def scale_pixels(train, val, test, X_all):
	# convert from integers to floats and normalize between 0-1
  train_norm = train.astype('float32') / 255.0
  val_norm = val.astype('float32') / 255.0
  test_norm = test.astype('float32') / 255.0
  X_all_norm = X_all.astype('float32') / 255.0
	# return normalized images
  return train_norm, val_norm, test_norm, X_all_norm

X_train, X_val, X_test, X_all = scale_pixels(X_train, X_val, X_test, X_all)

# %% [markdown]
# # Plot Diagnostics

# %%
# plot diagnostic learning curves
def summarize_diagnostics(history):
  # blue = training data; orange = validation data
	# plot validation loss
	plt.subplot(211)
	plt.title('Cross Entropy Loss')
	plt.plot(history.history['loss'], color='blue', label='train')
	plt.plot(history.history['val_loss'], color='orange', label='validation')
	# plot accuracy
	plt.subplot(212)
	plt.title('Classification Accuracy')
	plt.plot(history.history['accuracy'], color='blue', label='train')
	plt.plot(history.history['val_accuracy'], color='orange', label='validation')

# %%
# returns the confusion matrix
def find_confusion_matrix(model, X_test, y_test):
    y_pred = model.predict(X_test)
    y_pred_val = y_pred.argmax(axis=1)
    y_test_val = y_test.argmax(axis=1)
    return confusion_matrix(y_test_val, y_pred_val)

# returns the confusion matrix based on tn, fn, fp, tp
def find_confusion_matrix_2(tn, fn, fp, tp):
    return [[tn, fp], [fn, tp]]

# generate heat map for confusion matrix
def heatmap(confusion_matrix):
    df = pd.DataFrame(confusion_matrix, index = ['F', 'T'], columns = ['F', 'T'])
    sn.heatmap(df, annot=True) # create a heatmap
    
# returns normalized confusion matrix
def normalize_confusion_matrix(confusion_matrix):
    confusion_matrix = np.array(confusion_matrix)
    confusion_matrix_sum = confusion_matrix.astype(np.float).sum(axis=1)
    confusion_matrix_norm = confusion_matrix.astype(np.float)
    confusion_matrix_norm[0] = confusion_matrix_norm[0] / confusion_matrix_sum[0]
    confusion_matrix_norm[1] = confusion_matrix_norm[1] / confusion_matrix_sum[1]
    return confusion_matrix_norm

def print_confusion_matrix_results(results):
    # results is a dictionary
    # calculate mean and standard deviation for each key
    for key in results:
        mean = np.mean(results[key])
        std = np.std(results[key])
        print("{} mean: {}".format(key, mean))
        print("{} std: {}".format(key, std))

# %% [markdown]
# # Create CNN Model

# %%
# define cnn model
def define_model(learning_rate):
  model = keras.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(128, 128, 3)))
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Flatten())
  model.add(layers.Dense(128, activation='relu', kernel_initializer='he_uniform'))
  model.add(layers.Dense(2, activation='softmax'))  # compile model
  opt = optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
  model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
  return model

# %% [markdown]
# ## CNN Model with Batch Normalization

# %%
# define cnn model
def define_model_batch_normalization(learning_rate):
  model = keras.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(128, 128, 3)))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Flatten())
  model.add(layers.Dense(128, activation='relu', kernel_initializer='he_uniform'))
  model.add(layers.BatchNormalization())
  model.add(layers.Dense(2, activation='softmax'))  # compile model
  opt = optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
  model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
  return model

# %% [markdown]
# ## CNN Model with Dropout Regularization

# %%
# define cnn model
def define_model_dropout_regularization(learning_rate):
  model = keras.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(128, 128, 3)))
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.2)) # retain 80% of neurons
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.3))
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.4))
  model.add(layers.Flatten())
  model.add(layers.Dense(128, activation='relu', kernel_initializer='he_uniform'))
  model.add(layers.Dropout(0.5))
  model.add(layers.Dense(2, activation='softmax'))  # compile model
  opt = optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
  model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
  return model

# %% [markdown]
# ### CNN Model with Dropout Regularization and Batch Normalization

# %%
# define cnn model
def define_model_dropout_regularization_batch_normalization(learning_rate):
  model = keras.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(128, 128, 3)))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.2)) # retain 80% of neurons
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.3))
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.4))
  model.add(layers.Flatten())
  model.add(layers.Dense(128, activation='relu', kernel_initializer='he_uniform'))
  model.add(layers.BatchNormalization())
  model.add(layers.Dropout(0.5))
  model.add(layers.Dense(2, activation='softmax'))  # compile model
  opt = optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
  model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
  return model

# %% [markdown]
# ## CNN Model with Weight Regularization

# %%
# define cnn model
def define_model_weight_regularization(learning_rate):
  model = keras.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.01), input_shape=(128, 128, 3)))
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Flatten())
  model.add(layers.Dense(128, activation='relu', kernel_initializer='he_uniform', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.Dense(2, activation='softmax'))  # compile model
  opt = optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
  model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
  return model

# %% [markdown]
# ### CNN Model with Weight Regularization and Batch Normalization

# %%
# define cnn model
def define_model_weight_regularization_batch_normalization(learning_rate):
  model = keras.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.01), input_shape=(128, 128, 3)))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Flatten())
  model.add(layers.Dense(128, activation='relu', kernel_initializer='he_uniform', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.BatchNormalization())
  model.add(layers.Dense(2, activation='softmax'))  # compile model
  opt = optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
  model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
  return model

# %% [markdown]
# # Train Data
# Hyperparameters are inputted into the function

# %%
def train(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model(learning_rate)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
  # fit model
  history = model.fit(X_train, y_train, epochs=epochs, batch_size=64, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model, accuracy = train(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 75)
print(accuracy)

# %%
model_test, accuracy = train(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 75)
print(accuracy)
y_pred = model_test.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %% [markdown]
# ## Train Data w/ Cross Validation

# %%
def benchmark_model(X_all, y_all, split):
    X_train_cv, y_train_cv = X_all[split[0]], y_all[split[0]]
    X_val_cv, y_val_cv = X_all[split[1]], y_all[split[1]]
    model, accuracy = train(X_train_cv, X_val_cv, X_val_cv, y_train_cv, y_val_cv, y_val_cv, 0.001, 75) 
    results = {}
    results["model"] = model
    results["accuracy"] = accuracy
    results["confusion_matrix"] = find_confusion_matrix(model, X_val_cv, y_val_cv)
    tn, fp, fn, tp = results["confusion_matrix"].ravel()
    results["tn"] = tn
    results["fp"] = fp
    results["fn"] = fn
    results["tp"] = tp
    results["TPR/Recall"] = tp/(tp+fn)
    results["TNR/Specificity"] = tn/(tn+fp)
    results["PPV/Precision"] = tp/(tp+fp)
    results["NPV"] = tn/(tn+fn)
    return results

# %%
kf = KFold(n_splits=5)
folds = list(kf.split(X_all, y_all))

# %%
output_as_csv("normal_fold_1", benchmark_model(X_all, y_all, folds[0]))

# %%
output_as_csv("normal_fold_2", benchmark_model(X_all, y_all, folds[1]))

# %%
output_as_csv("normal_fold_3", benchmark_model(X_all, y_all, folds[2]))

# %%
output_as_csv("normal_fold_4", benchmark_model(X_all, y_all, folds[3]))

# %%
output_as_csv("normal_fold_5", benchmark_model(X_all, y_all, folds[4]))

# %%
# results_list is a list of dictionaries
results_list = []
for i in range(1,6):
    path = "../input/hurricane-normal-cv/normal_fold_" + str(i) + ".csv"
    results_list.append(input_csv(path))

# results_dict is a dictionary of lists
results_dict = {}
results_dict["accuracy"] = [(float)(i["accuracy"]) for i in results_list]
results_dict["TPR/Recall"] = [(float)(i["TPR/Recall"]) for i in results_list]
results_dict["TNR/Specificity"] = [(float)(i["TNR/Specificity"]) for i in results_list]
results_dict["PPV/Precision"] = [(float)(i["PPV/Precision"]) for i in results_list]
results_dict["NPV"] = [(float)(i["NPV"]) for i in results_list]

print_confusion_matrix_results(results_dict)

# %%
# find confusion matrices
results_dict["tn"] = [(int)(i["tn"]) for i in results_list]
results_dict["fp"] = [(int)(i["fp"]) for i in results_list]
results_dict["fn"] = [(int)(i["fn"]) for i in results_list]
results_dict["tp"] = [(int)(i["tp"]) for i in results_list]
results_dict["confusion_matrix"] = []
# append confusion matrix for each cross-validation fold
for i in range(len(folds)):
    results_dict["confusion_matrix"].append(find_confusion_matrix_2(results_dict["tn"][i], results_dict["fp"][i], results_dict["fn"][i], results_dict["tp"][i]))
                                            
# total confusion matrix summed together
confusion_matrix_list = []
confusion_matrix_list = results_dict["confusion_matrix"]
confusion_matrix_comb = np.sum(confusion_matrix_list, axis=0)
heatmap(confusion_matrix_comb)

# %%
# normalized confusion matrix
confusion_matrix_norm = normalize_confusion_matrix(confusion_matrix_comb)
heatmap(confusion_matrix_norm)

# %% [markdown]
# ## Train Data with Batch Normalization

# %%
def train_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model_batch_normalization(learning_rate)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
  # fit model
  history = model.fit(X_train, y_train, epochs=epochs, batch_size=64, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model, accuracy = train_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 75)
print(accuracy)

# %%
model_test_batch_normalization, accuracy = train_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 75)
print(accuracy)
y_pred = model_test_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %% [markdown]
# ### Tune Hyperparameters - learning rate

# %%
model_test_batch_normalization, accuracy = train_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, 0.0005, 75)
print(accuracy)
y_pred = model_test_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))
# Out:
# Epoch 1/75
# 157/157 [==============================] - 742s 5s/step - loss: 0.4339 - accuracy: 0.8370 - val_loss: 1.8142 - val_accuracy: 0.5000
# Epoch 2/75
# 157/157 [==============================] - 726s 5s/step - loss: 0.1386 - accuracy: 0.9567 - val_loss: 0.6883 - val_accuracy: 0.6550
# Epoch 3/75
# 157/157 [==============================] - 731s 5s/step - loss: 0.1006 - accuracy: 0.9675 - val_loss: 0.2322 - val_accuracy: 0.9120
# Epoch 4/75
# 157/157 [==============================] - 729s 5s/step - loss: 0.0690 - accuracy: 0.9815 - val_loss: 0.1320 - val_accuracy: 0.9595
# Epoch 5/75
# 157/157 [==============================] - 724s 5s/step - loss: 0.0646 - accuracy: 0.9816 - val_loss: 0.1309 - val_accuracy: 0.9545
# Epoch 6/75
# 157/157 [==============================] - 729s 5s/step - loss: 0.0469 - accuracy: 0.9898 - val_loss: 0.1058 - val_accuracy: 0.9635
# Epoch 7/75
# 157/157 [==============================] - 737s 5s/step - loss: 0.0424 - accuracy: 0.9913 - val_loss: 0.1032 - val_accuracy: 0.9655
# Epoch 8/75
# 157/157 [==============================] - 732s 5s/step - loss: 0.0298 - accuracy: 0.9942 - val_loss: 0.1148 - val_accuracy: 0.9580
# Epoch 9/75
# 157/157 [==============================] - 728s 5s/step - loss: 0.0295 - accuracy: 0.9952 - val_loss: 0.0905 - val_accuracy: 0.9670
# Epoch 10/75
# 157/157 [==============================] - 720s 5s/step - loss: 0.0265 - accuracy: 0.9954 - val_loss: 0.0879 - val_accuracy: 0.9700
# Epoch 11/75
# 157/157 [==============================] - 724s 5s/step - loss: 0.0203 - accuracy: 0.9981 - val_loss: 0.0987 - val_accuracy: 0.9705
# Epoch 12/75
# 157/157 [==============================] - 722s 5s/step - loss: 0.0196 - accuracy: 0.9975 - val_loss: 0.1012 - val_accuracy: 0.9600
# Epoch 13/75
# 157/157 [==============================] - 720s 5s/step - loss: 0.0172 - accuracy: 0.9982 - val_loss: 0.0933 - val_accuracy: 0.9710
# Epoch 14/75
# 157/157 [==============================] - 725s 5s/step - loss: 0.0145 - accuracy: 0.9991 - val_loss: 0.0906 - val_accuracy: 0.9670
# Epoch 15/75
# 157/157 [==============================] - 723s 5s/step - loss: 0.0128 - accuracy: 0.9993 - val_loss: 0.0888 - val_accuracy: 0.9710
# Epoch 00015: early stopping
# 63/63 [==============================] - 34s 533ms/step - loss: 0.0531 - accuracy: 0.9835
# 0.9835000038146973
# 985 15 18 982
# TPR/Recall: 0.982
# TNR/Specificity: 0.985
# PPV/Precision: 0.9849548645937813
# NPV: 0.9820538384845464

# %%
model_test_batch_normalization, accuracy = train_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, 0.005, 40)
print(accuracy)
y_pred = model_test_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))
# Out:
# Epoch 1/40
# 157/157 [==============================] - 683s 4s/step - loss: 0.3107 - accuracy: 0.8811 - val_loss: 2.8441 - val_accuracy: 0.5010
# Epoch 2/40
# 157/157 [==============================] - 676s 4s/step - loss: 0.0919 - accuracy: 0.9677 - val_loss: 0.4590 - val_accuracy: 0.7950
# Epoch 3/40
# 157/157 [==============================] - 677s 4s/step - loss: 0.0635 - accuracy: 0.9786 - val_loss: 0.1793 - val_accuracy: 0.9385
# Epoch 4/40
# 157/157 [==============================] - 678s 4s/step - loss: 0.0414 - accuracy: 0.9866 - val_loss: 0.1054 - val_accuracy: 0.9570
# Epoch 5/40
# 157/157 [==============================] - 680s 4s/step - loss: 0.0291 - accuracy: 0.9921 - val_loss: 0.0911 - val_accuracy: 0.9670
# Epoch 6/40
# 157/157 [==============================] - 679s 4s/step - loss: 0.0133 - accuracy: 0.9975 - val_loss: 0.1139 - val_accuracy: 0.9645
# Epoch 7/40
# 157/157 [==============================] - 680s 4s/step - loss: 0.0108 - accuracy: 0.9979 - val_loss: 0.0881 - val_accuracy: 0.9710
# Epoch 8/40
# 157/157 [==============================] - 682s 4s/step - loss: 0.0073 - accuracy: 0.9989 - val_loss: 0.0825 - val_accuracy: 0.9715
# Epoch 9/40
# 157/157 [==============================] - 682s 4s/step - loss: 0.0092 - accuracy: 0.9985 - val_loss: 0.0899 - val_accuracy: 0.9700
# Epoch 10/40
# 157/157 [==============================] - 683s 4s/step - loss: 0.0084 - accuracy: 0.9984 - val_loss: 0.1039 - val_accuracy: 0.9685
# Epoch 11/40
# 157/157 [==============================] - 684s 4s/step - loss: 0.0060 - accuracy: 0.9992 - val_loss: 0.0843 - val_accuracy: 0.9745
# Epoch 12/40
# 157/157 [==============================] - 685s 4s/step - loss: 0.0028 - accuracy: 0.9998 - val_loss: 0.0795 - val_accuracy: 0.9755
# Epoch 13/40
# 157/157 [==============================] - 686s 4s/step - loss: 0.0019 - accuracy: 0.9998 - val_loss: 0.0996 - val_accuracy: 0.9695
# Epoch 14/40
# 157/157 [==============================] - 683s 4s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0813 - val_accuracy: 0.9750
# Epoch 15/40
# 157/157 [==============================] - 682s 4s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0841 - val_accuracy: 0.9755
# Epoch 16/40
# 157/157 [==============================] - 682s 4s/step - loss: 0.0024 - accuracy: 0.9995 - val_loss: 0.0821 - val_accuracy: 0.9725
# Epoch 17/40
# 157/157 [==============================] - 682s 4s/step - loss: 0.0018 - accuracy: 0.9998 - val_loss: 0.0844 - val_accuracy: 0.9765
# Epoch 00017: early stopping
# 63/63 [==============================] - 31s 491ms/step - loss: 0.0467 - accuracy: 0.9860
# 0.9860000014305115
# 993 7 21 979
# TPR/Recall: 0.979
# TNR/Specificity: 0.993
# PPV/Precision: 0.9929006085192698
# NPV: 0.9792899408284024

# %%
model_test_batch_normalization, accuracy = train_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, 0.01, 40)
print(accuracy)
y_pred = model_test_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))
# Out:
# Epoch 1/40
# 157/157 [==============================] - 824s 5s/step - loss: 0.2769 - accuracy: 0.8986 - val_loss: 2.9580 - val_accuracy: 0.5000
# Epoch 2/40
# 157/157 [==============================] - 819s 5s/step - loss: 0.1007 - accuracy: 0.9609 - val_loss: 0.6785 - val_accuracy: 0.7365
# Epoch 3/40
# 157/157 [==============================] - 819s 5s/step - loss: 0.0720 - accuracy: 0.9738 - val_loss: 0.2535 - val_accuracy: 0.9280
# Epoch 4/40
# 157/157 [==============================] - 819s 5s/step - loss: 0.0570 - accuracy: 0.9812 - val_loss: 0.1369 - val_accuracy: 0.9500
# Epoch 5/40
# 157/157 [==============================] - 817s 5s/step - loss: 0.0313 - accuracy: 0.9900 - val_loss: 0.1041 - val_accuracy: 0.9595
# Epoch 6/40
# 157/157 [==============================] - 818s 5s/step - loss: 0.0160 - accuracy: 0.9960 - val_loss: 0.1243 - val_accuracy: 0.9540
# Epoch 7/40
# 157/157 [==============================] - 815s 5s/step - loss: 0.0160 - accuracy: 0.9957 - val_loss: 0.0775 - val_accuracy: 0.9725
# Epoch 8/40
# 157/157 [==============================] - 814s 5s/step - loss: 0.0057 - accuracy: 0.9996 - val_loss: 0.4316 - val_accuracy: 0.8900
# Epoch 9/40
# 157/157 [==============================] - 816s 5s/step - loss: 0.0117 - accuracy: 0.9967 - val_loss: 0.1634 - val_accuracy: 0.9465
# Epoch 10/40
# 157/157 [==============================] - 819s 5s/step - loss: 0.0036 - accuracy: 0.9996 - val_loss: 0.0784 - val_accuracy: 0.9735
# Epoch 11/40
# 157/157 [==============================] - 816s 5s/step - loss: 0.0019 - accuracy: 0.9998 - val_loss: 0.0795 - val_accuracy: 0.9765
# Epoch 12/40
# 157/157 [==============================] - 815s 5s/step - loss: 0.0021 - accuracy: 0.9999 - val_loss: 0.0910 - val_accuracy: 0.9730
# Epoch 00012: early stopping
# 63/63 [==============================] - 36s 561ms/step - loss: 0.0521 - accuracy: 0.9850
# 0.9850000143051147
# 993 7 23 977
# TPR/Recall: 0.977
# TNR/Specificity: 0.993
# PPV/Precision: 0.9928861788617886
# NPV: 0.9773622047244095

# %%
model_test_batch_normalization, accuracy = train_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, 0.1, 40)
print(accuracy)
y_pred = model_test_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))
# Out:
# Epoch 1/40
# 157/157 [==============================] - 806s 5s/step - loss: 0.2969 - accuracy: 0.8860 - val_loss: 0.7221 - val_accuracy: 0.5940
# Epoch 2/40
# 157/157 [==============================] - 812s 5s/step - loss: 0.1339 - accuracy: 0.9452 - val_loss: 0.8051 - val_accuracy: 0.7715
# Epoch 3/40
# 157/157 [==============================] - 807s 5s/step - loss: 0.1106 - accuracy: 0.9581 - val_loss: 0.4778 - val_accuracy: 0.8115
# Epoch 4/40
# 157/157 [==============================] - 808s 5s/step - loss: 0.0784 - accuracy: 0.9687 - val_loss: 3.3428 - val_accuracy: 0.5450
# Epoch 5/40
# 157/157 [==============================] - 805s 5s/step - loss: 0.0772 - accuracy: 0.9723 - val_loss: 1.0538 - val_accuracy: 0.7600
# Epoch 6/40
# 157/157 [==============================] - 805s 5s/step - loss: 0.0437 - accuracy: 0.9842 - val_loss: 0.3707 - val_accuracy: 0.8340
# Epoch 7/40
# 157/157 [==============================] - 820s 5s/step - loss: 0.0376 - accuracy: 0.9869 - val_loss: 0.2838 - val_accuracy: 0.9070
# Epoch 8/40
# 157/157 [==============================] - 817s 5s/step - loss: 0.0479 - accuracy: 0.9826 - val_loss: 4.6635 - val_accuracy: 0.5840
# Epoch 9/40
# 157/157 [==============================] - 803s 5s/step - loss: 0.0261 - accuracy: 0.9913 - val_loss: 1.8907 - val_accuracy: 0.6460
# Epoch 10/40
# 157/157 [==============================] - 824s 5s/step - loss: 0.0126 - accuracy: 0.9965 - val_loss: 0.2256 - val_accuracy: 0.9505
# Epoch 11/40
# 157/157 [==============================] - 804s 5s/step - loss: 0.0153 - accuracy: 0.9957 - val_loss: 3.5950 - val_accuracy: 0.5150
# Epoch 12/40
# 157/157 [==============================] - 802s 5s/step - loss: 0.0142 - accuracy: 0.9957 - val_loss: 0.1027 - val_accuracy: 0.9735
# Epoch 13/40
# 157/157 [==============================] - 802s 5s/step - loss: 0.0108 - accuracy: 0.9963 - val_loss: 0.3734 - val_accuracy: 0.9055
# Epoch 14/40
# 157/157 [==============================] - 803s 5s/step - loss: 0.0063 - accuracy: 0.9982 - val_loss: 0.1868 - val_accuracy: 0.9640
# Epoch 15/40
# 157/157 [==============================] - 803s 5s/step - loss: 0.0028 - accuracy: 0.9997 - val_loss: 0.2636 - val_accuracy: 0.9530
# Epoch 16/40
# 157/157 [==============================] - 801s 5s/step - loss: 0.0118 - accuracy: 0.9962 - val_loss: 0.2754 - val_accuracy: 0.9390
# Epoch 17/40
# 157/157 [==============================] - 809s 5s/step - loss: 0.0073 - accuracy: 0.9979 - val_loss: 0.3375 - val_accuracy: 0.9335
# Epoch 00017: early stopping
# 63/63 [==============================] - 37s 581ms/step - loss: 0.3051 - accuracy: 0.9300
# 0.9300000071525574
# 872 128 12 988
# TPR/Recall: 0.988
# TNR/Specificity: 0.872
# PPV/Precision: 0.8853046594982079
# NPV: 0.9864253393665159

# %% [markdown]
# ### Tune Hyperparameters - batch size

# %%
def train_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, batch_size, epochs):
  # define model
  model = define_model_batch_normalization(learning_rate)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
  # fit model
  history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_batch_normalization, accuracy = train_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, 0.005, 128, 40)
print(accuracy)
y_pred = model_test_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))
# Out:
# Epoch 1/40
# 79/79 [==============================] - 734s 9s/step - loss: 0.3718 - accuracy: 0.8485 - val_loss: 2.3963 - val_accuracy: 0.5000
# Epoch 2/40
# 79/79 [==============================] - 725s 9s/step - loss: 0.0978 - accuracy: 0.9664 - val_loss: 4.1798 - val_accuracy: 0.5000
# Epoch 3/40
# 79/79 [==============================] - 726s 9s/step - loss: 0.0760 - accuracy: 0.9703 - val_loss: 3.5021 - val_accuracy: 0.5000
# Epoch 4/40
# 79/79 [==============================] - 728s 9s/step - loss: 0.0413 - accuracy: 0.9877 - val_loss: 2.5377 - val_accuracy: 0.5065
# Epoch 5/40
# 79/79 [==============================] - 725s 9s/step - loss: 0.0249 - accuracy: 0.9943 - val_loss: 1.3011 - val_accuracy: 0.6010
# Epoch 6/40
# 79/79 [==============================] - 735s 9s/step - loss: 0.0165 - accuracy: 0.9973 - val_loss: 0.2074 - val_accuracy: 0.9105
# Epoch 7/40
# 79/79 [==============================] - 740s 9s/step - loss: 0.0102 - accuracy: 0.9993 - val_loss: 0.1659 - val_accuracy: 0.9370
# Epoch 8/40
# 79/79 [==============================] - 732s 9s/step - loss: 0.0246 - accuracy: 0.9937 - val_loss: 0.1908 - val_accuracy: 0.9280
# Epoch 9/40
# 79/79 [==============================] - 730s 9s/step - loss: 0.0076 - accuracy: 0.9998 - val_loss: 0.1277 - val_accuracy: 0.9615
# Epoch 10/40
# 79/79 [==============================] - 727s 9s/step - loss: 0.0260 - accuracy: 0.9918 - val_loss: 0.1889 - val_accuracy: 0.9370
# Epoch 11/40
# 79/79 [==============================] - 722s 9s/step - loss: 0.0053 - accuracy: 0.9995 - val_loss: 0.0887 - val_accuracy: 0.9680
# Epoch 12/40
# 79/79 [==============================] - 723s 9s/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0813 - val_accuracy: 0.9700
# Epoch 13/40
# 79/79 [==============================] - 728s 9s/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0769 - val_accuracy: 0.9710
# Epoch 14/40
# 79/79 [==============================] - 729s 9s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0828 - val_accuracy: 0.9700
# Epoch 15/40
# 79/79 [==============================] - 740s 9s/step - loss: 0.0021 - accuracy: 0.9999 - val_loss: 0.0880 - val_accuracy: 0.9720
# Epoch 16/40
# 79/79 [==============================] - 726s 9s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0947 - val_accuracy: 0.9685
# Epoch 17/40
# 79/79 [==============================] - 722s 9s/step - loss: 0.0146 - accuracy: 0.9955 - val_loss: 0.0911 - val_accuracy: 0.9675
# Epoch 18/40
# 79/79 [==============================] - 736s 9s/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0854 - val_accuracy: 0.9720
# Epoch 00018: early stopping
# 63/63 [==============================] - 35s 550ms/step - loss: 0.0415 - accuracy: 0.9850
# 0.9850000143051147
# 988 12 18 982
# TPR/Recall: 0.982
# TNR/Specificity: 0.988
# PPV/Precision: 0.9879275653923542
# NPV: 0.9821073558648111

# %%
model_test_batch_normalization, accuracy = train_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, 0.005, 32, 40)
print(accuracy)
y_pred = model_test_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_batch_normalization, accuracy = train_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, 0.005, 256, 40)
print(accuracy)
y_pred = model_test_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %% [markdown]
# ### Train Data with Batch Normalization and Cross Validation

# %%
def benchmark_model_batch_normalization(X_all, y_all, split):
    X_train_cv, y_train_cv = X_all[split[0]], y_all[split[0]]
    X_val_cv, y_val_cv = X_all[split[1]], y_all[split[1]]
    model, accuracy = train_batch_normalization(X_train_cv, X_val_cv, X_val_cv, y_train_cv, y_val_cv, y_val_cv, 0.001, 75) 
    results = {}
    results["model"] = model
    results["accuracy"] = accuracy
    results["confusion_matrix"] = find_confusion_matrix(model, X_val_cv, y_val_cv)
    tn, fp, fn, tp = results["confusion_matrix"].ravel()
    results["tn"] = tn
    results["fp"] = fp
    results["fn"] = fn
    results["tp"] = tp
    results["TPR/Recall"] = tp/(tp+fn)
    results["TNR/Specificity"] = tn/(tn+fp)
    results["PPV/Precision"] = tp/(tp+fp)
    results["NPV"] = tn/(tn+fn)
    return results

# %%
kf = KFold(n_splits=5)
folds = list(kf.split(X_all, y_all))

# %%
output_as_csv("batch normalization fold 1", benchmark_model_batch_normalization(X_all, y_all, folds[0]))

# %%
output_as_csv("batch normalization fold 2", benchmark_model_batch_normalization(X_all, y_all, folds[1]))

# %%
output_as_csv("batch normalization fold 3", benchmark_model_batch_normalization(X_all, y_all, folds[2]))

# %%
output_as_csv("batch normalization fold 4", benchmark_model_batch_normalization(X_all, y_all, folds[3]))

# %%
output_as_csv("batch normalization fold 5", benchmark_model_batch_normalization(X_all, y_all, folds[4]))

# %% [markdown]
# ## Train Data with Data Augmentation

# %%
def train_data_augmentation(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model(learning_rate)
  # create data generator
  datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
  # prepare iterator
  it_train = datagen.flow(X_train, y_train, batch_size=64)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=8, verbose=1)
	# fit model
  steps = int(X_train.shape[0] / 64)
  history = model.fit(it_train, epochs=epochs, steps_per_epoch=steps, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model, accuracy = train_data_augmentation(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 100)
print(accuracy)

# %%
model_test_data, accuracy = train_data_augmentation(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 50)
print(accuracy)
y_pred = model_test_data.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %% [markdown]
# ### Train Data with Data Augmentation and Batch Normalization

# %%
def train_data_augmentation_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model_batch_normalization(learning_rate)
  # create data generator
  datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
  # prepare iterator
  it_train = datagen.flow(X_train, y_train, batch_size=64)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
	# fit model  
  steps = int(X_train.shape[0] / 64)
  history = model.fit(it_train, epochs=epochs, steps_per_epoch=steps, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model, accuracy = train_data_augmentation_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 100)
print(accuracy)

# %%
model_test_data_augmentation_batch_normalization, accuracy = train_data_augmentation_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 100)
print(accuracy)
y_pred = model_test_data_augmentation_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %% [markdown]
# ## Train Data with Dropout Regularization and Batch Normalization

# %%
def train_data_dropout_batch(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model_dropout_regularization_batch_normalization(learning_rate)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
  # fit model
  history = model.fit(X_train, y_train, epochs=epochs, batch_size=64, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_data_dropout_batch_normalization, accuracy = train_data_dropout_batch(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 40)
print(accuracy)
y_pred = model_test_data_dropout_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))
# Out:
# Epoch 1/40
# 157/157 [==============================] - 746s 5s/step - loss: 0.6001 - accuracy: 0.7804 - val_loss: 1.0484 - val_accuracy: 0.5035
# Epoch 2/40
# 157/157 [==============================] - 747s 5s/step - loss: 0.1953 - accuracy: 0.9356 - val_loss: 0.9957 - val_accuracy: 0.5600
# Epoch 3/40
# 157/157 [==============================] - 738s 5s/step - loss: 0.1484 - accuracy: 0.9435 - val_loss: 0.3477 - val_accuracy: 0.8810
# Epoch 4/40
# 157/157 [==============================] - 756s 5s/step - loss: 0.1363 - accuracy: 0.9497 - val_loss: 0.3863 - val_accuracy: 0.8765
# Epoch 5/40
# 157/157 [==============================] - 749s 5s/step - loss: 0.1134 - accuracy: 0.9560 - val_loss: 0.4768 - val_accuracy: 0.8460
# Epoch 6/40
# 157/157 [==============================] - 742s 5s/step - loss: 0.1202 - accuracy: 0.9531 - val_loss: 0.3000 - val_accuracy: 0.9060
# Epoch 7/40
# 157/157 [==============================] - 742s 5s/step - loss: 0.0993 - accuracy: 0.9649 - val_loss: 0.4192 - val_accuracy: 0.8480
# Epoch 8/40
# 157/157 [==============================] - 743s 5s/step - loss: 0.1017 - accuracy: 0.9585 - val_loss: 0.2097 - val_accuracy: 0.9475
# Epoch 9/40
# 157/157 [==============================] - 738s 5s/step - loss: 0.0872 - accuracy: 0.9640 - val_loss: 0.2529 - val_accuracy: 0.9190
# Epoch 10/40
# 157/157 [==============================] - 747s 5s/step - loss: 0.0766 - accuracy: 0.9700 - val_loss: 0.1695 - val_accuracy: 0.9420
# Epoch 11/40
# 157/157 [==============================] - 738s 5s/step - loss: 0.0776 - accuracy: 0.9739 - val_loss: 0.1648 - val_accuracy: 0.9570
# Epoch 12/40
# 157/157 [==============================] - 744s 5s/step - loss: 0.0758 - accuracy: 0.9719 - val_loss: 0.3485 - val_accuracy: 0.8840
# Epoch 13/40
# 157/157 [==============================] - 745s 5s/step - loss: 0.0733 - accuracy: 0.9722 - val_loss: 0.2321 - val_accuracy: 0.9330
# Epoch 14/40
# 157/157 [==============================] - 742s 5s/step - loss: 0.0616 - accuracy: 0.9766 - val_loss: 0.2326 - val_accuracy: 0.9440
# Epoch 15/40
# 157/157 [==============================] - 736s 5s/step - loss: 0.0635 - accuracy: 0.9756 - val_loss: 0.2349 - val_accuracy: 0.9435
# Epoch 16/40
# 157/157 [==============================] - 744s 5s/step - loss: 0.0618 - accuracy: 0.9776 - val_loss: 0.1761 - val_accuracy: 0.9505
# Epoch 00016: early stopping
# 63/63 [==============================] - 34s 538ms/step - loss: 0.1660 - accuracy: 0.9485
# 0.9484999775886536
# 920 80 23 977
# TPR/Recall: 0.977
# TNR/Specificity: 0.92
# PPV/Precision: 0.924314096499527
# NPV: 0.975609756097561

# %% [markdown]
# ### Train Data with Data Augmentation, Dropout Regularization and Batch Normalization

# %%
def train_data_augmentation_dropout_batch(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model_weight_regularization_batch_normalization(learning_rate)
  # create data generator
  datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
  # prepare iterator
  it_train = datagen.flow(X_train, y_train, batch_size=64)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
	# fit model  
  steps = int(X_train.shape[0] / 64)
  history = model.fit(it_train, epochs=epochs, steps_per_epoch=steps, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_data_dropout_batch_normalization, accuracy = train_data_augmentation_dropout_batch(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 25)
print(accuracy)
y_pred = model_test_data_dropout_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %% [markdown]
# ## Train Data with Weight Regularization and Batch Normalization

# %%
def train_data_weight_batch(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model_weight_regularization_batch_normalization(learning_rate)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
  # fit model
  history = model.fit(X_train, y_train, epochs=epochs, batch_size=64, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_weight_batch_normalization, accuracy = train_data_weight_batch(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 40)
print(accuracy)
y_pred = model_test_weight_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))
# Out:
# Epoch 1/40
# 157/157 [==============================] - 804s 5s/step - loss: 11.7378 - accuracy: 0.8547 - val_loss: 13.2116 - val_accuracy: 0.5000
# Epoch 2/40
# 157/157 [==============================] - 798s 5s/step - loss: 10.7736 - accuracy: 0.9621 - val_loss: 11.7291 - val_accuracy: 0.5195
# Epoch 3/40
# 157/157 [==============================] - 792s 5s/step - loss: 10.0865 - accuracy: 0.9794 - val_loss: 10.1766 - val_accuracy: 0.7180
# Epoch 4/40
# 157/157 [==============================] - 792s 5s/step - loss: 9.4553 - accuracy: 0.9875 - val_loss: 9.1529 - val_accuracy: 0.9310
# Epoch 5/40
# 157/157 [==============================] - 784s 5s/step - loss: 8.8699 - accuracy: 0.9935 - val_loss: 8.6079 - val_accuracy: 0.9280
# Epoch 6/40
# 157/157 [==============================] - 786s 5s/step - loss: 8.3273 - accuracy: 0.9933 - val_loss: 8.0240 - val_accuracy: 0.9625
# Epoch 7/40
# 157/157 [==============================] - 792s 5s/step - loss: 7.8135 - accuracy: 0.9973 - val_loss: 7.5947 - val_accuracy: 0.9400
# Epoch 8/40
# 157/157 [==============================] - 785s 5s/step - loss: 7.3350 - accuracy: 0.9981 - val_loss: 7.0761 - val_accuracy: 0.9635
# Epoch 9/40
# 157/157 [==============================] - 790s 5s/step - loss: 6.8864 - accuracy: 0.9972 - val_loss: 6.6393 - val_accuracy: 0.9650
# Epoch 10/40
# 157/157 [==============================] - 792s 5s/step - loss: 6.4638 - accuracy: 0.9994 - val_loss: 6.2565 - val_accuracy: 0.9660
# Epoch 11/40
# 157/157 [==============================] - 797s 5s/step - loss: 6.0710 - accuracy: 0.9991 - val_loss: 5.8950 - val_accuracy: 0.9620
# Epoch 12/40
# 157/157 [==============================] - 790s 5s/step - loss: 5.6986 - accuracy: 0.9993 - val_loss: 5.5133 - val_accuracy: 0.9705
# Epoch 13/40
# 157/157 [==============================] - 797s 5s/step - loss: 5.3509 - accuracy: 0.9997 - val_loss: 5.1841 - val_accuracy: 0.9670
# Epoch 14/40
# 157/157 [==============================] - 800s 5s/step - loss: 5.0254 - accuracy: 0.9991 - val_loss: 4.8934 - val_accuracy: 0.9645
# Epoch 15/40
# 157/157 [==============================] - 801s 5s/step - loss: 4.7165 - accuracy: 0.9999 - val_loss: 4.5841 - val_accuracy: 0.9665
# Epoch 16/40
# 157/157 [==============================] - 806s 5s/step - loss: 4.4308 - accuracy: 0.9997 - val_loss: 4.3091 - val_accuracy: 0.9685
# Epoch 17/40
# 157/157 [==============================] - 809s 5s/step - loss: 4.1586 - accuracy: 1.0000 - val_loss: 4.0560 - val_accuracy: 0.9685
# Epoch 18/40
# 157/157 [==============================] - 795s 5s/step - loss: 3.9288 - accuracy: 0.9922 - val_loss: 3.8300 - val_accuracy: 0.9625
# Epoch 19/40
# 157/157 [==============================] - 794s 5s/step - loss: 3.6712 - accuracy: 0.9998 - val_loss: 3.5844 - val_accuracy: 0.9690
# Epoch 20/40
# 157/157 [==============================] - 796s 5s/step - loss: 3.4461 - accuracy: 1.0000 - val_loss: 3.3793 - val_accuracy: 0.9665
# Epoch 21/40
# 157/157 [==============================] - 788s 5s/step - loss: 3.2376 - accuracy: 0.9996 - val_loss: 3.1714 - val_accuracy: 0.9690
# Epoch 22/40
# 157/157 [==============================] - 801s 5s/step - loss: 3.0384 - accuracy: 1.0000 - val_loss: 2.9854 - val_accuracy: 0.9710
# Epoch 23/40
# 157/157 [==============================] - 804s 5s/step - loss: 2.8531 - accuracy: 1.0000 - val_loss: 2.9007 - val_accuracy: 0.9410
# Epoch 24/40
# 157/157 [==============================] - 808s 5s/step - loss: 2.6794 - accuracy: 1.0000 - val_loss: 2.6557 - val_accuracy: 0.9695
# Epoch 25/40
# 157/157 [==============================] - 793s 5s/step - loss: 2.5161 - accuracy: 1.0000 - val_loss: 2.5059 - val_accuracy: 0.9665
# Epoch 26/40
# 157/157 [==============================] - 788s 5s/step - loss: 2.3632 - accuracy: 1.0000 - val_loss: 2.4049 - val_accuracy: 0.9540
# Epoch 27/40
# 157/157 [==============================] - 790s 5s/step - loss: 2.2246 - accuracy: 0.9984 - val_loss: 2.5811 - val_accuracy: 0.8500
# Epoch 28/40
# 157/157 [==============================] - 793s 5s/step - loss: 2.1197 - accuracy: 0.9914 - val_loss: 2.5882 - val_accuracy: 0.8260
# Epoch 29/40
# 157/157 [==============================] - 792s 5s/step - loss: 1.9803 - accuracy: 0.9948 - val_loss: 1.9922 - val_accuracy: 0.9630
# Epoch 30/40
# 157/157 [==============================] - 793s 5s/step - loss: 1.8637 - accuracy: 0.9946 - val_loss: 1.8830 - val_accuracy: 0.9620
# Epoch 31/40
# 157/157 [==============================] - 794s 5s/step - loss: 1.7517 - accuracy: 0.9949 - val_loss: 1.7624 - val_accuracy: 0.9625
# Epoch 32/40
# 157/157 [==============================] - 782s 5s/step - loss: 1.6393 - accuracy: 0.9984 - val_loss: 1.7301 - val_accuracy: 0.9445
# Epoch 33/40
# 157/157 [==============================] - 791s 5s/step - loss: 1.5403 - accuracy: 0.9987 - val_loss: 1.5579 - val_accuracy: 0.9705
# Epoch 34/40
# 157/157 [==============================] - 784s 5s/step - loss: 1.4438 - accuracy: 0.9998 - val_loss: 1.4601 - val_accuracy: 0.9730
# Epoch 35/40
# 157/157 [==============================] - 789s 5s/step - loss: 1.3552 - accuracy: 0.9998 - val_loss: 1.3854 - val_accuracy: 0.9705
# Epoch 36/40
# 157/157 [==============================] - 795s 5s/step - loss: 1.2714 - accuracy: 1.0000 - val_loss: 1.3289 - val_accuracy: 0.9670
# Epoch 37/40
# 157/157 [==============================] - 789s 5s/step - loss: 1.1973 - accuracy: 0.9992 - val_loss: 1.2579 - val_accuracy: 0.9630
# Epoch 38/40
# 157/157 [==============================] - 785s 5s/step - loss: 1.1250 - accuracy: 0.9993 - val_loss: 1.1864 - val_accuracy: 0.9630
# Epoch 39/40
# 157/157 [==============================] - 796s 5s/step - loss: 1.0559 - accuracy: 0.9993 - val_loss: 1.1008 - val_accuracy: 0.9730
# Epoch 40/40
# 157/157 [==============================] - 794s 5s/step - loss: 0.9900 - accuracy: 1.0000 - val_loss: 1.0345 - val_accuracy: 0.9715
# 63/63 [==============================] - 35s 562ms/step - loss: 0.9890 - accuracy: 0.9845
# 0.984499990940094
# 989 11 20 980
# TPR/Recall: 0.98
# TNR/Specificity: 0.989
# PPV/Precision: 0.9889001009081736
# NPV: 0.9801783944499505

# %%
model_test_weight_batch_normalization, accuracy = train_data_weight_batch(X_train, X_val, X_test, y_train, y_val, y_test, 0.01, 40)
print(accuracy)
y_pred = model_test_weight_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-760af9436935> in <module>
# ----> 1 model_test_weight_batch_normalization, accuracy = train_data_weight_batch(X_train, X_val, X_test, y_train, y_val, y_test, 0.01, 40)
#       2 print(accuracy)
#       3 y_pred = model_test_weight_batch_normalization.predict(X_test)
#       4 y_pred_val = y_pred.argmax(axis=1)
#       5 y_test_val = y_test.argmax(axis=1)
#
# <ipython-input-14-8877e2ff8f63> in train_data_weight_batch(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs)
#       1 def train_data_weight_batch(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
#       2   # define model
# ----> 3   model = define_model_dropout_regularization_batch_normalization(learning_rate)
#       4   # define early stopping
#       5   es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
#
# NameError: name 'define_model_dropout_regularization_batch_normalization' is not defined

# %% [markdown]
# ### Train Data with Data Augmentation, Weight Regularization and Batch Normalization

# %%
def train_data_augmentation_weight_batch(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model_weight_regularization_batch_normalization(learning_rate)
  # create data generator
  datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
  # prepare iterator
  it_train = datagen.flow(X_train, y_train, batch_size=64)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
	# fit model  
  steps = int(X_train.shape[0] / 64)
  history = model.fit(it_train, epochs=epochs, steps_per_epoch=steps, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_data_weight_batch_normalization, accuracy = train_data_augmentation_weight_batch(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 30)
print(accuracy)
y_pred = model_test_data_weight_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))
