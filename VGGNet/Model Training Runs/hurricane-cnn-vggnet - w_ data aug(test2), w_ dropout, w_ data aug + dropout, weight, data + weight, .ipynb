# %% [markdown]
# # Imports

# %%
import numpy as np
import glob
from PIL import Image
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from tensorflow.keras import optimizers
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import KFold
import pandas as pd
import seaborn as sn
sn.set(font_scale=1.4) # for label size
import multiprocessing as mp
import csv

# %% [markdown]
# # Load DataSet
#
# 0 means unlikely to have flood damage, 1 means likely to have flood damage
#
# [0,1] --> damage
#
# [1,0] --> no damage

# %% [markdown]
# ## Load Training Set

# %%
images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/train_another/damage/*.jpeg')
dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  dmg_img.append(im_arr)
dmg_img = np.array(dmg_img)

images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/train_another/no_damage/*.jpeg')
no_dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  no_dmg_img.append(im_arr)
no_dmg_img = np.array(no_dmg_img)

X_train = np.concatenate((dmg_img, no_dmg_img))
dmg_img_y = np.array(dmg_img.shape[0] * [[0,1]])
no_dmg_img_y = np.array(no_dmg_img.shape[0] * [[1,0]])
y_train = np.concatenate((dmg_img_y, no_dmg_img_y))

# shuffle arrays so that the array is a mix of damage and no_damage in a random order
shuffler = np.random.permutation(X_train.shape[0])
X_train = X_train[shuffler]
y_train = y_train[shuffler]

# %% [markdown]
# ## Load Validation Set

# %%
images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/validation_another/damage/*.jpeg')
dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  dmg_img.append(im_arr)
dmg_img = np.array(dmg_img)

images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/validation_another/no_damage/*.jpeg')
no_dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  no_dmg_img.append(im_arr)
no_dmg_img = np.array(no_dmg_img)

X_val = np.concatenate((dmg_img, no_dmg_img))
dmg_img_y = np.array(dmg_img.shape[0] * [[0,1]])
no_dmg_img_y = np.array(no_dmg_img.shape[0] * [[1,0]])
y_val = np.concatenate((dmg_img_y, no_dmg_img_y))

# shuffle arrays so that the array is a mix of damage and no_damage in a random order
shuffler = np.random.permutation(X_val.shape[0])
X_val = X_val[shuffler]
y_val = y_val[shuffler]

# %%
# combine training and validation data - for cross-validation
X_all = np.concatenate((X_train, X_val))
y_all = np.concatenate((y_train, y_val))

# %% [markdown]
# ## Load Test Set

# %%
images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/test/damage/*.jpeg')
dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  dmg_img.append(im_arr)
dmg_img = np.array(dmg_img)

images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/test/no_damage/*.jpeg')
no_dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  no_dmg_img.append(im_arr)
no_dmg_img = np.array(no_dmg_img)

X_test = np.concatenate((dmg_img, no_dmg_img))
dmg_img_y = np.array(dmg_img.shape[0] * [[0,1]])
no_dmg_img_y = np.array(no_dmg_img.shape[0] * [[1,0]])
y_test = np.concatenate((dmg_img_y, no_dmg_img_y))

# shuffle arrays so that the array is a mix of damage and no_damage in a random order
shuffler = np.random.permutation(X_val.shape[0])
X_test = X_test[shuffler]
y_test = y_test[shuffler]

# %% [markdown]
# ## Input/Output

# %%
# save a dictionary as a csv file
def output_as_csv(name, a):
    path = "/kaggle/working/" + name + ".csv"
    with open(path, 'w') as csv_file:
        # create the csv writer
        writer = csv.writer(csv_file)

        # write a row to the csv file
        writer.writerow(a.keys())
        writer.writerow(a.values())

# input a csv file
def input_csv(path):
    b, keys = {}, {}
    with open(path, mode='r') as csv_file:
        csv_reader = csv.DictReader(csv_file)
        line_count = 0
        for row in csv_reader:
            keys = row
    b = dict(keys)
    return b # returns a dictionary

# %% [markdown]
# # Pre-Process DataSet

# %%
# pre-process data 
def scale_pixels(train, val, test, X_all):
	# convert from integers to floats and normalize between 0-1
  train_norm = train.astype('float32') / 255.0
  val_norm = val.astype('float32') / 255.0
  test_norm = test.astype('float32') / 255.0
  X_all_norm = X_all.astype('float32') / 255.0
	# return normalized images
  return train_norm, val_norm, test_norm, X_all_norm

X_train, X_val, X_test, X_all = scale_pixels(X_train, X_val, X_test, X_all)

# %% [markdown]
# # Plot Diagnostics

# %%
# plot diagnostic learning curves
def summarize_diagnostics(history):
  # blue = training data; orange = validation data
	# plot validation loss
	plt.subplot(211)
	plt.title('Cross Entropy Loss')
	plt.plot(history.history['loss'], color='blue', label='train')
	plt.plot(history.history['val_loss'], color='orange', label='validation')
	# plot accuracy
	plt.subplot(212)
	plt.title('Classification Accuracy')
	plt.plot(history.history['accuracy'], color='blue', label='train')
	plt.plot(history.history['val_accuracy'], color='orange', label='validation')

# %%
# returns the confusion matrix
def find_confusion_matrix(model, X_test, y_test):
    y_pred = model.predict(X_test)
    y_pred_val = y_pred.argmax(axis=1)
    y_test_val = y_test.argmax(axis=1)
    return confusion_matrix(y_test_val, y_pred_val)

# returns the confusion matrix based on tn, fn, fp, tp
def find_confusion_matrix_2(tn, fn, fp, tp):
    return [[tn, fp], [fn, tp]]

# generate heat map for confusion matrix
def heatmap(confusion_matrix):
    df = pd.DataFrame(confusion_matrix, index = ['F', 'T'], columns = ['F', 'T'])
    sn.heatmap(df, annot=True) # create a heatmap
    
# returns normalized confusion matrix
def normalize_confusion_matrix(confusion_matrix):
    confusion_matrix = np.array(confusion_matrix)
    confusion_matrix_sum = confusion_matrix.astype(np.float).sum(axis=1)
    confusion_matrix_norm = confusion_matrix.astype(np.float)
    confusion_matrix_norm[0] = confusion_matrix_norm[0] / confusion_matrix_sum[0]
    confusion_matrix_norm[1] = confusion_matrix_norm[1] / confusion_matrix_sum[1]
    return confusion_matrix_norm

def print_confusion_matrix_results(results):
    # results is a dictionary
    # calculate mean and standard deviation for each key
    for key in results:
        mean = np.mean(results[key])
        std = np.std(results[key])
        print("{} mean: {}".format(key, mean))
        print("{} std: {}".format(key, std))

# %% [markdown]
# # Create CNN Model

# %%
# define cnn model
def define_model(learning_rate):
  model = keras.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(128, 128, 3)))
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Flatten())
  model.add(layers.Dense(128, activation='relu', kernel_initializer='he_uniform'))
  model.add(layers.Dense(2, activation='softmax'))  # compile model
  opt = optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
  model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
  return model

# %% [markdown]
# ## CNN Model with Batch Normalization

# %%
# define cnn model
def define_model_batch_normalization(learning_rate):
  model = keras.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(128, 128, 3)))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Flatten())
  model.add(layers.Dense(128, activation='relu', kernel_initializer='he_uniform'))
  model.add(layers.BatchNormalization())
  model.add(layers.Dense(2, activation='softmax'))  # compile model
  opt = optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
  model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
  return model

# %% [markdown]
# ## CNN Model with Dropout Regularization

# %%
# define cnn model
def define_model_dropout_regularization(learning_rate):
  model = keras.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(128, 128, 3)))
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.2)) # retain 80% of neurons
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.3))
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.4))
  model.add(layers.Flatten())
  model.add(layers.Dense(128, activation='relu', kernel_initializer='he_uniform'))
  model.add(layers.Dropout(0.5))
  model.add(layers.Dense(2, activation='softmax'))  # compile model
  opt = optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
  model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
  return model

# %% [markdown]
# ### CNN Model with Dropout Regularization and Batch Normalization

# %%
# define cnn model
def define_model_dropout_regularization_batch_normalization(learning_rate):
  model = keras.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(128, 128, 3)))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.2)) # retain 80% of neurons
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.3))
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.4))
  model.add(layers.Flatten())
  model.add(layers.Dense(128, activation='relu', kernel_initializer='he_uniform'))
  model.add(layers.BatchNormalization())
  model.add(layers.Dropout(0.5))
  model.add(layers.Dense(2, activation='softmax'))  # compile model
  opt = optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
  model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
  return model

# %% [markdown]
# ## CNN Model with Weight Regularization

# %%
# define cnn model
def define_model_weight_regularization(learning_rate):
  model = keras.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.001), input_shape=(128, 128, 3)))
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.001)))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.001)))
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.001)))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.001)))
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.001)))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Flatten())
  model.add(layers.Dense(128, activation='relu', kernel_initializer='he_uniform', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.Dense(2, activation='softmax'))  # compile model
  opt = optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
  model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
  return model

# %% [markdown]
# ### CNN Model with Weight Regularization and Batch Normalization

# %%
# define cnn model
def define_model_weight_regularization_batch_normalization(learning_rate):
  model = keras.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.001), input_shape=(128, 128, 3)))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.001)))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.001)))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.001)))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.001)))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.001)))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Flatten())
  model.add(layers.Dense(128, activation='relu', kernel_initializer='he_uniform', kernel_regularizer=regularizers.l2(0.001)))
  model.add(layers.BatchNormalization())
  model.add(layers.Dense(2, activation='softmax'))  # compile model
  opt = optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
  model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
  return model

# %%
# define cnn model
def define_model_weight_regularization_batch_normalization2(learning_rate, regularization_lambda):
  model = keras.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(regularization_lambda), input_shape=(128, 128, 3)))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(regularization_lambda)))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(regularization_lambda)))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(regularization_lambda)))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(regularization_lambda)))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(regularization_lambda)))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Flatten())
  model.add(layers.Dense(128, activation='relu', kernel_initializer='he_uniform', kernel_regularizer=regularizers.l2(regularization_lambda)))
  model.add(layers.BatchNormalization())
  model.add(layers.Dense(2, activation='softmax'))  # compile model
  opt = optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
  model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
  return model

# %% [markdown]
# # Train Data
# Hyperparameters are inputted into the function

# %%
def train(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model(learning_rate)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
  # fit model
  history = model.fit(X_train, y_train, epochs=epochs, batch_size=64, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test, accuracy = train(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 75)
print(accuracy)
y_pred = model_test.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %% [markdown]
# ## Train Data w/ Cross Validation

# %%
def benchmark_model(X_all, y_all, split):
    X_train_cv, y_train_cv = X_all[split[0]], y_all[split[0]]
    X_val_cv, y_val_cv = X_all[split[1]], y_all[split[1]]
    model, accuracy = train(X_train_cv, X_val_cv, X_val_cv, y_train_cv, y_val_cv, y_val_cv, 0.001, 75) 
    results = {}
#     results["model"] = model
    results["accuracy"] = accuracy
    results["confusion_matrix"] = find_confusion_matrix(model, X_val_cv, y_val_cv)
    tn, fp, fn, tp = results["confusion_matrix"].ravel()
    results["tn"] = tn
    results["fp"] = fp
    results["fn"] = fn
    results["tp"] = tp
    results["TPR/Recall"] = tp/(tp+fn)
    results["TNR/Specificity"] = tn/(tn+fp)
    results["PPV/Precision"] = tp/(tp+fp)
    results["NPV"] = tn/(tn+fn)
    return results

# %%
kf = KFold(n_splits=5)
folds = list(kf.split(X_all, y_all))

# %%
output_as_csv("normal_fold_1", benchmark_model(X_all, y_all, folds[0]))

# %%
output_as_csv("normal_fold_2", benchmark_model(X_all, y_all, folds[1]))

# %%
output_as_csv("normal_fold_3", benchmark_model(X_all, y_all, folds[2]))

# %%
output_as_csv("normal_fold_4", benchmark_model(X_all, y_all, folds[3]))

# %%
output_as_csv("normal_fold_5", benchmark_model(X_all, y_all, folds[4]))

# %%
# results_list is a list of dictionaries
results_list = []
for i in range(1,6):
    path = "../input/hurricane-normal-cv/normal_fold_" + str(i) + ".csv"
    results_list.append(input_csv(path))

# results_dict is a dictionary of lists
results_dict = {}
results_dict["accuracy"] = [(float)(i["accuracy"]) for i in results_list]
results_dict["TPR/Recall"] = [(float)(i["TPR/Recall"]) for i in results_list]
results_dict["TNR/Specificity"] = [(float)(i["TNR/Specificity"]) for i in results_list]
results_dict["PPV/Precision"] = [(float)(i["PPV/Precision"]) for i in results_list]
results_dict["NPV"] = [(float)(i["NPV"]) for i in results_list]

print_confusion_matrix_results(results_dict)

# %%
# find confusion matrices
results_dict["tn"] = [(int)(i["tn"]) for i in results_list]
results_dict["fp"] = [(int)(i["fp"]) for i in results_list]
results_dict["fn"] = [(int)(i["fn"]) for i in results_list]
results_dict["tp"] = [(int)(i["tp"]) for i in results_list]
results_dict["confusion_matrix"] = []
# append confusion matrix for each cross-validation fold
for i in range(len(folds)):
    results_dict["confusion_matrix"].append(find_confusion_matrix_2(results_dict["tn"][i], results_dict["fp"][i], results_dict["fn"][i], results_dict["tp"][i]))
                                            
# total confusion matrix summed together
confusion_matrix_list = []
confusion_matrix_list = results_dict["confusion_matrix"]
confusion_matrix_comb = np.sum(confusion_matrix_list, axis=0)
heatmap(confusion_matrix_comb)

# %%
# normalized confusion matrix
confusion_matrix_norm = normalize_confusion_matrix(confusion_matrix_comb)
heatmap(confusion_matrix_norm)

# %% [markdown]
# ## Train Data with Batch Normalization

# %%
def train_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model_batch_normalization(learning_rate)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
  # fit model
  history = model.fit(X_train, y_train, epochs=epochs, batch_size=64, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_batch_normalization, accuracy = train_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 75)
print(accuracy)
y_pred = model_test_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %% [markdown]
# ### Tune Hyperparameters - learning rate

# %%
model_test_batch_normalization, accuracy = train_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, 0.0005, 75)
print(accuracy)
y_pred = model_test_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_batch_normalization, accuracy = train_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, 0.005, 40)
print(accuracy)
y_pred = model_test_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_batch_normalization, accuracy = train_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, 0.01, 40)
print(accuracy)
y_pred = model_test_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_batch_normalization, accuracy = train_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, 0.1, 40)
print(accuracy)
y_pred = model_test_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %% [markdown]
# ### Tune Hyperparameters - batch size

# %%
def train_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, batch_size, epochs):
  # define model
  model = define_model_batch_normalization(learning_rate)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
  # fit model
  history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_batch_normalization, accuracy = train_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, 0.005, 128, 40)
print(accuracy)
y_pred = model_test_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_batch_normalization, accuracy = train_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, 0.005, 32, 40)
print(accuracy)
y_pred = model_test_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_batch_normalization, accuracy = train_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, 0.005, 256, 40)
print(accuracy)
y_pred = model_test_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %% [markdown]
# ### Train Data with Batch Normalization and Cross Validation

# %%
def benchmark_model_batch_normalization(X_all, y_all, split):
    X_train_cv, y_train_cv = X_all[split[0]], y_all[split[0]]
    X_val_cv, y_val_cv = X_all[split[1]], y_all[split[1]]
    model, accuracy = train_batch_normalization(X_train_cv, X_val_cv, X_val_cv, y_train_cv, y_val_cv, y_val_cv, 0.001, 40) 
    results = {}
#     results["model"] = model
    results["accuracy"] = accuracy
    results["confusion_matrix"] = find_confusion_matrix(model, X_val_cv, y_val_cv)
    tn, fp, fn, tp = results["confusion_matrix"].ravel()
    results["tn"] = tn
    results["fp"] = fp
    results["fn"] = fn
    results["tp"] = tp
    results["TPR/Recall"] = tp/(tp+fn)
    results["TNR/Specificity"] = tn/(tn+fp)
    results["PPV/Precision"] = tp/(tp+fp)
    results["NPV"] = tn/(tn+fn)
    return results

# %%
kf = KFold(n_splits=5)
folds = list(kf.split(X_all, y_all))

# %%
output_as_csv("batch normalization fold 1", benchmark_model_batch_normalization(X_all, y_all, folds[0]))

# %%
output_as_csv("batch normalization fold 2", benchmark_model_batch_normalization(X_all, y_all, folds[1]))

# %%
output_as_csv("batch normalization fold 3", benchmark_model_batch_normalization(X_all, y_all, folds[2]))

# %%
output_as_csv("batch normalization fold 4", benchmark_model_batch_normalization(X_all, y_all, folds[3]))

# %%
output_as_csv("batch normalization fold 5", benchmark_model_batch_normalization(X_all, y_all, folds[4]))

# %%
# results_list is a list of dictionaries
results_list = []
for i in range(1,6):
    path = "../input/hurricane-vgg-batch-cv/batch normalization fold " + str(i) + ".csv"
    results_list.append(input_csv(path))

# results_dict is a dictionary of lists
results_dict = {}
results_dict["accuracy"] = [(float)(i["accuracy"]) for i in results_list]
results_dict["TPR/Recall"] = [(float)(i["TPR/Recall"]) for i in results_list]
results_dict["TNR/Specificity"] = [(float)(i["TNR/Specificity"]) for i in results_list]
results_dict["PPV/Precision"] = [(float)(i["PPV/Precision"]) for i in results_list]
results_dict["NPV"] = [(float)(i["NPV"]) for i in results_list]

print_confusion_matrix_results(results_dict)

# %%
# find confusion matrices
results_dict["tn"] = [(int)(i["tn"]) for i in results_list]
results_dict["fp"] = [(int)(i["fp"]) for i in results_list]
results_dict["fn"] = [(int)(i["fn"]) for i in results_list]
results_dict["tp"] = [(int)(i["tp"]) for i in results_list]
results_dict["confusion_matrix"] = []
# append confusion matrix for each cross-validation fold
for i in range(len(folds)):
    results_dict["confusion_matrix"].append(find_confusion_matrix_2(results_dict["tn"][i], results_dict["fp"][i], results_dict["fn"][i], results_dict["tp"][i]))
                                            
# total confusion matrix summed together
confusion_matrix_list = []
confusion_matrix_list = results_dict["confusion_matrix"]
confusion_matrix_comb = np.sum(confusion_matrix_list, axis=0)
heatmap(confusion_matrix_comb)

# %%
# normalized confusion matrix
confusion_matrix_norm = normalize_confusion_matrix(confusion_matrix_comb)
heatmap(confusion_matrix_norm)

# %% [markdown]
# ## Train Data with Data Augmentation

# %%
def train_data_augmentation(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model(learning_rate)
  # create data generator
  datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
  # prepare iterator
  it_train = datagen.flow(X_train, y_train, batch_size=64)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=8, verbose=1)
	# fit model
  steps = int(X_train.shape[0] / 64)
  history = model.fit(it_train, epochs=epochs, steps_per_epoch=steps, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_data, accuracy = train_data_augmentation(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 40)
print(accuracy)
y_pred = model_test_data.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))
# Out:
# Epoch 1/40
# 156/156 [==============================] - 625s 4s/step - loss: 0.6667 - accuracy: 0.5764 - val_loss: 0.5565 - val_accuracy: 0.7885
# Epoch 2/40
# 156/156 [==============================] - 614s 4s/step - loss: 0.5576 - accuracy: 0.7429 - val_loss: 0.4959 - val_accuracy: 0.7965
# Epoch 3/40
# 156/156 [==============================] - 615s 4s/step - loss: 0.4605 - accuracy: 0.8097 - val_loss: 0.3600 - val_accuracy: 0.8615
# Epoch 4/40
# 156/156 [==============================] - 615s 4s/step - loss: 0.3839 - accuracy: 0.8527 - val_loss: 0.3252 - val_accuracy: 0.8740
# Epoch 5/40
# 156/156 [==============================] - 615s 4s/step - loss: 0.3558 - accuracy: 0.8593 - val_loss: 0.2956 - val_accuracy: 0.8880
# Epoch 6/40
# 156/156 [==============================] - 614s 4s/step - loss: 0.3318 - accuracy: 0.8646 - val_loss: 0.2631 - val_accuracy: 0.8935
# Epoch 7/40
# 156/156 [==============================] - 611s 4s/step - loss: 0.2975 - accuracy: 0.8739 - val_loss: 0.2357 - val_accuracy: 0.9035
# Epoch 8/40
# 156/156 [==============================] - 613s 4s/step - loss: 0.2638 - accuracy: 0.8942 - val_loss: 0.2256 - val_accuracy: 0.9120
# Epoch 9/40
# 156/156 [==============================] - 614s 4s/step - loss: 0.2274 - accuracy: 0.9060 - val_loss: 0.2104 - val_accuracy: 0.9090
# Epoch 10/40
# 156/156 [==============================] - 614s 4s/step - loss: 0.2246 - accuracy: 0.9068 - val_loss: 0.2676 - val_accuracy: 0.8875
# Epoch 11/40
# 156/156 [==============================] - 611s 4s/step - loss: 0.2105 - accuracy: 0.9111 - val_loss: 0.2186 - val_accuracy: 0.9260
# Epoch 12/40
# 156/156 [==============================] - 610s 4s/step - loss: 0.2018 - accuracy: 0.9216 - val_loss: 0.2121 - val_accuracy: 0.9180
# Epoch 13/40
# 156/156 [==============================] - 610s 4s/step - loss: 0.1921 - accuracy: 0.9190 - val_loss: 0.1936 - val_accuracy: 0.9225
# Epoch 14/40
# 156/156 [==============================] - 611s 4s/step - loss: 0.1730 - accuracy: 0.9333 - val_loss: 0.1714 - val_accuracy: 0.9385
# Epoch 15/40
# 156/156 [==============================] - 610s 4s/step - loss: 0.1637 - accuracy: 0.9369 - val_loss: 0.1955 - val_accuracy: 0.9270
# Epoch 16/40
# 156/156 [==============================] - 613s 4s/step - loss: 0.1584 - accuracy: 0.9413 - val_loss: 0.1522 - val_accuracy: 0.9400
# Epoch 17/40
# 156/156 [==============================] - 614s 4s/step - loss: 0.1485 - accuracy: 0.9416 - val_loss: 0.1480 - val_accuracy: 0.9425
# Epoch 18/40
# 156/156 [==============================] - 615s 4s/step - loss: 0.1443 - accuracy: 0.9434 - val_loss: 0.1345 - val_accuracy: 0.9485
# Epoch 19/40
# 156/156 [==============================] - 614s 4s/step - loss: 0.1439 - accuracy: 0.9456 - val_loss: 0.1516 - val_accuracy: 0.9420
# Epoch 20/40
# 156/156 [==============================] - 612s 4s/step - loss: 0.1353 - accuracy: 0.9476 - val_loss: 0.1373 - val_accuracy: 0.9450
# Epoch 21/40
# 156/156 [==============================] - 612s 4s/step - loss: 0.1328 - accuracy: 0.9491 - val_loss: 0.1319 - val_accuracy: 0.9515
# Epoch 22/40
# 156/156 [==============================] - 611s 4s/step - loss: 0.1215 - accuracy: 0.9507 - val_loss: 0.1568 - val_accuracy: 0.9385
# Epoch 23/40
# 156/156 [==============================] - 609s 4s/step - loss: 0.1253 - accuracy: 0.9530 - val_loss: 0.1663 - val_accuracy: 0.9370
# Epoch 24/40
# 156/156 [==============================] - 611s 4s/step - loss: 0.1104 - accuracy: 0.9574 - val_loss: 0.1165 - val_accuracy: 0.9530
# Epoch 25/40
# 156/156 [==============================] - 609s 4s/step - loss: 0.1194 - accuracy: 0.9550 - val_loss: 0.1122 - val_accuracy: 0.9565
# Epoch 26/40
# 156/156 [==============================] - 609s 4s/step - loss: 0.1070 - accuracy: 0.9572 - val_loss: 0.1449 - val_accuracy: 0.9450
# Epoch 27/40
# 156/156 [==============================] - 609s 4s/step - loss: 0.1045 - accuracy: 0.9604 - val_loss: 0.1218 - val_accuracy: 0.9490
# Epoch 28/40
# 156/156 [==============================] - 610s 4s/step - loss: 0.1099 - accuracy: 0.9571 - val_loss: 0.1075 - val_accuracy: 0.9560
# Epoch 29/40
# 156/156 [==============================] - 611s 4s/step - loss: 0.1070 - accuracy: 0.9585 - val_loss: 0.1578 - val_accuracy: 0.9380
# Epoch 30/40
# 156/156 [==============================] - 610s 4s/step - loss: 0.1097 - accuracy: 0.9576 - val_loss: 0.1769 - val_accuracy: 0.9380
# Epoch 31/40
# 156/156 [==============================] - 609s 4s/step - loss: 0.1054 - accuracy: 0.9574 - val_loss: 0.1034 - val_accuracy: 0.9620
# Epoch 32/40
# 156/156 [==============================] - 609s 4s/step - loss: 0.1032 - accuracy: 0.9610 - val_loss: 0.1048 - val_accuracy: 0.9570
# Epoch 33/40
# 156/156 [==============================] - 611s 4s/step - loss: 0.1059 - accuracy: 0.9606 - val_loss: 0.1020 - val_accuracy: 0.9590
# Epoch 34/40
# 156/156 [==============================] - 609s 4s/step - loss: 0.0892 - accuracy: 0.9667 - val_loss: 0.0997 - val_accuracy: 0.9645
# Epoch 35/40
# 156/156 [==============================] - 610s 4s/step - loss: 0.0951 - accuracy: 0.9627 - val_loss: 0.1133 - val_accuracy: 0.9550
# Epoch 36/40
# 156/156 [==============================] - 610s 4s/step - loss: 0.0939 - accuracy: 0.9633 - val_loss: 0.1385 - val_accuracy: 0.9520
# Epoch 37/40
# 156/156 [==============================] - 607s 4s/step - loss: 0.0913 - accuracy: 0.9635 - val_loss: 0.1236 - val_accuracy: 0.9525
# Epoch 38/40
# 156/156 [==============================] - 609s 4s/step - loss: 0.0938 - accuracy: 0.9657 - val_loss: 0.0929 - val_accuracy: 0.9665
# Epoch 39/40
# 156/156 [==============================] - 609s 4s/step - loss: 0.0878 - accuracy: 0.9640 - val_loss: 0.0977 - val_accuracy: 0.9635
# Epoch 40/40
# 156/156 [==============================] - 610s 4s/step - loss: 0.0795 - accuracy: 0.9711 - val_loss: 0.1055 - val_accuracy: 0.9610
# 63/63 [==============================] - 29s 458ms/step - loss: 0.0958 - accuracy: 0.9625
# 0.9624999761581421
# 962 38 37 963
# TPR/Recall: 0.963
# TNR/Specificity: 0.962
# PPV/Precision: 0.962037962037962
# NPV: 0.9629629629629629

# %% [markdown]
# ### Train Data with Data Augmentation and Batch Normalization

# %%
def train_data_augmentation_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model_batch_normalization(learning_rate)
  # create data generator
  datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
  # prepare iterator
  it_train = datagen.flow(X_train, y_train, batch_size=64)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
	# fit model  
  steps = int(X_train.shape[0] / 64)
  history = model.fit(it_train, epochs=epochs, steps_per_epoch=steps, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_data_augmentation_batch_normalization, accuracy = train_data_augmentation_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 100)
print(accuracy)
y_pred = model_test_data_augmentation_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %% [markdown]
# ## Train Data with Dropout Regularization

# %%
def train_data_dropout(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model_dropout_regularization(learning_rate)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
  # fit model
  history = model.fit(X_train, y_train, epochs=epochs, batch_size=64, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_data_dropout, accuracy = train_data_dropout(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 40)
print(accuracy)
y_pred = model_test_data_dropout.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))
# Out:
# Epoch 1/40
# 157/157 [==============================] - 612s 4s/step - loss: 0.7704 - accuracy: 0.5046 - val_loss: 0.6915 - val_accuracy: 0.5570
# Epoch 2/40
# 157/157 [==============================] - 619s 4s/step - loss: 0.6891 - accuracy: 0.5194 - val_loss: 0.6916 - val_accuracy: 0.5210
# Epoch 3/40
# 157/157 [==============================] - 621s 4s/step - loss: 0.6832 - accuracy: 0.5547 - val_loss: 0.6921 - val_accuracy: 0.5015
# Epoch 4/40
# 157/157 [==============================] - 620s 4s/step - loss: 0.6700 - accuracy: 0.5837 - val_loss: 0.7066 - val_accuracy: 0.5000
# Epoch 5/40
# 157/157 [==============================] - 614s 4s/step - loss: 0.6270 - accuracy: 0.6627 - val_loss: 0.7065 - val_accuracy: 0.5305
# Epoch 6/40
# 157/157 [==============================] - 615s 4s/step - loss: 0.5330 - accuracy: 0.7684 - val_loss: 0.5770 - val_accuracy: 0.6675
# Epoch 7/40
# 157/157 [==============================] - 614s 4s/step - loss: 0.4522 - accuracy: 0.8267 - val_loss: 0.6569 - val_accuracy: 0.6735
# Epoch 8/40
# 157/157 [==============================] - 614s 4s/step - loss: 0.4007 - accuracy: 0.8522 - val_loss: 0.5118 - val_accuracy: 0.7630
# Epoch 9/40
# 157/157 [==============================] - 614s 4s/step - loss: 0.3403 - accuracy: 0.8698 - val_loss: 0.4617 - val_accuracy: 0.8050
# Epoch 10/40
# 157/157 [==============================] - 615s 4s/step - loss: 0.3174 - accuracy: 0.8822 - val_loss: 0.2350 - val_accuracy: 0.9100
# Epoch 11/40
# 157/157 [==============================] - 611s 4s/step - loss: 0.3391 - accuracy: 0.8722 - val_loss: 0.2599 - val_accuracy: 0.8995
# Epoch 12/40
# 157/157 [==============================] - 613s 4s/step - loss: 0.2619 - accuracy: 0.9034 - val_loss: 0.2402 - val_accuracy: 0.9050
# Epoch 13/40
# 157/157 [==============================] - 610s 4s/step - loss: 0.2504 - accuracy: 0.9022 - val_loss: 0.2964 - val_accuracy: 0.8815
# Epoch 14/40
# 157/157 [==============================] - 612s 4s/step - loss: 0.2410 - accuracy: 0.9041 - val_loss: 0.2491 - val_accuracy: 0.8985
# Epoch 15/40
# 157/157 [==============================] - 610s 4s/step - loss: 0.1978 - accuracy: 0.9207 - val_loss: 0.2103 - val_accuracy: 0.9130
# Epoch 16/40
# 157/157 [==============================] - 611s 4s/step - loss: 0.1937 - accuracy: 0.9206 - val_loss: 0.1517 - val_accuracy: 0.9370
# Epoch 17/40
# 157/157 [==============================] - 611s 4s/step - loss: 0.1763 - accuracy: 0.9257 - val_loss: 0.1410 - val_accuracy: 0.9500
# Epoch 18/40
# 157/157 [==============================] - 612s 4s/step - loss: 0.1742 - accuracy: 0.9319 - val_loss: 0.1499 - val_accuracy: 0.9460
# Epoch 19/40
# 157/157 [==============================] - 610s 4s/step - loss: 0.1565 - accuracy: 0.9340 - val_loss: 0.1951 - val_accuracy: 0.9190
# Epoch 20/40
# 157/157 [==============================] - 612s 4s/step - loss: 0.1468 - accuracy: 0.9403 - val_loss: 0.1500 - val_accuracy: 0.9480
# Epoch 21/40
# 157/157 [==============================] - 611s 4s/step - loss: 0.1608 - accuracy: 0.9362 - val_loss: 0.1670 - val_accuracy: 0.9250
# Epoch 22/40
# 157/157 [==============================] - 609s 4s/step - loss: 0.1651 - accuracy: 0.9311 - val_loss: 0.1482 - val_accuracy: 0.9325
# Epoch 00022: early stopping
# 63/63 [==============================] - 29s 454ms/step - loss: 0.1534 - accuracy: 0.9330
# 0.9330000281333923
# 878 122 12 988
# TPR/Recall: 0.988
# TNR/Specificity: 0.878
# PPV/Precision: 0.8900900900900901
# NPV: 0.9865168539325843

# %% [markdown]
# ## Train Data with Dropout Regularization and Batch Normalization

# %%
def train_data_dropout_batch(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model_dropout_regularization_batch_normalization(learning_rate)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
  # fit model
  history = model.fit(X_train, y_train, epochs=epochs, batch_size=64, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_data_dropout_batch_normalization, accuracy = train_data_dropout_batch(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 40)
print(accuracy)
y_pred = model_test_data_dropout_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %% [markdown]
# ## Train Data with Data Augmentation and Dropout Regularization

# %%
def train_data_augmentation_dropout(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model_dropout_regularization(learning_rate)
  # create data generator
  datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
  # prepare iterator
  it_train = datagen.flow(X_train, y_train, batch_size=64)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
	# fit model  
  steps = int(X_train.shape[0] / 64)
  history = model.fit(it_train, epochs=epochs, steps_per_epoch=steps, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_data_dropout, accuracy = train_data_augmentation_dropout(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 100)
print(accuracy)
y_pred = model_test_data_dropout.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))
# Out:
# Epoch 1/100
# 156/156 [==============================] - 44s 234ms/step - loss: 0.7843 - accuracy: 0.5073 - val_loss: 0.6910 - val_accuracy: 0.5455
# Epoch 2/100
# 156/156 [==============================] - 36s 228ms/step - loss: 0.6891 - accuracy: 0.5264 - val_loss: 0.6903 - val_accuracy: 0.6110
# Epoch 3/100
# 156/156 [==============================] - 37s 237ms/step - loss: 0.6863 - accuracy: 0.5395 - val_loss: 0.6865 - val_accuracy: 0.5510
# Epoch 4/100
# 156/156 [==============================] - 37s 236ms/step - loss: 0.6759 - accuracy: 0.5827 - val_loss: 0.6856 - val_accuracy: 0.5195
# Epoch 5/100
# 156/156 [==============================] - 36s 232ms/step - loss: 0.6578 - accuracy: 0.6120 - val_loss: 0.6197 - val_accuracy: 0.6490
# Epoch 6/100
# 156/156 [==============================] - 36s 230ms/step - loss: 0.5766 - accuracy: 0.7343 - val_loss: 0.6807 - val_accuracy: 0.5655
# Epoch 7/100
# 156/156 [==============================] - 35s 226ms/step - loss: 0.5178 - accuracy: 0.7744 - val_loss: 0.5934 - val_accuracy: 0.6485
# Epoch 8/100
# 156/156 [==============================] - 36s 228ms/step - loss: 0.4759 - accuracy: 0.7999 - val_loss: 0.3564 - val_accuracy: 0.8575
# Epoch 9/100
# 156/156 [==============================] - 36s 231ms/step - loss: 0.3936 - accuracy: 0.8466 - val_loss: 0.3281 - val_accuracy: 0.8680
# Epoch 10/100
# 156/156 [==============================] - 36s 232ms/step - loss: 0.3724 - accuracy: 0.8547 - val_loss: 0.3170 - val_accuracy: 0.8685
# Epoch 11/100
# 156/156 [==============================] - 36s 231ms/step - loss: 0.3469 - accuracy: 0.8689 - val_loss: 0.2980 - val_accuracy: 0.8770
# Epoch 12/100
# 156/156 [==============================] - 36s 230ms/step - loss: 0.3454 - accuracy: 0.8644 - val_loss: 0.2842 - val_accuracy: 0.8810
# Epoch 13/100
# 156/156 [==============================] - 35s 226ms/step - loss: 0.3301 - accuracy: 0.8738 - val_loss: 0.2926 - val_accuracy: 0.8755
# Epoch 14/100
# 156/156 [==============================] - 36s 228ms/step - loss: 0.3285 - accuracy: 0.8765 - val_loss: 0.3033 - val_accuracy: 0.8880
# Epoch 15/100
# 156/156 [==============================] - 36s 232ms/step - loss: 0.3162 - accuracy: 0.8726 - val_loss: 0.2698 - val_accuracy: 0.8920
# Epoch 16/100
# 156/156 [==============================] - 36s 228ms/step - loss: 0.3041 - accuracy: 0.8835 - val_loss: 0.2514 - val_accuracy: 0.8930
# Epoch 17/100
# 156/156 [==============================] - 36s 228ms/step - loss: 0.2972 - accuracy: 0.8850 - val_loss: 0.2827 - val_accuracy: 0.8760
# Epoch 18/100
# 156/156 [==============================] - 36s 228ms/step - loss: 0.2966 - accuracy: 0.8883 - val_loss: 0.2382 - val_accuracy: 0.9005
# Epoch 19/100
# 156/156 [==============================] - 36s 228ms/step - loss: 0.2912 - accuracy: 0.8925 - val_loss: 0.2514 - val_accuracy: 0.8975
# Epoch 20/100
# 156/156 [==============================] - 35s 227ms/step - loss: 0.2744 - accuracy: 0.8976 - val_loss: 0.2298 - val_accuracy: 0.9060
# Epoch 21/100
# 156/156 [==============================] - 36s 227ms/step - loss: 0.2694 - accuracy: 0.8972 - val_loss: 0.2251 - val_accuracy: 0.9095
# Epoch 22/100
# 156/156 [==============================] - 36s 227ms/step - loss: 0.2689 - accuracy: 0.9009 - val_loss: 0.2251 - val_accuracy: 0.9105
# Epoch 23/100
# 156/156 [==============================] - 36s 229ms/step - loss: 0.2504 - accuracy: 0.9043 - val_loss: 0.2118 - val_accuracy: 0.9175
# Epoch 24/100
# 156/156 [==============================] - 36s 229ms/step - loss: 0.2549 - accuracy: 0.9041 - val_loss: 0.2093 - val_accuracy: 0.9180
# Epoch 25/100
# 156/156 [==============================] - 36s 230ms/step - loss: 0.2473 - accuracy: 0.9002 - val_loss: 0.2065 - val_accuracy: 0.9190
# Epoch 26/100
# 156/156 [==============================] - 36s 232ms/step - loss: 0.2429 - accuracy: 0.9102 - val_loss: 0.2263 - val_accuracy: 0.9110
# Epoch 27/100
# 156/156 [==============================] - 36s 228ms/step - loss: 0.2457 - accuracy: 0.9050 - val_loss: 0.2832 - val_accuracy: 0.8945
# Epoch 28/100
# 156/156 [==============================] - 36s 228ms/step - loss: 0.2435 - accuracy: 0.9063 - val_loss: 0.2010 - val_accuracy: 0.9250
# Epoch 29/100
# 156/156 [==============================] - 36s 230ms/step - loss: 0.2417 - accuracy: 0.9086 - val_loss: 0.2030 - val_accuracy: 0.9230
# Epoch 30/100
# 156/156 [==============================] - 37s 231ms/step - loss: 0.2312 - accuracy: 0.9108 - val_loss: 0.2060 - val_accuracy: 0.9215
# Epoch 31/100
# 156/156 [==============================] - 36s 230ms/step - loss: 0.2317 - accuracy: 0.9070 - val_loss: 0.1983 - val_accuracy: 0.9280
# Epoch 32/100
# 156/156 [==============================] - 36s 229ms/step - loss: 0.2231 - accuracy: 0.9134 - val_loss: 0.1872 - val_accuracy: 0.9290
# Epoch 33/100
# 156/156 [==============================] - 36s 230ms/step - loss: 0.2303 - accuracy: 0.9117 - val_loss: 0.2170 - val_accuracy: 0.9160
# Epoch 34/100
# 156/156 [==============================] - 36s 229ms/step - loss: 0.2098 - accuracy: 0.9179 - val_loss: 0.2032 - val_accuracy: 0.9210
# Epoch 35/100
# 156/156 [==============================] - 36s 229ms/step - loss: 0.2245 - accuracy: 0.9159 - val_loss: 0.1859 - val_accuracy: 0.9260
# Epoch 36/100
# 156/156 [==============================] - 35s 227ms/step - loss: 0.2219 - accuracy: 0.9161 - val_loss: 0.1914 - val_accuracy: 0.9280
# Epoch 37/100
# 156/156 [==============================] - 36s 230ms/step - loss: 0.2175 - accuracy: 0.9187 - val_loss: 0.1906 - val_accuracy: 0.9255
# Epoch 38/100
# 156/156 [==============================] - 35s 227ms/step - loss: 0.2147 - accuracy: 0.9199 - val_loss: 0.2227 - val_accuracy: 0.9145
# Epoch 39/100
# 156/156 [==============================] - 35s 226ms/step - loss: 0.2178 - accuracy: 0.9118 - val_loss: 0.1947 - val_accuracy: 0.9305
# Epoch 40/100
# 156/156 [==============================] - 36s 231ms/step - loss: 0.2024 - accuracy: 0.9209 - val_loss: 0.1970 - val_accuracy: 0.9285
# Epoch 00040: early stopping
# 63/63 [==============================] - 1s 8ms/step - loss: 0.2171 - accuracy: 0.9095
# 0.909500002861023
# 952 48 133 867
# TPR/Recall: 0.867
# TNR/Specificity: 0.952
# PPV/Precision: 0.9475409836065574
# NPV: 0.8774193548387097

# %% [markdown]
# ### Train Data with Data Augmentation, Dropout Regularization and Batch Normalization

# %%
def train_data_augmentation_dropout_batch(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model_weight_regularization_batch_normalization(learning_rate)
  # create data generator
  datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
  # prepare iterator
  it_train = datagen.flow(X_train, y_train, batch_size=64)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
	# fit model  
  steps = int(X_train.shape[0] / 64)
  history = model.fit(it_train, epochs=epochs, steps_per_epoch=steps, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_data_dropout_batch_normalization, accuracy = train_data_augmentation_dropout_batch(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 25)
print(accuracy)
y_pred = model_test_data_dropout_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %% [markdown]
# ## Train Data with Weight Regularization

# %%
def train_data_weight(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model_weight_regularization(learning_rate)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
  # fit model
  history = model.fit(X_train, y_train, epochs=epochs, batch_size=64, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_weight, accuracy = train_data_weight(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 100)
print(accuracy)
y_pred = model_test_weight.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))
# Out:
# Epoch 1/100
# 157/157 [==============================] - 8s 46ms/step - loss: 4.1043 - accuracy: 0.5727 - val_loss: 3.8353 - val_accuracy: 0.8255
# Epoch 2/100
# 157/157 [==============================] - 7s 43ms/step - loss: 3.7688 - accuracy: 0.8016 - val_loss: 3.6394 - val_accuracy: 0.8090
# Epoch 3/100
# 157/157 [==============================] - 7s 43ms/step - loss: 3.5541 - accuracy: 0.8218 - val_loss: 3.4063 - val_accuracy: 0.8450
# Epoch 4/100
# 157/157 [==============================] - 7s 44ms/step - loss: 3.3532 - accuracy: 0.8568 - val_loss: 3.1747 - val_accuracy: 0.8925
# Epoch 5/100
# 157/157 [==============================] - 7s 43ms/step - loss: 3.1731 - accuracy: 0.8724 - val_loss: 3.1646 - val_accuracy: 0.8290
# Epoch 6/100
# 157/157 [==============================] - 7s 43ms/step - loss: 3.0149 - accuracy: 0.8886 - val_loss: 2.8860 - val_accuracy: 0.9000
# Epoch 7/100
# 157/157 [==============================] - 7s 43ms/step - loss: 2.8762 - accuracy: 0.8930 - val_loss: 2.8331 - val_accuracy: 0.8815
# Epoch 8/100
# 157/157 [==============================] - 7s 43ms/step - loss: 2.7583 - accuracy: 0.8926 - val_loss: 2.6397 - val_accuracy: 0.9175
# Epoch 9/100
# 157/157 [==============================] - 7s 44ms/step - loss: 2.6037 - accuracy: 0.9147 - val_loss: 2.5189 - val_accuracy: 0.9160
# Epoch 10/100
# 157/157 [==============================] - 7s 44ms/step - loss: 2.4715 - accuracy: 0.9280 - val_loss: 2.3923 - val_accuracy: 0.9390
# Epoch 11/100
# 157/157 [==============================] - 7s 43ms/step - loss: 2.3615 - accuracy: 0.9380 - val_loss: 2.3177 - val_accuracy: 0.9360
# Epoch 12/100
# 157/157 [==============================] - 7s 43ms/step - loss: 2.2598 - accuracy: 0.9451 - val_loss: 2.1953 - val_accuracy: 0.9540
# Epoch 13/100
# 157/157 [==============================] - 7s 43ms/step - loss: 2.1549 - accuracy: 0.9545 - val_loss: 2.1859 - val_accuracy: 0.9215
# Epoch 14/100
# 157/157 [==============================] - 7s 44ms/step - loss: 2.0939 - accuracy: 0.9472 - val_loss: 2.0213 - val_accuracy: 0.9565
# Epoch 15/100
# 157/157 [==============================] - 7s 44ms/step - loss: 2.0016 - accuracy: 0.9585 - val_loss: 1.9846 - val_accuracy: 0.9435
# Epoch 16/100
# 157/157 [==============================] - 7s 44ms/step - loss: 1.9225 - accuracy: 0.9621 - val_loss: 1.8861 - val_accuracy: 0.9585
# Epoch 17/100
# 157/157 [==============================] - 7s 43ms/step - loss: 1.8520 - accuracy: 0.9627 - val_loss: 1.8464 - val_accuracy: 0.9460
# Epoch 18/100
# 157/157 [==============================] - 7s 44ms/step - loss: 1.7788 - accuracy: 0.9681 - val_loss: 1.7546 - val_accuracy: 0.9620
# Epoch 19/100
# 157/157 [==============================] - 7s 44ms/step - loss: 1.7199 - accuracy: 0.9694 - val_loss: 1.7065 - val_accuracy: 0.9595
# Epoch 20/100
# 157/157 [==============================] - 7s 43ms/step - loss: 1.6680 - accuracy: 0.9696 - val_loss: 1.6447 - val_accuracy: 0.9665
# Epoch 21/100
# 157/157 [==============================] - 7s 43ms/step - loss: 1.6094 - accuracy: 0.9714 - val_loss: 1.6456 - val_accuracy: 0.9420
# Epoch 22/100
# 157/157 [==============================] - 7s 43ms/step - loss: 1.5651 - accuracy: 0.9704 - val_loss: 1.5502 - val_accuracy: 0.9615
# Epoch 23/100
# 157/157 [==============================] - 7s 44ms/step - loss: 1.5154 - accuracy: 0.9712 - val_loss: 1.5089 - val_accuracy: 0.9565
# Epoch 24/100
# 157/157 [==============================] - 7s 44ms/step - loss: 1.4634 - accuracy: 0.9736 - val_loss: 1.4593 - val_accuracy: 0.9615
# Epoch 25/100
# 157/157 [==============================] - 7s 43ms/step - loss: 1.4300 - accuracy: 0.9710 - val_loss: 1.4217 - val_accuracy: 0.9580
# Epoch 26/100
# 157/157 [==============================] - 7s 43ms/step - loss: 1.3799 - accuracy: 0.9763 - val_loss: 1.3977 - val_accuracy: 0.9570
# Epoch 27/100
# 157/157 [==============================] - 7s 43ms/step - loss: 1.3456 - accuracy: 0.9755 - val_loss: 1.3537 - val_accuracy: 0.9620
# Epoch 28/100
# 157/157 [==============================] - 7s 44ms/step - loss: 1.3041 - accuracy: 0.9793 - val_loss: 1.3264 - val_accuracy: 0.9645
# Epoch 29/100
# 157/157 [==============================] - 7s 43ms/step - loss: 1.2728 - accuracy: 0.9763 - val_loss: 1.3096 - val_accuracy: 0.9500
# Epoch 30/100
# 157/157 [==============================] - 7s 43ms/step - loss: 1.2407 - accuracy: 0.9758 - val_loss: 1.2506 - val_accuracy: 0.9630
# Epoch 31/100
# 157/157 [==============================] - 7s 43ms/step - loss: 1.2130 - accuracy: 0.9767 - val_loss: 1.2282 - val_accuracy: 0.9660
# Epoch 32/100
# 157/157 [==============================] - 7s 44ms/step - loss: 1.1721 - accuracy: 0.9856 - val_loss: 1.2097 - val_accuracy: 0.9640
# Epoch 33/100
# 157/157 [==============================] - 7s 43ms/step - loss: 1.1491 - accuracy: 0.9824 - val_loss: 1.1879 - val_accuracy: 0.9570
# Epoch 34/100
# 157/157 [==============================] - 7s 43ms/step - loss: 1.1370 - accuracy: 0.9755 - val_loss: 1.1985 - val_accuracy: 0.9485
# Epoch 35/100
# 157/157 [==============================] - 7s 43ms/step - loss: 1.1084 - accuracy: 0.9798 - val_loss: 1.1374 - val_accuracy: 0.9570
# Epoch 36/100
# 157/157 [==============================] - 7s 44ms/step - loss: 1.0714 - accuracy: 0.9846 - val_loss: 1.1096 - val_accuracy: 0.9640
# Epoch 37/100
# 157/157 [==============================] - 7s 44ms/step - loss: 1.0487 - accuracy: 0.9847 - val_loss: 1.0808 - val_accuracy: 0.9645
# Epoch 38/100
# 157/157 [==============================] - 7s 43ms/step - loss: 1.0263 - accuracy: 0.9875 - val_loss: 1.0855 - val_accuracy: 0.9620
# Epoch 39/100
# 157/157 [==============================] - 7s 43ms/step - loss: 1.0340 - accuracy: 0.9757 - val_loss: 1.0723 - val_accuracy: 0.9605
# Epoch 40/100
# 157/157 [==============================] - 7s 44ms/step - loss: 0.9864 - accuracy: 0.9877 - val_loss: 1.0283 - val_accuracy: 0.9625
# Epoch 41/100
# 157/157 [==============================] - 7s 43ms/step - loss: 0.9799 - accuracy: 0.9820 - val_loss: 1.0201 - val_accuracy: 0.9570
# Epoch 42/100
# 157/157 [==============================] - 7s 44ms/step - loss: 0.9577 - accuracy: 0.9869 - val_loss: 0.9973 - val_accuracy: 0.9645
# Epoch 43/100
# 157/157 [==============================] - 7s 43ms/step - loss: 0.9339 - accuracy: 0.9892 - val_loss: 0.9839 - val_accuracy: 0.9640
# Epoch 44/100
# 157/157 [==============================] - 7s 43ms/step - loss: 0.9131 - accuracy: 0.9920 - val_loss: 1.0054 - val_accuracy: 0.9625
# Epoch 45/100
# 157/157 [==============================] - 7s 43ms/step - loss: 0.9056 - accuracy: 0.9891 - val_loss: 0.9597 - val_accuracy: 0.9640
# Epoch 46/100
# 157/157 [==============================] - 7s 43ms/step - loss: 0.8908 - accuracy: 0.9900 - val_loss: 0.9511 - val_accuracy: 0.9640
# Epoch 47/100
# 157/157 [==============================] - 7s 44ms/step - loss: 0.8774 - accuracy: 0.9891 - val_loss: 0.9247 - val_accuracy: 0.9660
# Epoch 48/100
# 157/157 [==============================] - 7s 44ms/step - loss: 0.8591 - accuracy: 0.9915 - val_loss: 0.9227 - val_accuracy: 0.9645
# Epoch 49/100
# 157/157 [==============================] - 7s 44ms/step - loss: 0.8610 - accuracy: 0.9831 - val_loss: 0.9283 - val_accuracy: 0.9635
# Epoch 50/100
# 157/157 [==============================] - 7s 43ms/step - loss: 0.8357 - accuracy: 0.9932 - val_loss: 0.9700 - val_accuracy: 0.9445
# Epoch 51/100
# 157/157 [==============================] - 7s 43ms/step - loss: 0.8574 - accuracy: 0.9771 - val_loss: 0.8988 - val_accuracy: 0.9610
# Epoch 52/100
# 157/157 [==============================] - 7s 44ms/step - loss: 0.8163 - accuracy: 0.9901 - val_loss: 0.8823 - val_accuracy: 0.9630
# Epoch 53/100
# 157/157 [==============================] - 7s 43ms/step - loss: 0.7993 - accuracy: 0.9952 - val_loss: 0.8884 - val_accuracy: 0.9615
# Epoch 54/100
# 157/157 [==============================] - 7s 43ms/step - loss: 0.8061 - accuracy: 0.9874 - val_loss: 0.8613 - val_accuracy: 0.9620
# Epoch 55/100
# 157/157 [==============================] - 7s 43ms/step - loss: 0.7819 - accuracy: 0.9943 - val_loss: 0.8621 - val_accuracy: 0.9615
# Epoch 56/100
# 157/157 [==============================] - 7s 43ms/step - loss: 0.7696 - accuracy: 0.9957 - val_loss: 0.8393 - val_accuracy: 0.9665
# Epoch 57/100
# 157/157 [==============================] - 7s 44ms/step - loss: 0.7594 - accuracy: 0.9941 - val_loss: 0.8394 - val_accuracy: 0.9650
# Epoch 58/100
# 157/157 [==============================] - 7s 43ms/step - loss: 0.7525 - accuracy: 0.9944 - val_loss: 0.8300 - val_accuracy: 0.9625
# Epoch 59/100
# 157/157 [==============================] - 7s 43ms/step - loss: 0.7470 - accuracy: 0.9936 - val_loss: 0.9164 - val_accuracy: 0.9370
# Epoch 60/100
# 157/157 [==============================] - 7s 43ms/step - loss: 0.7513 - accuracy: 0.9876 - val_loss: 0.8122 - val_accuracy: 0.9640
# Epoch 61/100
# 157/157 [==============================] - 7s 44ms/step - loss: 0.7275 - accuracy: 0.9956 - val_loss: 0.8033 - val_accuracy: 0.9685
# Epoch 62/100
# 157/157 [==============================] - 7s 44ms/step - loss: 0.7272 - accuracy: 0.9937 - val_loss: 0.8008 - val_accuracy: 0.9640
# Epoch 63/100
# 157/157 [==============================] - 7s 44ms/step - loss: 0.7166 - accuracy: 0.9938 - val_loss: 0.8012 - val_accuracy: 0.9625
# Epoch 64/100
# 157/157 [==============================] - 7s 43ms/step - loss: 0.7087 - accuracy: 0.9942 - val_loss: 0.8164 - val_accuracy: 0.9615
# Epoch 65/100
# 157/157 [==============================] - 7s 43ms/step - loss: 0.6994 - accuracy: 0.9954 - val_loss: 0.7875 - val_accuracy: 0.9645
# Epoch 66/100
# 157/157 [==============================] - 7s 45ms/step - loss: 0.6937 - accuracy: 0.9971 - val_loss: 0.7772 - val_accuracy: 0.9645
# Epoch 67/100
# 157/157 [==============================] - 7s 43ms/step - loss: 0.6820 - accuracy: 0.9981 - val_loss: 0.7921 - val_accuracy: 0.9555
# Epoch 68/100
# 157/157 [==============================] - 7s 43ms/step - loss: 0.6883 - accuracy: 0.9914 - val_loss: 0.7644 - val_accuracy: 0.9625
# Epoch 69/100
# 157/157 [==============================] - 7s 44ms/step - loss: 0.6891 - accuracy: 0.9895 - val_loss: 0.7899 - val_accuracy: 0.9550
# Epoch 70/100
# 157/157 [==============================] - 7s 43ms/step - loss: 0.6868 - accuracy: 0.9893 - val_loss: 0.7497 - val_accuracy: 0.9680
# Epoch 71/100
# 157/157 [==============================] - 7s 44ms/step - loss: 0.6585 - accuracy: 0.9982 - val_loss: 0.7473 - val_accuracy: 0.9655
# Epoch 72/100
# 157/157 [==============================] - 7s 43ms/step - loss: 0.6576 - accuracy: 0.9960 - val_loss: 0.7424 - val_accuracy: 0.9655
# Epoch 73/100
# 157/157 [==============================] - 7s 44ms/step - loss: 0.6497 - accuracy: 0.9972 - val_loss: 0.7723 - val_accuracy: 0.9550
# Epoch 74/100
# 157/157 [==============================] - 7s 44ms/step - loss: 0.6533 - accuracy: 0.9940 - val_loss: 0.7214 - val_accuracy: 0.9670
# Epoch 75/100
# 157/157 [==============================] - 7s 43ms/step - loss: 0.6449 - accuracy: 0.9938 - val_loss: 0.7373 - val_accuracy: 0.9645
# Epoch 76/100
# 157/157 [==============================] - 7s 45ms/step - loss: 0.6336 - accuracy: 0.9984 - val_loss: 0.7372 - val_accuracy: 0.9615
# Epoch 77/100
# 157/157 [==============================] - 7s 44ms/step - loss: 0.6382 - accuracy: 0.9931 - val_loss: 0.7139 - val_accuracy: 0.9655
# Epoch 78/100
# 157/157 [==============================] - 7s 43ms/step - loss: 0.6215 - accuracy: 0.9979 - val_loss: 0.7095 - val_accuracy: 0.9675
# Epoch 79/100
# 157/157 [==============================] - 7s 43ms/step - loss: 0.6148 - accuracy: 0.9987 - val_loss: 0.7610 - val_accuracy: 0.9565
# Epoch 80/100
# 157/157 [==============================] - 7s 43ms/step - loss: 0.6971 - accuracy: 0.9693 - val_loss: 0.6983 - val_accuracy: 0.9625
# Epoch 81/100
# 157/157 [==============================] - 7s 45ms/step - loss: 0.6229 - accuracy: 0.9927 - val_loss: 0.6966 - val_accuracy: 0.9690
# Epoch 82/100
# 157/157 [==============================] - 7s 43ms/step - loss: 0.6107 - accuracy: 0.9952 - val_loss: 0.6995 - val_accuracy: 0.9595
# Epoch 83/100
# 157/157 [==============================] - 7s 43ms/step - loss: 0.5982 - accuracy: 0.9992 - val_loss: 0.6926 - val_accuracy: 0.9655
# Epoch 84/100
# 157/157 [==============================] - 7s 44ms/step - loss: 0.5946 - accuracy: 0.9990 - val_loss: 0.7100 - val_accuracy: 0.9640
# Epoch 85/100
# 157/157 [==============================] - 7s 45ms/step - loss: 0.5908 - accuracy: 0.9990 - val_loss: 0.6910 - val_accuracy: 0.9665
# Epoch 86/100
# 157/157 [==============================] - 7s 43ms/step - loss: 0.5840 - accuracy: 0.9992 - val_loss: 0.7058 - val_accuracy: 0.9640
# Epoch 87/100
# 157/157 [==============================] - 7s 44ms/step - loss: 0.5827 - accuracy: 0.9979 - val_loss: 0.6847 - val_accuracy: 0.9645
# Epoch 88/100
# 157/157 [==============================] - 7s 43ms/step - loss: 0.5748 - accuracy: 0.9994 - val_loss: 0.6740 - val_accuracy: 0.9675
# Epoch 89/100
# 157/157 [==============================] - 7s 43ms/step - loss: 0.5742 - accuracy: 0.9987 - val_loss: 0.6920 - val_accuracy: 0.9640
# Epoch 90/100
# 157/157 [==============================] - 7s 44ms/step - loss: 0.5725 - accuracy: 0.9977 - val_loss: 0.8058 - val_accuracy: 0.9335
# Epoch 91/100
# 157/157 [==============================] - 7s 43ms/step - loss: 0.6011 - accuracy: 0.9831 - val_loss: 0.6951 - val_accuracy: 0.9555
# Epoch 92/100
# 157/157 [==============================] - 7s 43ms/step - loss: 0.5717 - accuracy: 0.9940 - val_loss: 0.6644 - val_accuracy: 0.9675
# Epoch 93/100
# 157/157 [==============================] - 7s 43ms/step - loss: 0.5598 - accuracy: 0.9984 - val_loss: 0.6541 - val_accuracy: 0.9710
# Epoch 94/100
# 157/157 [==============================] - 7s 43ms/step - loss: 0.5563 - accuracy: 0.9985 - val_loss: 0.9515 - val_accuracy: 0.8705
# Epoch 95/100
# 157/157 [==============================] - 7s 44ms/step - loss: 0.6156 - accuracy: 0.9749 - val_loss: 0.6487 - val_accuracy: 0.9660
# Epoch 96/100
# 157/157 [==============================] - 7s 43ms/step - loss: 0.5596 - accuracy: 0.9946 - val_loss: 0.6495 - val_accuracy: 0.9710
# Epoch 97/100
# 157/157 [==============================] - 7s 43ms/step - loss: 0.5481 - accuracy: 0.9980 - val_loss: 0.6429 - val_accuracy: 0.9675
# Epoch 98/100
# 157/157 [==============================] - 7s 43ms/step - loss: 0.5406 - accuracy: 0.9991 - val_loss: 0.6509 - val_accuracy: 0.9665
# Epoch 99/100
# 157/157 [==============================] - 7s 43ms/step - loss: 0.5415 - accuracy: 0.9979 - val_loss: 0.6364 - val_accuracy: 0.9675
# Epoch 100/100
# 157/157 [==============================] - 7s 44ms/step - loss: 0.5399 - accuracy: 0.9976 - val_loss: 0.6322 - val_accuracy: 0.9695
# 63/63 [==============================] - 1s 8ms/step - loss: 0.5919 - accuracy: 0.9805
# 0.9804999828338623
# 988 12 27 973
# TPR/Recall: 0.973
# TNR/Specificity: 0.988
# PPV/Precision: 0.9878172588832488
# NPV: 0.9733990147783251

# %% [markdown]
# ## Train Data with Weight Regularization and Batch Normalization

# %%
def train_data_weight_batch(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model_weight_regularization_batch_normalization(learning_rate)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
  # fit model
  history = model.fit(X_train, y_train, epochs=epochs, batch_size=64, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_weight_batch_normalization, accuracy = train_data_weight_batch(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 40)
print(accuracy)
y_pred = model_test_weight_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_weight_batch_normalization, accuracy = train_data_weight_batch(X_train, X_val, X_test, y_train, y_val, y_test, 0.01, 40)
print(accuracy)
y_pred = model_test_weight_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_weight_batch_normalization, accuracy = train_data_weight_batch(X_train, X_val, X_test, y_train, y_val, y_test, 0.003, 40)
print(accuracy)
y_pred = model_test_weight_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_weight_batch_normalization, accuracy = train_data_weight_batch(X_train, X_val, X_test, y_train, y_val, y_test, 0.002, 40)
print(accuracy)
y_pred = model_test_weight_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_weight_batch_normalization, accuracy = train_data_weight_batch(X_train, X_val, X_test, y_train, y_val, y_test, 0.0009, 40)
print(accuracy)
y_pred = model_test_weight_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
def train_data_weight_batch2(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, regularization_lambda, epochs):
  # define model
  model = define_model_weight_regularization_batch_normalization2(learning_rate, regularization_lambda)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
  # fit model
  history = model.fit(X_train, y_train, epochs=epochs, batch_size=64, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_weight_batch_normalization, accuracy = train_data_weight_batch2(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 0.001, 40)
print(accuracy)
y_pred = model_test_weight_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_weight_batch_normalization, accuracy = train_data_weight_batch2(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 0.0001, 40)
print(accuracy)
y_pred = model_test_weight_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %% [markdown]
# ## Train Data with Data Augmentation and Weight Regularization

# %%
def train_data_augmentation_weight(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model_weight_regularization(learning_rate)
  # create data generator
  datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
  # prepare iterator
  it_train = datagen.flow(X_train, y_train, batch_size=64)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
	# fit model  
  steps = int(X_train.shape[0] / 64)
  history = model.fit(it_train, epochs=epochs, steps_per_epoch=steps, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_data_weight, accuracy = train_data_augmentation_weight(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 100)
print(accuracy)
y_pred = model_test_data_weight.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))
# Out:
# Epoch 1/100
# 156/156 [==============================] - 36s 230ms/step - loss: 4.0885 - accuracy: 0.5798 - val_loss: 3.9216 - val_accuracy: 0.6200
# Epoch 2/100
# 156/156 [==============================] - 36s 228ms/step - loss: 3.7949 - accuracy: 0.7697 - val_loss: 3.6132 - val_accuracy: 0.8250
# Epoch 3/100
# 156/156 [==============================] - 35s 225ms/step - loss: 3.5511 - accuracy: 0.8279 - val_loss: 3.3674 - val_accuracy: 0.8670
# Epoch 4/100
# 156/156 [==============================] - 35s 224ms/step - loss: 3.3497 - accuracy: 0.8537 - val_loss: 3.2885 - val_accuracy: 0.8280
# Epoch 5/100
# 156/156 [==============================] - 35s 225ms/step - loss: 3.1832 - accuracy: 0.8639 - val_loss: 3.0748 - val_accuracy: 0.8665
# Epoch 6/100
# 156/156 [==============================] - 35s 223ms/step - loss: 3.0230 - accuracy: 0.8786 - val_loss: 2.9523 - val_accuracy: 0.8695
# Epoch 7/100
# 156/156 [==============================] - 35s 227ms/step - loss: 2.8473 - accuracy: 0.9022 - val_loss: 2.7620 - val_accuracy: 0.9025
# Epoch 8/100
# 156/156 [==============================] - 35s 224ms/step - loss: 2.7238 - accuracy: 0.9112 - val_loss: 2.6723 - val_accuracy: 0.8980
# Epoch 9/100
# 156/156 [==============================] - 35s 227ms/step - loss: 2.5942 - accuracy: 0.9226 - val_loss: 2.5305 - val_accuracy: 0.9160
# Epoch 10/100
# 156/156 [==============================] - 35s 227ms/step - loss: 2.4938 - accuracy: 0.9231 - val_loss: 2.4031 - val_accuracy: 0.9350
# Epoch 11/100
# 156/156 [==============================] - 36s 228ms/step - loss: 2.4168 - accuracy: 0.9206 - val_loss: 2.3079 - val_accuracy: 0.9365
# Epoch 12/100
# 156/156 [==============================] - 35s 226ms/step - loss: 2.2952 - accuracy: 0.9333 - val_loss: 2.1982 - val_accuracy: 0.9495
# Epoch 13/100
# 156/156 [==============================] - 35s 222ms/step - loss: 2.2005 - accuracy: 0.9377 - val_loss: 2.1420 - val_accuracy: 0.9340
# Epoch 14/100
# 156/156 [==============================] - 35s 223ms/step - loss: 2.1110 - accuracy: 0.9435 - val_loss: 2.1055 - val_accuracy: 0.9190
# Epoch 15/100
# 156/156 [==============================] - 35s 222ms/step - loss: 2.0399 - accuracy: 0.9416 - val_loss: 2.0144 - val_accuracy: 0.9270
# Epoch 16/100
# 156/156 [==============================] - 35s 222ms/step - loss: 1.9698 - accuracy: 0.9419 - val_loss: 1.8913 - val_accuracy: 0.9570
# Epoch 17/100
# 156/156 [==============================] - 35s 223ms/step - loss: 1.8912 - accuracy: 0.9464 - val_loss: 1.8327 - val_accuracy: 0.9560
# Epoch 18/100
# 156/156 [==============================] - 35s 226ms/step - loss: 1.8267 - accuracy: 0.9507 - val_loss: 1.7645 - val_accuracy: 0.9540
# Epoch 19/100
# 156/156 [==============================] - 35s 225ms/step - loss: 1.7688 - accuracy: 0.9466 - val_loss: 1.7338 - val_accuracy: 0.9465
# Epoch 20/100
# 156/156 [==============================] - 35s 225ms/step - loss: 1.7107 - accuracy: 0.9527 - val_loss: 1.6785 - val_accuracy: 0.9455
# Epoch 21/100
# 156/156 [==============================] - 35s 224ms/step - loss: 1.6580 - accuracy: 0.9517 - val_loss: 1.6636 - val_accuracy: 0.9355
# Epoch 22/100
# 156/156 [==============================] - 36s 228ms/step - loss: 1.6256 - accuracy: 0.9426 - val_loss: 1.6016 - val_accuracy: 0.9420
# Epoch 23/100
# 156/156 [==============================] - 35s 226ms/step - loss: 1.5662 - accuracy: 0.9507 - val_loss: 1.5167 - val_accuracy: 0.9595
# Epoch 24/100
# 156/156 [==============================] - 35s 223ms/step - loss: 1.5144 - accuracy: 0.9512 - val_loss: 1.5077 - val_accuracy: 0.9430
# Epoch 25/100
# 156/156 [==============================] - 35s 223ms/step - loss: 1.4763 - accuracy: 0.9531 - val_loss: 1.4606 - val_accuracy: 0.9445
# Epoch 26/100
# 156/156 [==============================] - 35s 225ms/step - loss: 1.4342 - accuracy: 0.9527 - val_loss: 1.4504 - val_accuracy: 0.9360
# Epoch 27/100
# 156/156 [==============================] - 35s 222ms/step - loss: 1.3968 - accuracy: 0.9564 - val_loss: 1.3640 - val_accuracy: 0.9635
# Epoch 28/100
# 156/156 [==============================] - 35s 224ms/step - loss: 1.3632 - accuracy: 0.9506 - val_loss: 1.3386 - val_accuracy: 0.9570
# Epoch 29/100
# 156/156 [==============================] - 35s 222ms/step - loss: 1.3444 - accuracy: 0.9461 - val_loss: 1.3322 - val_accuracy: 0.9465
# Epoch 30/100
# 156/156 [==============================] - 35s 224ms/step - loss: 1.3005 - accuracy: 0.9523 - val_loss: 1.3074 - val_accuracy: 0.9375
# Epoch 31/100
# 156/156 [==============================] - 35s 221ms/step - loss: 1.2509 - accuracy: 0.9625 - val_loss: 1.2536 - val_accuracy: 0.9515
# Epoch 32/100
# 156/156 [==============================] - 35s 222ms/step - loss: 1.2294 - accuracy: 0.9597 - val_loss: 1.2396 - val_accuracy: 0.9460
# Epoch 33/100
# 156/156 [==============================] - 35s 221ms/step - loss: 1.2032 - accuracy: 0.9592 - val_loss: 1.2036 - val_accuracy: 0.9515
# Epoch 34/100
# 156/156 [==============================] - 36s 231ms/step - loss: 1.1720 - accuracy: 0.9618 - val_loss: 1.1689 - val_accuracy: 0.9530
# Epoch 35/100
# 156/156 [==============================] - 36s 231ms/step - loss: 1.1619 - accuracy: 0.9553 - val_loss: 1.1404 - val_accuracy: 0.9580
# Epoch 36/100
# 156/156 [==============================] - 36s 229ms/step - loss: 1.1298 - accuracy: 0.9553 - val_loss: 1.1205 - val_accuracy: 0.9550
# Epoch 37/100
# 156/156 [==============================] - 36s 231ms/step - loss: 1.1152 - accuracy: 0.9576 - val_loss: 1.0996 - val_accuracy: 0.9590
# Epoch 38/100
# 156/156 [==============================] - 35s 226ms/step - loss: 1.0840 - accuracy: 0.9614 - val_loss: 1.0812 - val_accuracy: 0.9560
# Epoch 39/100
# 156/156 [==============================] - 35s 223ms/step - loss: 1.0752 - accuracy: 0.9588 - val_loss: 1.1931 - val_accuracy: 0.9145
# Epoch 40/100
# 156/156 [==============================] - 35s 223ms/step - loss: 1.0419 - accuracy: 0.9631 - val_loss: 1.0716 - val_accuracy: 0.9435
# Epoch 41/100
# 156/156 [==============================] - 35s 225ms/step - loss: 1.0295 - accuracy: 0.9620 - val_loss: 1.0103 - val_accuracy: 0.9640
# Epoch 42/100
# 156/156 [==============================] - 35s 224ms/step - loss: 1.0119 - accuracy: 0.9598 - val_loss: 1.0001 - val_accuracy: 0.9625
# Epoch 43/100
# 156/156 [==============================] - 35s 227ms/step - loss: 1.0049 - accuracy: 0.9538 - val_loss: 1.0037 - val_accuracy: 0.9520
# Epoch 44/100
# 156/156 [==============================] - 36s 231ms/step - loss: 0.9697 - accuracy: 0.9651 - val_loss: 0.9695 - val_accuracy: 0.9600
# Epoch 45/100
# 156/156 [==============================] - 36s 229ms/step - loss: 0.9545 - accuracy: 0.9637 - val_loss: 0.9641 - val_accuracy: 0.9585
# Epoch 46/100
# 156/156 [==============================] - 35s 226ms/step - loss: 0.9426 - accuracy: 0.9683 - val_loss: 0.9523 - val_accuracy: 0.9605
# Epoch 47/100
# 156/156 [==============================] - 35s 225ms/step - loss: 0.9400 - accuracy: 0.9613 - val_loss: 0.9299 - val_accuracy: 0.9610
# Epoch 48/100
# 156/156 [==============================] - 36s 228ms/step - loss: 0.9175 - accuracy: 0.9651 - val_loss: 0.9362 - val_accuracy: 0.9540
# Epoch 49/100
# 156/156 [==============================] - 35s 225ms/step - loss: 0.9013 - accuracy: 0.9655 - val_loss: 0.9038 - val_accuracy: 0.9605
# Epoch 50/100
# 156/156 [==============================] - 35s 221ms/step - loss: 0.8985 - accuracy: 0.9608 - val_loss: 0.8869 - val_accuracy: 0.9660
# Epoch 51/100
# 156/156 [==============================] - 35s 224ms/step - loss: 0.8775 - accuracy: 0.9682 - val_loss: 0.8942 - val_accuracy: 0.9535
# Epoch 52/100
# 156/156 [==============================] - 35s 222ms/step - loss: 0.8676 - accuracy: 0.9676 - val_loss: 0.8770 - val_accuracy: 0.9605
# Epoch 53/100
# 156/156 [==============================] - 35s 225ms/step - loss: 0.8514 - accuracy: 0.9697 - val_loss: 0.8924 - val_accuracy: 0.9480
# Epoch 54/100
# 156/156 [==============================] - 35s 222ms/step - loss: 0.8478 - accuracy: 0.9642 - val_loss: 0.8457 - val_accuracy: 0.9665
# Epoch 55/100
# 156/156 [==============================] - 35s 223ms/step - loss: 0.8259 - accuracy: 0.9723 - val_loss: 0.8398 - val_accuracy: 0.9645
# Epoch 56/100
# 156/156 [==============================] - 35s 223ms/step - loss: 0.8309 - accuracy: 0.9681 - val_loss: 0.8266 - val_accuracy: 0.9645
# Epoch 57/100
# 156/156 [==============================] - 35s 221ms/step - loss: 0.8209 - accuracy: 0.9647 - val_loss: 0.8162 - val_accuracy: 0.9650
# Epoch 58/100
# 156/156 [==============================] - 35s 222ms/step - loss: 0.8025 - accuracy: 0.9698 - val_loss: 0.9073 - val_accuracy: 0.9270
# Epoch 59/100
# 156/156 [==============================] - 35s 224ms/step - loss: 0.8169 - accuracy: 0.9628 - val_loss: 0.8287 - val_accuracy: 0.9545
# Epoch 60/100
# 156/156 [==============================] - 35s 223ms/step - loss: 0.7913 - accuracy: 0.9670 - val_loss: 0.7958 - val_accuracy: 0.9645
# Epoch 61/100
# 156/156 [==============================] - 35s 225ms/step - loss: 0.7882 - accuracy: 0.9692 - val_loss: 0.7808 - val_accuracy: 0.9665
# Epoch 62/100
# 156/156 [==============================] - 34s 221ms/step - loss: 0.7740 - accuracy: 0.9676 - val_loss: 0.8227 - val_accuracy: 0.9530
# Epoch 63/100
# 156/156 [==============================] - 35s 222ms/step - loss: 0.7758 - accuracy: 0.9668 - val_loss: 0.8935 - val_accuracy: 0.9280
# Epoch 64/100
# 156/156 [==============================] - 35s 225ms/step - loss: 0.7762 - accuracy: 0.9643 - val_loss: 0.7577 - val_accuracy: 0.9690
# Epoch 65/100
# 156/156 [==============================] - 35s 223ms/step - loss: 0.7517 - accuracy: 0.9702 - val_loss: 0.7785 - val_accuracy: 0.9580
# Epoch 66/100
# 156/156 [==============================] - 34s 220ms/step - loss: 0.7522 - accuracy: 0.9696 - val_loss: 0.8328 - val_accuracy: 0.9390
# Epoch 67/100
# 156/156 [==============================] - 35s 224ms/step - loss: 0.7479 - accuracy: 0.9687 - val_loss: 0.7421 - val_accuracy: 0.9705
# Epoch 68/100
# 156/156 [==============================] - 35s 224ms/step - loss: 0.7338 - accuracy: 0.9711 - val_loss: 0.7574 - val_accuracy: 0.9600
# Epoch 69/100
# 156/156 [==============================] - 35s 224ms/step - loss: 0.7363 - accuracy: 0.9677 - val_loss: 0.7819 - val_accuracy: 0.9455
# Epoch 70/100
# 156/156 [==============================] - 34s 220ms/step - loss: 0.7270 - accuracy: 0.9676 - val_loss: 0.7515 - val_accuracy: 0.9585
# Epoch 71/100
# 156/156 [==============================] - 35s 225ms/step - loss: 0.7185 - accuracy: 0.9704 - val_loss: 0.7079 - val_accuracy: 0.9760
# Epoch 72/100
# 156/156 [==============================] - 35s 222ms/step - loss: 0.7224 - accuracy: 0.9661 - val_loss: 0.7304 - val_accuracy: 0.9635
# Epoch 73/100
# 156/156 [==============================] - 34s 220ms/step - loss: 0.7057 - accuracy: 0.9706 - val_loss: 0.7563 - val_accuracy: 0.9545
# Epoch 74/100
# 156/156 [==============================] - 35s 222ms/step - loss: 0.7049 - accuracy: 0.9718 - val_loss: 0.7076 - val_accuracy: 0.9665
# Epoch 75/100
# 156/156 [==============================] - 35s 222ms/step - loss: 0.7156 - accuracy: 0.9652 - val_loss: 0.7246 - val_accuracy: 0.9605
# Epoch 76/100
# 156/156 [==============================] - 35s 222ms/step - loss: 0.6995 - accuracy: 0.9659 - val_loss: 0.7056 - val_accuracy: 0.9650
# Epoch 77/100
# 156/156 [==============================] - 34s 219ms/step - loss: 0.6990 - accuracy: 0.9686 - val_loss: 0.6969 - val_accuracy: 0.9655
# Epoch 78/100
# 156/156 [==============================] - 35s 223ms/step - loss: 0.6833 - accuracy: 0.9689 - val_loss: 0.7114 - val_accuracy: 0.9580
# Epoch 79/100
# 156/156 [==============================] - 35s 224ms/step - loss: 0.6740 - accuracy: 0.9710 - val_loss: 0.7065 - val_accuracy: 0.9610
# Epoch 80/100
# 156/156 [==============================] - 35s 222ms/step - loss: 0.6769 - accuracy: 0.9712 - val_loss: 0.6856 - val_accuracy: 0.9665
# Epoch 81/100
# 156/156 [==============================] - 35s 224ms/step - loss: 0.6658 - accuracy: 0.9713 - val_loss: 0.6833 - val_accuracy: 0.9650
# Epoch 82/100
# 156/156 [==============================] - 35s 222ms/step - loss: 0.6584 - accuracy: 0.9750 - val_loss: 0.6970 - val_accuracy: 0.9590
# Epoch 83/100
# 156/156 [==============================] - 35s 222ms/step - loss: 0.6573 - accuracy: 0.9719 - val_loss: 0.7195 - val_accuracy: 0.9510
# Epoch 84/100
# 156/156 [==============================] - 35s 222ms/step - loss: 0.6595 - accuracy: 0.9659 - val_loss: 0.6583 - val_accuracy: 0.9675
# Epoch 85/100
# 156/156 [==============================] - 35s 221ms/step - loss: 0.6451 - accuracy: 0.9726 - val_loss: 0.6628 - val_accuracy: 0.9650
# Epoch 86/100
# 156/156 [==============================] - 34s 220ms/step - loss: 0.6412 - accuracy: 0.9737 - val_loss: 0.6619 - val_accuracy: 0.9650
# Epoch 87/100
# 156/156 [==============================] - 35s 221ms/step - loss: 0.6388 - accuracy: 0.9726 - val_loss: 0.6702 - val_accuracy: 0.9615
# Epoch 88/100
# 156/156 [==============================] - 35s 224ms/step - loss: 0.6398 - accuracy: 0.9731 - val_loss: 0.6730 - val_accuracy: 0.9630
# Epoch 89/100
# 156/156 [==============================] - 35s 222ms/step - loss: 0.6307 - accuracy: 0.9730 - val_loss: 0.7072 - val_accuracy: 0.9465
# Epoch 00089: early stopping
# 63/63 [==============================] - 1s 8ms/step - loss: 0.6913 - accuracy: 0.9440
# 0.9440000057220459
# 892 108 4 996
# TPR/Recall: 0.996
# TNR/Specificity: 0.892
# PPV/Precision: 0.9021739130434783
# NPV: 0.9955357142857143

# %% [markdown]
# ### Train Data with Data Augmentation, Weight Regularization and Batch Normalization

# %%
def train_data_augmentation_weight_batch(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model_weight_regularization_batch_normalization(learning_rate)
  # create data generator
  datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
  # prepare iterator
  it_train = datagen.flow(X_train, y_train, batch_size=64)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
	# fit model  
  steps = int(X_train.shape[0] / 64)
  history = model.fit(it_train, epochs=epochs, steps_per_epoch=steps, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_data_weight_batch_normalization, accuracy = train_data_augmentation_weight_batch(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 30)
print(accuracy)
y_pred = model_test_data_weight_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_data_weight_batch_normalization, accuracy = train_data_augmentation_weight_batch(X_train, X_val, X_test, y_train, y_val, y_test, 0.01, 40)
print(accuracy)
y_pred = model_test_data_weight_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_data_weight_batch_normalization, accuracy = train_data_augmentation_weight_batch(X_train, X_val, X_test, y_train, y_val, y_test, 0.003, 40)
print(accuracy)
y_pred = model_test_data_weight_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
def train_data_augmentation_weight_batch2(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, regularization_lambda, epochs):
  # define model
  model = define_model_weight_regularization_batch_normalization2(learning_rate, regularization_lambda)
  # create data generator
  datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
  # prepare iterator
  it_train = datagen.flow(X_train, y_train, batch_size=64)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
	# fit model  
  steps = int(X_train.shape[0] / 64)
  history = model.fit(it_train, epochs=epochs, steps_per_epoch=steps, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_data_weight, accuracy = train_data_augmentation_weight_batch2(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 0.001, 35)
print(accuracy)
y_pred = model_test_data_weight.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_data_weight, accuracy = train_data_augmentation_weight_batch2(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 0.1, 35)
print(accuracy)
y_pred = model_test_data_weight.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_data_weight, accuracy = train_data_augmentation_weight_batch2(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 0.0001, 35)
print(accuracy)
y_pred = model_test_data_weight.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_data_weight, accuracy = train_data_augmentation_weight_batch2(X_train, X_val, X_test, y_train, y_val, y_test, 5e-6, 0.001, 35)
print(accuracy)
y_pred = model_test_data_weight.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))
