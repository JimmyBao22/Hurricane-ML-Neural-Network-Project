# %% [markdown]
# # Imports

# %%
import numpy as np
import glob
from PIL import Image
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from tensorflow.keras import optimizers
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import KFold
import pandas as pd
import seaborn as sn
sn.set(font_scale=1.4) # for label size
import multiprocessing as mp
import csv

# %% [markdown]
# # Load DataSet
#
# 0 means unlikely to have flood damage, 1 means likely to have flood damage
#
# [0,1] --> damage
#
# [1,0] --> no damage

# %% [markdown]
# ## Load Training Set

# %%
images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/train_another/damage/*.jpeg')
dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  dmg_img.append(im_arr)
dmg_img = np.array(dmg_img)

images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/train_another/no_damage/*.jpeg')
no_dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  no_dmg_img.append(im_arr)
no_dmg_img = np.array(no_dmg_img)

X_train = np.concatenate((dmg_img, no_dmg_img))
dmg_img_y = np.array(dmg_img.shape[0] * [[0,1]])
no_dmg_img_y = np.array(no_dmg_img.shape[0] * [[1,0]])
y_train = np.concatenate((dmg_img_y, no_dmg_img_y))

# shuffle arrays so that the array is a mix of damage and no_damage in a random order
shuffler = np.random.permutation(X_train.shape[0])
X_train = X_train[shuffler]
y_train = y_train[shuffler]

# %% [markdown]
# ## Load Validation Set

# %%
images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/validation_another/damage/*.jpeg')
dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  dmg_img.append(im_arr)
dmg_img = np.array(dmg_img)

images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/validation_another/no_damage/*.jpeg')
no_dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  no_dmg_img.append(im_arr)
no_dmg_img = np.array(no_dmg_img)

X_val = np.concatenate((dmg_img, no_dmg_img))
dmg_img_y = np.array(dmg_img.shape[0] * [[0,1]])
no_dmg_img_y = np.array(no_dmg_img.shape[0] * [[1,0]])
y_val = np.concatenate((dmg_img_y, no_dmg_img_y))

# shuffle arrays so that the array is a mix of damage and no_damage in a random order
shuffler = np.random.permutation(X_val.shape[0])
X_val = X_val[shuffler]
y_val = y_val[shuffler]

# %%
# combine training and validation data - for cross-validation
X_all = np.concatenate((X_train, X_val))
y_all = np.concatenate((y_train, y_val))

# %% [markdown]
# ## Load Test Set

# %%
images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/test/damage/*.jpeg')
dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  dmg_img.append(im_arr)
dmg_img = np.array(dmg_img)

images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/test/no_damage/*.jpeg')
no_dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  no_dmg_img.append(im_arr)
no_dmg_img = np.array(no_dmg_img)

X_test = np.concatenate((dmg_img, no_dmg_img))
dmg_img_y = np.array(dmg_img.shape[0] * [[0,1]])
no_dmg_img_y = np.array(no_dmg_img.shape[0] * [[1,0]])
y_test = np.concatenate((dmg_img_y, no_dmg_img_y))

# shuffle arrays so that the array is a mix of damage and no_damage in a random order
shuffler = np.random.permutation(X_val.shape[0])
X_test = X_test[shuffler]
y_test = y_test[shuffler]

# %% [markdown]
# ## Input/Output

# %%
# save a dictionary as a csv file
def output_as_csv(name, a):
    path = "/kaggle/working/" + name + ".csv"
    with open(path, 'w') as csv_file:
        # create the csv writer
        writer = csv.writer(csv_file)

        # write a row to the csv file
        writer.writerow(a.keys())
        writer.writerow(a.values())

# input a csv file
def input_csv(path):
    b, keys = {}, {}
    with open(path, mode='r') as csv_file:
        csv_reader = csv.DictReader(csv_file)
        line_count = 0
        for row in csv_reader:
            keys = row
    b = dict(keys)
    return b # returns a dictionary

# %% [markdown]
# # Pre-Process DataSet

# %%
# pre-process data 
def scale_pixels(train, val, test, X_all):
	# convert from integers to floats and normalize between 0-1
  train_norm = train.astype('float32') / 255.0
  val_norm = val.astype('float32') / 255.0
  test_norm = test.astype('float32') / 255.0
  X_all_norm = X_all.astype('float32') / 255.0
	# return normalized images
  return train_norm, val_norm, test_norm, X_all_norm

X_train, X_val, X_test, X_all = scale_pixels(X_train, X_val, X_test, X_all)

# %% [markdown]
# # Plot Diagnostics

# %%
# plot diagnostic learning curves
def summarize_diagnostics(history):
  # blue = training data; orange = validation data
	# plot validation loss
	plt.subplot(211)
	plt.title('Cross Entropy Loss')
	plt.plot(history.history['loss'], color='blue', label='train')
	plt.plot(history.history['val_loss'], color='orange', label='validation')
	# plot accuracy
	plt.subplot(212)
	plt.title('Classification Accuracy')
	plt.plot(history.history['accuracy'], color='blue', label='train')
	plt.plot(history.history['val_accuracy'], color='orange', label='validation')

# %%
# returns the confusion matrix
def find_confusion_matrix(model, X_test, y_test):
    y_pred = model.predict(X_test)
    y_pred_val = y_pred.argmax(axis=1)
    y_test_val = y_test.argmax(axis=1)
    return confusion_matrix(y_test_val, y_pred_val)

# returns the confusion matrix based on tn, fn, fp, tp
def find_confusion_matrix_2(tn, fn, fp, tp):
    return [[tn, fp], [fn, tp]]

# generate heat map for confusion matrix
def heatmap(confusion_matrix):
    df = pd.DataFrame(confusion_matrix, index = ['F', 'T'], columns = ['F', 'T'])
    sn.heatmap(df, annot=True) # create a heatmap
    
# returns normalized confusion matrix
def normalize_confusion_matrix(confusion_matrix):
    confusion_matrix = np.array(confusion_matrix)
    confusion_matrix_sum = confusion_matrix.astype(np.float).sum(axis=1)
    confusion_matrix_norm = confusion_matrix.astype(np.float)
    confusion_matrix_norm[0] = confusion_matrix_norm[0] / confusion_matrix_sum[0]
    confusion_matrix_norm[1] = confusion_matrix_norm[1] / confusion_matrix_sum[1]
    return confusion_matrix_norm

def print_confusion_matrix_results(results):
    # results is a dictionary
    # calculate mean and standard deviation for each key
    for key in results:
        mean = np.mean(results[key])
        std = np.std(results[key])
        print("{} mean: {}".format(key, mean))
        print("{} std: {}".format(key, std))

# %% [markdown]
# # Create CNN Model

# %%
# define cnn model
def define_model(learning_rate):
  model = keras.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(128, 128, 3)))
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Flatten())
  model.add(layers.Dense(128, activation='relu', kernel_initializer='he_uniform'))
  model.add(layers.Dense(2, activation='softmax'))  # compile model
  opt = optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
  model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
  return model

# %% [markdown]
# ## CNN Model with Batch Normalization

# %%
# define cnn model
def define_model_batch_normalization(learning_rate):
  model = keras.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(128, 128, 3)))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Flatten())
  model.add(layers.Dense(128, activation='relu', kernel_initializer='he_uniform'))
  model.add(layers.BatchNormalization())
  model.add(layers.Dense(2, activation='softmax'))  # compile model
  opt = optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
  model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
  return model

# %% [markdown]
# ## CNN Model with Dropout Regularization

# %%
# define cnn model
def define_model_dropout_regularization(learning_rate):
  model = keras.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(128, 128, 3)))
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.2)) # retain 80% of neurons
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.3))
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.4))
  model.add(layers.Flatten())
  model.add(layers.Dense(128, activation='relu', kernel_initializer='he_uniform'))
  model.add(layers.Dropout(0.5))
  model.add(layers.Dense(2, activation='softmax'))  # compile model
  opt = optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
  model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
  return model

# %% [markdown]
# ### CNN Model with Dropout Regularization and Batch Normalization

# %%
# define cnn model
def define_model_dropout_regularization_batch_normalization(learning_rate):
  model = keras.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(128, 128, 3)))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.2)) # retain 80% of neurons
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.3))
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.4))
  model.add(layers.Flatten())
  model.add(layers.Dense(128, activation='relu', kernel_initializer='he_uniform'))
  model.add(layers.BatchNormalization())
  model.add(layers.Dropout(0.5))
  model.add(layers.Dense(2, activation='softmax'))  # compile model
  opt = optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
  model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
  return model

# %% [markdown]
# ## CNN Model with Weight Regularization

# %%
# define cnn model
def define_model_weight_regularization(learning_rate):
  model = keras.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.01), input_shape=(128, 128, 3)))
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Flatten())
  model.add(layers.Dense(128, activation='relu', kernel_initializer='he_uniform', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.Dense(2, activation='softmax'))  # compile model
  opt = optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
  model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
  return model

# %% [markdown]
# ### CNN Model with Weight Regularization and Batch Normalization

# %%
# define cnn model
def define_model_weight_regularization_batch_normalization(learning_rate):
  model = keras.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.01), input_shape=(128, 128, 3)))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Flatten())
  model.add(layers.Dense(128, activation='relu', kernel_initializer='he_uniform', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.BatchNormalization())
  model.add(layers.Dense(2, activation='softmax'))  # compile model
  opt = optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
  model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
  return model

# %% [markdown]
# # Train Data
# Hyperparameters are inputted into the function

# %%
def train(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model(learning_rate)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
  # fit model
  history = model.fit(X_train, y_train, epochs=epochs, batch_size=64, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model, accuracy = train(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 75)
print(accuracy)

# %%
model_test, accuracy = train(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 75)
print(accuracy)
y_pred = model_test.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %% [markdown]
# ## Train Data w/ Cross Validation

# %%
def benchmark_model(X_all, y_all, split):
    X_train_cv, y_train_cv = X_all[split[0]], y_all[split[0]]
    X_val_cv, y_val_cv = X_all[split[1]], y_all[split[1]]
    model, accuracy = train(X_train_cv, X_val_cv, X_val_cv, y_train_cv, y_val_cv, y_val_cv, 0.001, 75) 
    results = {}
    results["model"] = model
    results["accuracy"] = accuracy
    results["confusion_matrix"] = find_confusion_matrix(model, X_val_cv, y_val_cv)
    tn, fp, fn, tp = results["confusion_matrix"].ravel()
    results["tn"] = tn
    results["fp"] = fp
    results["fn"] = fn
    results["tp"] = tp
    results["TPR/Recall"] = tp/(tp+fn)
    results["TNR/Specificity"] = tn/(tn+fp)
    results["PPV/Precision"] = tp/(tp+fp)
    results["NPV"] = tn/(tn+fn)
    return results

# %%
kf = KFold(n_splits=5)
folds = list(kf.split(X_all, y_all))

# %%
output_as_csv("normal_fold_1", benchmark_model(X_all, y_all, folds[0]))

# %%
output_as_csv("normal_fold_2", benchmark_model(X_all, y_all, folds[1]))

# %%
output_as_csv("normal_fold_3", benchmark_model(X_all, y_all, folds[2]))

# %%
output_as_csv("normal_fold_4", benchmark_model(X_all, y_all, folds[3]))

# %%
output_as_csv("normal_fold_5", benchmark_model(X_all, y_all, folds[4]))

# %%
# results_list is a list of dictionaries
results_list = []
for i in range(1,6):
    path = "../input/hurricane-normal-cv/normal_fold_" + str(i) + ".csv"
    results_list.append(input_csv(path))

# results_dict is a dictionary of lists
results_dict = {}
results_dict["accuracy"] = [(float)(i["accuracy"]) for i in results_list]
results_dict["TPR/Recall"] = [(float)(i["TPR/Recall"]) for i in results_list]
results_dict["TNR/Specificity"] = [(float)(i["TNR/Specificity"]) for i in results_list]
results_dict["PPV/Precision"] = [(float)(i["PPV/Precision"]) for i in results_list]
results_dict["NPV"] = [(float)(i["NPV"]) for i in results_list]

print_confusion_matrix_results(results_dict)

# %%
# find confusion matrices
results_dict["tn"] = [(int)(i["tn"]) for i in results_list]
results_dict["fp"] = [(int)(i["fp"]) for i in results_list]
results_dict["fn"] = [(int)(i["fn"]) for i in results_list]
results_dict["tp"] = [(int)(i["tp"]) for i in results_list]
results_dict["confusion_matrix"] = []
# append confusion matrix for each cross-validation fold
for i in range(len(folds)):
    results_dict["confusion_matrix"].append(find_confusion_matrix_2(results_dict["tn"][i], results_dict["fp"][i], results_dict["fn"][i], results_dict["tp"][i]))
                                            
# total confusion matrix summed together
confusion_matrix_list = []
confusion_matrix_list = results_dict["confusion_matrix"]
confusion_matrix_comb = np.sum(confusion_matrix_list, axis=0)
heatmap(confusion_matrix_comb)

# %%
# normalized confusion matrix
confusion_matrix_norm = normalize_confusion_matrix(confusion_matrix_comb)
heatmap(confusion_matrix_norm)

# %% [markdown]
# ## Train Data with Batch Normalization

# %%
def train_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model_batch_normalization(learning_rate)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
  # fit model
  history = model.fit(X_train, y_train, epochs=epochs, batch_size=64, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model, accuracy = train_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 75)
print(accuracy)

# %%
model_test_batch_normalization, accuracy = train_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 75)
print(accuracy)
y_pred = model_test_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %% [markdown]
# ### Train Data with Batch Normalization and Cross Validation

# %%
def benchmark_model_batch_normalization(X_all, y_all, split):
    X_train_cv, y_train_cv = X_all[split[0]], y_all[split[0]]
    X_val_cv, y_val_cv = X_all[split[1]], y_all[split[1]]
    model, accuracy = train_batch_normalization(X_train_cv, X_val_cv, X_val_cv, y_train_cv, y_val_cv, y_val_cv, 0.001, 75) 
    results = {}
    results["model"] = model
    results["accuracy"] = accuracy
    results["confusion_matrix"] = find_confusion_matrix(model, X_val_cv, y_val_cv)
    tn, fp, fn, tp = results["confusion_matrix"].ravel()
    results["tn"] = tn
    results["fp"] = fp
    results["fn"] = fn
    results["tp"] = tp
    results["TPR/Recall"] = tp/(tp+fn)
    results["TNR/Specificity"] = tn/(tn+fp)
    results["PPV/Precision"] = tp/(tp+fp)
    results["NPV"] = tn/(tn+fn)
    return results

# %%
kf = KFold(n_splits=5)
folds = list(kf.split(X_all, y_all))

# %%
output_as_csv("batch normalization fold 1", benchmark_model_batch_normalization(X_all, y_all, folds[0]))

# %%
output_as_csv("batch normalization fold 2", benchmark_model_batch_normalization(X_all, y_all, folds[1]))

# %%
output_as_csv("batch normalization fold 3", benchmark_model_batch_normalization(X_all, y_all, folds[2]))

# %%
output_as_csv("batch normalization fold 4", benchmark_model_batch_normalization(X_all, y_all, folds[3]))

# %%
output_as_csv("batch normalization fold 5", benchmark_model_batch_normalization(X_all, y_all, folds[4]))

# %% [markdown]
# ## Train Data with Data Augmentation

# %%
def train_data_augmentation(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model(learning_rate)
  # create data generator
  datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
  # prepare iterator
  it_train = datagen.flow(X_train, y_train, batch_size=64)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=8, verbose=1)
	# fit model
  steps = int(X_train.shape[0] / 64)
  history = model.fit(it_train, epochs=epochs, steps_per_epoch=steps, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model, accuracy = train_data_augmentation(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 100)
print(accuracy)

# %%
model_test_data, accuracy = train_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 75)
print(accuracy)
y_pred = model_test_data.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %% [markdown]
# ### Train Data with Data Augmentation and Batch Normalization

# %%
def train_data_augmentation_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model_batch_normalization(learning_rate)
  # create data generator
  datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
  # prepare iterator
  it_train = datagen.flow(X_train, y_train, batch_size=64)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
	# fit model  
  steps = int(X_train.shape[0] / 64)
  history = model.fit(it_train, epochs=epochs, steps_per_epoch=steps, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model, accuracy = train_data_augmentation_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 100)
print(accuracy)

# %%
model_test_data_augmentation_batch_normalization, accuracy = train_data_augmentation_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 100)
print(accuracy)
y_pred = model_test_data_augmentation_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %% [markdown]
# ## Train Data with Dropout Regularization and Batch Normalization

# %%
def train_data_dropout_batch(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model_dropout_regularization_batch_normalization(learning_rate)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
  # fit model
  history = model.fit(X_train, y_train, epochs=epochs, batch_size=64, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_data_dropout_batch_normalization, accuracy = train_data_dropout_batch(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 100)
print(accuracy)
y_pred = model_test_data_dropout_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))
# Out:
# Epoch 1/100
# 157/157 [==============================] - 874s 6s/step - loss: 0.5985 - accuracy: 0.7659 - val_loss: 1.6602 - val_accuracy: 0.5000
# Epoch 2/100
# 157/157 [==============================] - 855s 5s/step - loss: 0.2119 - accuracy: 0.9327 - val_loss: 2.7995 - val_accuracy: 0.5100
# Epoch 3/100
# 157/157 [==============================] - 852s 5s/step - loss: 0.1615 - accuracy: 0.9444 - val_loss: 0.5759 - val_accuracy: 0.7685
# Epoch 4/100
# 157/157 [==============================] - 836s 5s/step - loss: 0.1299 - accuracy: 0.9551 - val_loss: 0.1395 - val_accuracy: 0.9520
# Epoch 5/100
# 157/157 [==============================] - 750s 5s/step - loss: 0.1153 - accuracy: 0.9570 - val_loss: 0.1206 - val_accuracy: 0.9520
# Epoch 6/100
# 157/157 [==============================] - 748s 5s/step - loss: 0.1134 - accuracy: 0.9601 - val_loss: 0.1171 - val_accuracy: 0.9565
# Epoch 7/100
# 157/157 [==============================] - 750s 5s/step - loss: 0.1019 - accuracy: 0.9644 - val_loss: 0.0982 - val_accuracy: 0.9665
# Epoch 8/100
# 157/157 [==============================] - 749s 5s/step - loss: 0.1028 - accuracy: 0.9636 - val_loss: 0.0962 - val_accuracy: 0.9640
# Epoch 9/100
# 157/157 [==============================] - 747s 5s/step - loss: 0.0898 - accuracy: 0.9682 - val_loss: 0.1294 - val_accuracy: 0.9470
# Epoch 10/100
# 157/157 [==============================] - 745s 5s/step - loss: 0.0845 - accuracy: 0.9698 - val_loss: 0.0962 - val_accuracy: 0.9615
# Epoch 11/100
# 157/157 [==============================] - 752s 5s/step - loss: 0.0736 - accuracy: 0.9717 - val_loss: 0.0827 - val_accuracy: 0.9700
# Epoch 12/100
# 157/157 [==============================] - 746s 5s/step - loss: 0.0838 - accuracy: 0.9706 - val_loss: 0.1135 - val_accuracy: 0.9635
# Epoch 13/100
# 157/157 [==============================] - 791s 5s/step - loss: 0.0798 - accuracy: 0.9737 - val_loss: 0.0908 - val_accuracy: 0.9680
# Epoch 14/100
# 157/157 [==============================] - 840s 5s/step - loss: 0.0695 - accuracy: 0.9764 - val_loss: 0.1160 - val_accuracy: 0.9595
# Epoch 15/100
# 157/157 [==============================] - 835s 5s/step - loss: 0.0722 - accuracy: 0.9760 - val_loss: 0.1000 - val_accuracy: 0.9660
# Epoch 16/100
# 157/157 [==============================] - 800s 5s/step - loss: 0.0671 - accuracy: 0.9740 - val_loss: 0.1283 - val_accuracy: 0.9495
# Epoch 00016: early stopping
# 63/63 [==============================] - 34s 532ms/step - loss: 0.1164 - accuracy: 0.9550
# 0.9549999833106995
# 986 14 76 924
# TPR/Recall: 0.924
# TNR/Specificity: 0.986
# PPV/Precision: 0.9850746268656716
# NPV: 0.928436911487759

# %% [markdown]
# ### Train Data with Data Augmentation, Dropout Regularization and Batch Normalization

# %%
def train_data_augmentation_dropout_batch(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model_weight_regularization_batch_normalization(learning_rate)
  # create data generator
  datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
  # prepare iterator
  it_train = datagen.flow(X_train, y_train, batch_size=64)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
	# fit model  
  steps = int(X_train.shape[0] / 64)
  history = model.fit(it_train, epochs=epochs, steps_per_epoch=steps, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_data_dropout_batch_normalization, accuracy = train_data_augmentation_dropout_batch(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 25)
print(accuracy)
y_pred = model_test_data_dropout_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))
# Out:
# Epoch 1/25
# 156/156 [==============================] - 840s 5s/step - loss: 11.8363 - accuracy: 0.8338 - val_loss: 12.5753 - val_accuracy: 0.5000
# Epoch 2/25
# 156/156 [==============================] - 848s 5s/step - loss: 10.9034 - accuracy: 0.9392 - val_loss: 10.7390 - val_accuracy: 0.7400
# Epoch 3/25
# 156/156 [==============================] - 831s 5s/step - loss: 10.2101 - accuracy: 0.9557 - val_loss: 9.8937 - val_accuracy: 0.8965
# Epoch 4/25
# 156/156 [==============================] - 829s 5s/step - loss: 9.5882 - accuracy: 0.9591 - val_loss: 9.4194 - val_accuracy: 0.8250
# Epoch 5/25
# 156/156 [==============================] - 850s 5s/step - loss: 9.0183 - accuracy: 0.9566 - val_loss: 8.6331 - val_accuracy: 0.9535
# Epoch 6/25
# 156/156 [==============================] - 841s 5s/step - loss: 8.4514 - accuracy: 0.9692 - val_loss: 8.3663 - val_accuracy: 0.8420
# Epoch 7/25
# 156/156 [==============================] - 846s 5s/step - loss: 7.9529 - accuracy: 0.9656 - val_loss: 7.6529 - val_accuracy: 0.9475
# Epoch 8/25
# 156/156 [==============================] - 831s 5s/step - loss: 7.4762 - accuracy: 0.9679 - val_loss: 7.5835 - val_accuracy: 0.7580
# Epoch 9/25
# 156/156 [==============================] - 830s 5s/step - loss: 7.0172 - accuracy: 0.9722 - val_loss: 6.7793 - val_accuracy: 0.9495
# Epoch 10/25
# 156/156 [==============================] - 828s 5s/step - loss: 6.6072 - accuracy: 0.9688 - val_loss: 6.3100 - val_accuracy: 0.9680
# Epoch 11/25
# 156/156 [==============================] - 832s 5s/step - loss: 6.2012 - accuracy: 0.9749 - val_loss: 5.9511 - val_accuracy: 0.9640
# Epoch 12/25
# 156/156 [==============================] - 832s 5s/step - loss: 5.8259 - accuracy: 0.9757 - val_loss: 5.8470 - val_accuracy: 0.8650
# Epoch 13/25
# 156/156 [==============================] - 831s 5s/step - loss: 5.4769 - accuracy: 0.9756 - val_loss: 5.2432 - val_accuracy: 0.9700
# Epoch 14/25
# 156/156 [==============================] - 832s 5s/step - loss: 5.1420 - accuracy: 0.9795 - val_loss: 4.9702 - val_accuracy: 0.9540
# Epoch 15/25
# 156/156 [==============================] - 834s 5s/step - loss: 4.8333 - accuracy: 0.9825 - val_loss: 4.9879 - val_accuracy: 0.8385
# Epoch 16/25
# 156/156 [==============================] - 833s 5s/step - loss: 4.5551 - accuracy: 0.9780 - val_loss: 4.3652 - val_accuracy: 0.9735
# Epoch 17/25
# 156/156 [==============================] - 832s 5s/step - loss: 4.2777 - accuracy: 0.9775 - val_loss: 4.1042 - val_accuracy: 0.9750
# Epoch 18/25
# 156/156 [==============================] - 833s 5s/step - loss: 4.0229 - accuracy: 0.9768 - val_loss: 3.8474 - val_accuracy: 0.9760
# Epoch 19/25
# 156/156 [==============================] - 835s 5s/step - loss: 3.7825 - accuracy: 0.9807 - val_loss: 3.6434 - val_accuracy: 0.9730
# Epoch 20/25
# 156/156 [==============================] - 833s 5s/step - loss: 3.5560 - accuracy: 0.9806 - val_loss: 3.4043 - val_accuracy: 0.9745
# Epoch 21/25
# 156/156 [==============================] - 832s 5s/step - loss: 3.3404 - accuracy: 0.9822 - val_loss: 3.1998 - val_accuracy: 0.9775
# Epoch 22/25
# 156/156 [==============================] - 841s 5s/step - loss: 3.1446 - accuracy: 0.9815 - val_loss: 3.0259 - val_accuracy: 0.9735
# Epoch 23/25
# 156/156 [==============================] - 835s 5s/step - loss: 2.9527 - accuracy: 0.9845 - val_loss: 2.8688 - val_accuracy: 0.9690
# Epoch 24/25
# 156/156 [==============================] - 841s 5s/step - loss: 2.7813 - accuracy: 0.9840 - val_loss: 2.7066 - val_accuracy: 0.9670
# Epoch 25/25
# 156/156 [==============================] - 838s 5s/step - loss: 2.6145 - accuracy: 0.9839 - val_loss: 2.5607 - val_accuracy: 0.9635
# 63/63 [==============================] - 36s 573ms/step - loss: 2.5471 - accuracy: 0.9650
# 0.9649999737739563
# 995 5 65 935
# TPR/Recall: 0.935
# TNR/Specificity: 0.995
# PPV/Precision: 0.9946808510638298
# NPV: 0.9386792452830188

# %% [markdown]
# ## Train Data with Weight Regularization and Batch Normalization

# %%
def train_data_weight_batch(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model_dropout_regularization_batch_normalization(learning_rate)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
  # fit model
  history = model.fit(X_train, y_train, epochs=epochs, batch_size=64, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_weight_batch_normalization, accuracy = train_data_weight_batch(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 100)
print(accuracy)
y_pred = model_test_weight_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))
# Out:
# Epoch 1/100
# 157/157 [==============================] - 737s 5s/step - loss: 11.7833 - accuracy: 0.8450 - val_loss: 13.8334 - val_accuracy: 0.5000
# Epoch 2/100
# 157/157 [==============================] - 735s 5s/step - loss: 10.8078 - accuracy: 0.9623 - val_loss: 12.2669 - val_accuracy: 0.5100
# Epoch 3/100
# 157/157 [==============================] - 734s 5s/step - loss: 10.1267 - accuracy: 0.9731 - val_loss: 10.0158 - val_accuracy: 0.8055
# Epoch 4/100
# 157/157 [==============================] - 733s 5s/step - loss: 9.4932 - accuracy: 0.9842 - val_loss: 9.2428 - val_accuracy: 0.9005
# Epoch 5/100
# 157/157 [==============================] - 734s 5s/step - loss: 8.9006 - accuracy: 0.9914 - val_loss: 8.5642 - val_accuracy: 0.9600
# Epoch 6/100
# 157/157 [==============================] - 729s 5s/step - loss: 8.3555 - accuracy: 0.9929 - val_loss: 8.0494 - val_accuracy: 0.9605
# Epoch 7/100
# 157/157 [==============================] - 728s 5s/step - loss: 7.8375 - accuracy: 0.9973 - val_loss: 7.5601 - val_accuracy: 0.9655
# Epoch 8/100
# 157/157 [==============================] - 732s 5s/step - loss: 7.3559 - accuracy: 0.9977 - val_loss: 7.1036 - val_accuracy: 0.9680
# Epoch 9/100
# 157/157 [==============================] - 731s 5s/step - loss: 6.9068 - accuracy: 0.9981 - val_loss: 6.6668 - val_accuracy: 0.9650
# Epoch 10/100
# 157/157 [==============================] - 740s 5s/step - loss: 6.4830 - accuracy: 0.9992 - val_loss: 6.2562 - val_accuracy: 0.9685
# Epoch 11/100
# 157/157 [==============================] - 735s 5s/step - loss: 6.0892 - accuracy: 0.9987 - val_loss: 5.8857 - val_accuracy: 0.9700
# Epoch 12/100
# 157/157 [==============================] - 731s 5s/step - loss: 5.7147 - accuracy: 0.9998 - val_loss: 5.5493 - val_accuracy: 0.9650
# Epoch 13/100
# 157/157 [==============================] - 730s 5s/step - loss: 5.3664 - accuracy: 0.9995 - val_loss: 5.3355 - val_accuracy: 0.9185
# Epoch 14/100
# 157/157 [==============================] - 733s 5s/step - loss: 5.0417 - accuracy: 0.9985 - val_loss: 4.8958 - val_accuracy: 0.9690
# Epoch 15/100
# 157/157 [==============================] - 798s 5s/step - loss: 4.7313 - accuracy: 0.9998 - val_loss: 4.6021 - val_accuracy: 0.9660
# Epoch 16/100
# 157/157 [==============================] - 829s 5s/step - loss: 4.4436 - accuracy: 0.9999 - val_loss: 4.3114 - val_accuracy: 0.9745
# Epoch 17/100
# 157/157 [==============================] - 827s 5s/step - loss: 4.1730 - accuracy: 0.9997 - val_loss: 4.1035 - val_accuracy: 0.9520
# Epoch 18/100
# 157/157 [==============================] - 832s 5s/step - loss: 3.9261 - accuracy: 0.9974 - val_loss: 3.8443 - val_accuracy: 0.9615
# Epoch 19/100
# 157/157 [==============================] - 820s 5s/step - loss: 3.6811 - accuracy: 0.9999 - val_loss: 3.5888 - val_accuracy: 0.9700
# Epoch 20/100
# 157/157 [==============================] - 817s 5s/step - loss: 3.4588 - accuracy: 0.9990 - val_loss: 3.3811 - val_accuracy: 0.9710
# Epoch 21/100
# 157/157 [==============================] - 820s 5s/step - loss: 3.2460 - accuracy: 0.9997 - val_loss: 3.1775 - val_accuracy: 0.9715
# Epoch 22/100
# 157/157 [==============================] - 825s 5s/step - loss: 3.0474 - accuracy: 1.0000 - val_loss: 2.9955 - val_accuracy: 0.9705
# Epoch 23/100
# 157/157 [==============================] - 786s 5s/step - loss: 2.8611 - accuracy: 1.0000 - val_loss: 2.8374 - val_accuracy: 0.9710
# Epoch 24/100
# 157/157 [==============================] - 727s 5s/step - loss: 2.6880 - accuracy: 0.9998 - val_loss: 2.6466 - val_accuracy: 0.9745
# Epoch 25/100
# 157/157 [==============================] - 732s 5s/step - loss: 2.5238 - accuracy: 1.0000 - val_loss: 2.4936 - val_accuracy: 0.9705
# Epoch 26/100
# 157/157 [==============================] - 730s 5s/step - loss: 2.3696 - accuracy: 1.0000 - val_loss: 2.3372 - val_accuracy: 0.9725
# Epoch 27/100
# 157/157 [==============================] - 732s 5s/step - loss: 2.2248 - accuracy: 1.0000 - val_loss: 2.2065 - val_accuracy: 0.9710
# Epoch 28/100
# 157/157 [==============================] - 733s 5s/step - loss: 2.0892 - accuracy: 1.0000 - val_loss: 2.0778 - val_accuracy: 0.9705
# Epoch 29/100
# 157/157 [==============================] - 731s 5s/step - loss: 1.9623 - accuracy: 1.0000 - val_loss: 1.9504 - val_accuracy: 0.9730
# Epoch 30/100
# 157/157 [==============================] - 738s 5s/step - loss: 1.8476 - accuracy: 0.9982 - val_loss: 2.1534 - val_accuracy: 0.8805
# Epoch 31/100
# 157/157 [==============================] - 735s 5s/step - loss: 1.7908 - accuracy: 0.9800 - val_loss: 2.0499 - val_accuracy: 0.8435
# Epoch 32/100
# 157/157 [==============================] - 730s 5s/step - loss: 1.6660 - accuracy: 0.9911 - val_loss: 1.6643 - val_accuracy: 0.9625
# Epoch 33/100
# 157/157 [==============================] - 731s 5s/step - loss: 1.5500 - accuracy: 0.9976 - val_loss: 1.5499 - val_accuracy: 0.9745
# Epoch 34/100
# 157/157 [==============================] - 744s 5s/step - loss: 1.4501 - accuracy: 0.9994 - val_loss: 1.4790 - val_accuracy: 0.9680
# Epoch 35/100
# 157/157 [==============================] - 740s 5s/step - loss: 1.3603 - accuracy: 0.9997 - val_loss: 1.3846 - val_accuracy: 0.9695
# Epoch 36/100
# 157/157 [==============================] - 733s 5s/step - loss: 1.2758 - accuracy: 1.0000 - val_loss: 1.2913 - val_accuracy: 0.9750
# Epoch 37/100
# 157/157 [==============================] - 733s 5s/step - loss: 1.1975 - accuracy: 1.0000 - val_loss: 1.2261 - val_accuracy: 0.9720
# Epoch 38/100
# 157/157 [==============================] - 736s 5s/step - loss: 1.1588 - accuracy: 0.9901 - val_loss: 1.2616 - val_accuracy: 0.9390
# Epoch 39/100
# 157/157 [==============================] - 733s 5s/step - loss: 1.0984 - accuracy: 0.9898 - val_loss: 1.2342 - val_accuracy: 0.9170
# Epoch 40/100
# 157/157 [==============================] - 733s 5s/step - loss: 1.0192 - accuracy: 0.9949 - val_loss: 1.1565 - val_accuracy: 0.9250
# Epoch 41/100
# 157/157 [==============================] - 740s 5s/step - loss: 0.9545 - accuracy: 0.9974 - val_loss: 1.0158 - val_accuracy: 0.9580
# Epoch 42/100
# 157/157 [==============================] - 731s 5s/step - loss: 0.8921 - accuracy: 0.9994 - val_loss: 0.9247 - val_accuracy: 0.9710
# Epoch 43/100
# 157/157 [==============================] - ETA: 0s - loss: 0.8389 - accuracy: 0.9994

# %%
model_test_weight_batch_normalization, accuracy = train_data_weight_batch(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 25)
print(accuracy)
y_pred = model_test_weight_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))
# Out:
# Epoch 1/25
# 157/157 [==============================] - 746s 5s/step - loss: 11.7672 - accuracy: 0.8474 - val_loss: 14.2993 - val_accuracy: 0.5000
# Epoch 2/25
# 157/157 [==============================] - 746s 5s/step - loss: 10.8048 - accuracy: 0.9595 - val_loss: 13.5584 - val_accuracy: 0.5000
# Epoch 3/25
# 157/157 [==============================] - 740s 5s/step - loss: 10.1178 - accuracy: 0.9740 - val_loss: 10.4946 - val_accuracy: 0.6350
# Epoch 4/25
# 157/157 [==============================] - 738s 5s/step - loss: 9.4847 - accuracy: 0.9850 - val_loss: 9.3786 - val_accuracy: 0.8345
# Epoch 5/25
# 157/157 [==============================] - 736s 5s/step - loss: 8.8944 - accuracy: 0.9926 - val_loss: 8.5748 - val_accuracy: 0.9480
# Epoch 6/25
# 157/157 [==============================] - 736s 5s/step - loss: 8.3451 - accuracy: 0.9935 - val_loss: 8.0717 - val_accuracy: 0.9460
# Epoch 7/25
# 157/157 [==============================] - 737s 5s/step - loss: 7.8298 - accuracy: 0.9983 - val_loss: 7.5827 - val_accuracy: 0.9500
# Epoch 8/25
# 157/157 [==============================] - 740s 5s/step - loss: 7.3598 - accuracy: 0.9958 - val_loss: 7.1350 - val_accuracy: 0.9490
# Epoch 9/25
# 157/157 [==============================] - 736s 5s/step - loss: 6.9028 - accuracy: 0.9990 - val_loss: 6.6667 - val_accuracy: 0.9680
# Epoch 10/25
# 157/157 [==============================] - 741s 5s/step - loss: 6.4802 - accuracy: 0.9982 - val_loss: 6.2709 - val_accuracy: 0.9630
# Epoch 11/25
# 157/157 [==============================] - 742s 5s/step - loss: 6.0845 - accuracy: 0.9990 - val_loss: 5.8859 - val_accuracy: 0.9680
# Epoch 12/25
# 157/157 [==============================] - 740s 5s/step - loss: 5.7150 - accuracy: 0.9999 - val_loss: 5.5325 - val_accuracy: 0.9700
# Epoch 13/25
# 157/157 [==============================] - 734s 5s/step - loss: 5.3633 - accuracy: 0.9998 - val_loss: 5.2184 - val_accuracy: 0.9615
# Epoch 14/25
# 157/157 [==============================] - 733s 5s/step - loss: 5.0365 - accuracy: 0.9999 - val_loss: 4.8882 - val_accuracy: 0.9670
# Epoch 15/25
# 157/157 [==============================] - 732s 5s/step - loss: 4.7301 - accuracy: 0.9997 - val_loss: 4.6213 - val_accuracy: 0.9630
# Epoch 16/25
# 157/157 [==============================] - 733s 5s/step - loss: 4.4411 - accuracy: 0.9999 - val_loss: 4.3406 - val_accuracy: 0.9650
# Epoch 17/25
# 157/157 [==============================] - 738s 5s/step - loss: 4.1748 - accuracy: 0.9991 - val_loss: 4.2917 - val_accuracy: 0.9025
# Epoch 18/25
# 157/157 [==============================] - 730s 5s/step - loss: 3.9218 - accuracy: 0.9993 - val_loss: 3.8205 - val_accuracy: 0.9690
# Epoch 19/25
# 157/157 [==============================] - 734s 5s/step - loss: 3.6785 - accuracy: 1.0000 - val_loss: 3.6093 - val_accuracy: 0.9675
# Epoch 20/25
# 157/157 [==============================] - 733s 5s/step - loss: 3.4538 - accuracy: 1.0000 - val_loss: 3.3849 - val_accuracy: 0.9680
# Epoch 21/25
# 157/157 [==============================] - 731s 5s/step - loss: 3.2430 - accuracy: 1.0000 - val_loss: 3.2005 - val_accuracy: 0.9625
# Epoch 22/25
# 157/157 [==============================] - 732s 5s/step - loss: 3.0464 - accuracy: 1.0000 - val_loss: 3.0277 - val_accuracy: 0.9625
# Epoch 23/25
# 157/157 [==============================] - 735s 5s/step - loss: 2.8644 - accuracy: 0.9984 - val_loss: 2.8479 - val_accuracy: 0.9650
# Epoch 24/25
# 157/157 [==============================] - 734s 5s/step - loss: 2.6863 - accuracy: 1.0000 - val_loss: 2.6686 - val_accuracy: 0.9650
# Epoch 25/25
# 157/157 [==============================] - 739s 5s/step - loss: 2.5222 - accuracy: 1.0000 - val_loss: 2.4895 - val_accuracy: 0.9720
# 63/63 [==============================] - 35s 549ms/step - loss: 2.4362 - accuracy: 0.9875
# 0.987500011920929
# 988 12 13 987
# TPR/Recall: 0.987
# TNR/Specificity: 0.988
# PPV/Precision: 0.987987987987988
# NPV: 0.987012987012987

# %% [markdown]
# ### Train Data with Data Augmentation, Weight Regularization and Batch Normalization

# %%
def train_data_augmentation_weight_batch(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model_weight_regularization_batch_normalization(learning_rate)
  # create data generator
  datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
  # prepare iterator
  it_train = datagen.flow(X_train, y_train, batch_size=64)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
	# fit model  
  steps = int(X_train.shape[0] / 64)
  history = model.fit(it_train, epochs=epochs, steps_per_epoch=steps, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_data_weight_batch_normalization, accuracy = train_data_augmentation_weight_batch(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 30)
print(accuracy)
y_pred = model_test_data_weight_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))
# Out:
# Epoch 1/30
# 156/156 [==============================] - 743s 5s/step - loss: 11.7987 - accuracy: 0.8378 - val_loss: 13.6819 - val_accuracy: 0.5000
# Epoch 2/30
# 156/156 [==============================] - 732s 5s/step - loss: 10.8533 - accuracy: 0.9463 - val_loss: 11.2205 - val_accuracy: 0.5555
# Epoch 3/30
# 156/156 [==============================] - 739s 5s/step - loss: 10.1833 - accuracy: 0.9510 - val_loss: 9.8027 - val_accuracy: 0.9205
# Epoch 4/30
# 156/156 [==============================] - 745s 5s/step - loss: 9.5651 - accuracy: 0.9554 - val_loss: 9.1817 - val_accuracy: 0.9365
# Epoch 5/30
# 156/156 [==============================] - 742s 5s/step - loss: 8.9921 - accuracy: 0.9567 - val_loss: 8.5747 - val_accuracy: 0.9610
# Epoch 6/30
# 156/156 [==============================] - 742s 5s/step - loss: 8.4398 - accuracy: 0.9598 - val_loss: 8.0671 - val_accuracy: 0.9595
# Epoch 7/30
# 156/156 [==============================] - 743s 5s/step - loss: 7.9361 - accuracy: 0.9608 - val_loss: 7.6207 - val_accuracy: 0.9435
# Epoch 8/30
# 156/156 [==============================] - 746s 5s/step - loss: 7.4505 - accuracy: 0.9663 - val_loss: 7.1307 - val_accuracy: 0.9625
# Epoch 9/30
# 156/156 [==============================] - 755s 5s/step - loss: 7.0068 - accuracy: 0.9679 - val_loss: 6.7173 - val_accuracy: 0.9585
# Epoch 10/30
# 156/156 [==============================] - 743s 5s/step - loss: 6.5778 - accuracy: 0.9723 - val_loss: 6.3797 - val_accuracy: 0.9430
# Epoch 11/30
# 156/156 [==============================] - 746s 5s/step - loss: 6.1870 - accuracy: 0.9731 - val_loss: 5.9315 - val_accuracy: 0.9565
# Epoch 12/30
# 156/156 [==============================] - 746s 5s/step - loss: 5.8035 - accuracy: 0.9770 - val_loss: 5.6143 - val_accuracy: 0.9470
# Epoch 13/30
# 156/156 [==============================] - 763s 5s/step - loss: 5.4566 - accuracy: 0.9782 - val_loss: 5.2348 - val_accuracy: 0.9695
# Epoch 14/30
# 156/156 [==============================] - 752s 5s/step - loss: 5.1223 - accuracy: 0.9820 - val_loss: 4.9163 - val_accuracy: 0.9670
# Epoch 15/30
# 156/156 [==============================] - 755s 5s/step - loss: 4.8279 - accuracy: 0.9755 - val_loss: 4.6273 - val_accuracy: 0.9700
# Epoch 16/30
# 156/156 [==============================] - 749s 5s/step - loss: 4.5265 - accuracy: 0.9818 - val_loss: 4.3662 - val_accuracy: 0.9635
# Epoch 17/30
# 156/156 [==============================] - 753s 5s/step - loss: 4.2683 - accuracy: 0.9761 - val_loss: 4.1763 - val_accuracy: 0.9465
# Epoch 18/30
# 156/156 [==============================] - 765s 5s/step - loss: 4.0094 - accuracy: 0.9796 - val_loss: 3.8414 - val_accuracy: 0.9725
# Epoch 19/30
# 156/156 [==============================] - 753s 5s/step - loss: 3.7700 - accuracy: 0.9803 - val_loss: 3.6471 - val_accuracy: 0.9665
# Epoch 20/30
# 156/156 [==============================] - 755s 5s/step - loss: 3.5406 - accuracy: 0.9821 - val_loss: 3.4495 - val_accuracy: 0.9595
# Epoch 21/30
# 156/156 [==============================] - 754s 5s/step - loss: 3.3354 - accuracy: 0.9819 - val_loss: 3.2889 - val_accuracy: 0.9470
# Epoch 22/30
# 156/156 [==============================] - 764s 5s/step - loss: 3.1384 - accuracy: 0.9804 - val_loss: 3.0709 - val_accuracy: 0.9540
# Epoch 23/30
# 156/156 [==============================] - 753s 5s/step - loss: 2.9476 - accuracy: 0.9824 - val_loss: 2.8448 - val_accuracy: 0.9725
# Epoch 24/30
# 156/156 [==============================] - 745s 5s/step - loss: 2.7722 - accuracy: 0.9834 - val_loss: 2.6952 - val_accuracy: 0.9640
# Epoch 25/30
# 156/156 [==============================] - 744s 5s/step - loss: 2.6031 - accuracy: 0.9856 - val_loss: 2.5126 - val_accuracy: 0.9770
# Epoch 26/30
# 156/156 [==============================] - 743s 5s/step - loss: 2.4492 - accuracy: 0.9863 - val_loss: 2.3657 - val_accuracy: 0.9775
# Epoch 27/30
# 156/156 [==============================] - 741s 5s/step - loss: 2.3107 - accuracy: 0.9825 - val_loss: 2.2800 - val_accuracy: 0.9585
# Epoch 28/30
# 156/156 [==============================] - 738s 5s/step - loss: 2.1719 - accuracy: 0.9858 - val_loss: 2.1088 - val_accuracy: 0.9750
# Epoch 29/30
# 156/156 [==============================] - 736s 5s/step - loss: 2.0415 - accuracy: 0.9868 - val_loss: 2.0620 - val_accuracy: 0.9500
# Epoch 30/30
# 156/156 [==============================] - 738s 5s/step - loss: 1.9395 - accuracy: 0.9783 - val_loss: 1.8885 - val_accuracy: 0.9720
# 63/63 [==============================] - 34s 547ms/step - loss: 1.8759 - accuracy: 0.9740
# 0.9739999771118164
# 960 40 12 988
# TPR/Recall: 0.988
# TNR/Specificity: 0.96
# PPV/Precision: 0.9610894941634242
# NPV: 0.9876543209876543
