# %% [markdown]
# # Imports

# %%
import numpy as np
import glob
from PIL import Image
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from tensorflow.keras import optimizers
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import KFold
import pandas as pd
import seaborn as sn
sn.set(font_scale=1.4) # for label size
import multiprocessing as mp
import csv

# %% [markdown]
# # Load DataSet
#
# 0 means unlikely to have flood damage, 1 means likely to have flood damage
#
# [0,1] --> damage
#
# [1,0] --> no damage

# %% [markdown]
# ## Load Training Set

# %%
images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/train_another/damage/*.jpeg')
dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  dmg_img.append(im_arr)
dmg_img = np.array(dmg_img)

images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/train_another/no_damage/*.jpeg')
no_dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  no_dmg_img.append(im_arr)
no_dmg_img = np.array(no_dmg_img)

X_train = np.concatenate((dmg_img, no_dmg_img))
dmg_img_y = np.array(dmg_img.shape[0] * [[0,1]])
no_dmg_img_y = np.array(no_dmg_img.shape[0] * [[1,0]])
y_train = np.concatenate((dmg_img_y, no_dmg_img_y))

# shuffle arrays so that the array is a mix of damage and no_damage in a random order
shuffler = np.random.permutation(X_train.shape[0])
X_train = X_train[shuffler]
y_train = y_train[shuffler]

# %% [markdown]
# ## Load Validation Set

# %%
images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/validation_another/damage/*.jpeg')
dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  dmg_img.append(im_arr)
dmg_img = np.array(dmg_img)

images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/validation_another/no_damage/*.jpeg')
no_dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  no_dmg_img.append(im_arr)
no_dmg_img = np.array(no_dmg_img)

X_val = np.concatenate((dmg_img, no_dmg_img))
dmg_img_y = np.array(dmg_img.shape[0] * [[0,1]])
no_dmg_img_y = np.array(no_dmg_img.shape[0] * [[1,0]])
y_val = np.concatenate((dmg_img_y, no_dmg_img_y))

# shuffle arrays so that the array is a mix of damage and no_damage in a random order
shuffler = np.random.permutation(X_val.shape[0])
X_val = X_val[shuffler]
y_val = y_val[shuffler]

# %%
# combine training and validation data - for cross-validation
X_all = np.concatenate((X_train, X_val))
y_all = np.concatenate((y_train, y_val))

# %% [markdown]
# ## Load Test Set

# %%
images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/test/damage/*.jpeg')
dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  dmg_img.append(im_arr)
dmg_img = np.array(dmg_img)

images = glob.glob('/kaggle/input/satellite-images-of-hurricane-damage/test/no_damage/*.jpeg')
no_dmg_img = []
for i in images:
  im = Image.open(i)
  im_arr = np.array(im)
  no_dmg_img.append(im_arr)
no_dmg_img = np.array(no_dmg_img)

X_test = np.concatenate((dmg_img, no_dmg_img))
dmg_img_y = np.array(dmg_img.shape[0] * [[0,1]])
no_dmg_img_y = np.array(no_dmg_img.shape[0] * [[1,0]])
y_test = np.concatenate((dmg_img_y, no_dmg_img_y))

# shuffle arrays so that the array is a mix of damage and no_damage in a random order
shuffler = np.random.permutation(X_val.shape[0])
X_test = X_test[shuffler]
y_test = y_test[shuffler]

# %% [markdown]
# ## Input/Output

# %%
# save a dictionary as a csv file
def output_as_csv(name, a):
    path = "/kaggle/working/" + name + ".csv"
    with open(path, 'w') as csv_file:
        # create the csv writer
        writer = csv.writer(csv_file)

        # write a row to the csv file
        writer.writerow(a.keys())
        writer.writerow(a.values())

# input a csv file
def input_csv(path):
    b, keys = {}, {}
    with open(path, mode='r') as csv_file:
        csv_reader = csv.DictReader(csv_file)
        line_count = 0
        for row in csv_reader:
            keys = row
    b = dict(keys)
    return b # returns a dictionary

# %% [markdown]
# # Pre-Process DataSet

# %%
# pre-process data 
def scale_pixels(train, val, test, X_all):
	# convert from integers to floats and normalize between 0-1
  train_norm = train.astype('float32') / 255.0
  val_norm = val.astype('float32') / 255.0
  test_norm = test.astype('float32') / 255.0
  X_all_norm = X_all.astype('float32') / 255.0
	# return normalized images
  return train_norm, val_norm, test_norm, X_all_norm

X_train, X_val, X_test, X_all = scale_pixels(X_train, X_val, X_test, X_all)

# %% [markdown]
# # Plot Diagnostics

# %%
# plot diagnostic learning curves
def summarize_diagnostics(history):
  # blue = training data; orange = validation data
	# plot validation loss
	plt.subplot(211)
	plt.title('Cross Entropy Loss')
	plt.plot(history.history['loss'], color='blue', label='train')
	plt.plot(history.history['val_loss'], color='orange', label='validation')
	# plot accuracy
	plt.subplot(212)
	plt.title('Classification Accuracy')
	plt.plot(history.history['accuracy'], color='blue', label='train')
	plt.plot(history.history['val_accuracy'], color='orange', label='validation')

# %%
# returns the confusion matrix
def find_confusion_matrix(model, X_test, y_test):
    y_pred = model.predict(X_test)
    y_pred_val = y_pred.argmax(axis=1)
    y_test_val = y_test.argmax(axis=1)
    return confusion_matrix(y_test_val, y_pred_val)

# returns the confusion matrix based on tn, fn, fp, tp
def find_confusion_matrix_2(tn, fn, fp, tp):
    return [[tn, fp], [fn, tp]]

# generate heat map for confusion matrix
def heatmap(confusion_matrix):
    df = pd.DataFrame(confusion_matrix, index = ['F', 'T'], columns = ['F', 'T'])
    sn.heatmap(df, annot=True) # create a heatmap
    
# returns normalized confusion matrix
def normalize_confusion_matrix(confusion_matrix):
    confusion_matrix = np.array(confusion_matrix)
    confusion_matrix_sum = confusion_matrix.astype(np.float).sum(axis=1)
    confusion_matrix_norm = confusion_matrix.astype(np.float)
    confusion_matrix_norm[0] = confusion_matrix_norm[0] / confusion_matrix_sum[0]
    confusion_matrix_norm[1] = confusion_matrix_norm[1] / confusion_matrix_sum[1]
    return confusion_matrix_norm

def print_confusion_matrix_results(results):
    # results is a dictionary
    # calculate mean and standard deviation for each key
    for key in results:
        mean = np.mean(results[key])
        std = np.std(results[key])
        print("{} mean: {}".format(key, mean))
        print("{} std: {}".format(key, std))

# %% [markdown]
# # Create CNN Model

# %%
# define cnn model
def define_model(learning_rate):
  model = keras.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(128, 128, 3)))
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Flatten())
  model.add(layers.Dense(128, activation='relu', kernel_initializer='he_uniform'))
  model.add(layers.Dense(2, activation='softmax'))  # compile model
  opt = optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
  model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
  return model

# %% [markdown]
# ## CNN Model with Batch Normalization

# %%
# define cnn model
def define_model_batch_normalization(learning_rate):
  model = keras.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(128, 128, 3)))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Flatten())
  model.add(layers.Dense(128, activation='relu', kernel_initializer='he_uniform'))
  model.add(layers.BatchNormalization())
  model.add(layers.Dense(2, activation='softmax'))  # compile model
  opt = optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
  model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
  return model

# %% [markdown]
# ## CNN Model with Dropout Regularization

# %%
# define cnn model
def define_model_dropout_regularization(learning_rate):
  model = keras.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(128, 128, 3)))
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.2)) # retain 80% of neurons
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.3))
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.4))
  model.add(layers.Flatten())
  model.add(layers.Dense(128, activation='relu', kernel_initializer='he_uniform'))
  model.add(layers.Dropout(0.5))
  model.add(layers.Dense(2, activation='softmax'))  # compile model
  opt = optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
  model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
  return model

# %% [markdown]
# ### CNN Model with Dropout Regularization and Batch Normalization

# %%
# define cnn model
def define_model_dropout_regularization_batch_normalization(learning_rate):
  model = keras.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(128, 128, 3)))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.2)) # retain 80% of neurons
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.3))
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.4))
  model.add(layers.Flatten())
  model.add(layers.Dense(128, activation='relu', kernel_initializer='he_uniform'))
  model.add(layers.BatchNormalization())
  model.add(layers.Dropout(0.5))
  model.add(layers.Dense(2, activation='softmax'))  # compile model
  opt = optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
  model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
  return model

# %% [markdown]
# ## CNN Model with Weight Regularization

# %%
# define cnn model
def define_model_weight_regularization(learning_rate):
  model = keras.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.01), input_shape=(128, 128, 3)))
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Flatten())
  model.add(layers.Dense(128, activation='relu', kernel_initializer='he_uniform', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.Dense(2, activation='softmax'))  # compile model
  opt = optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
  model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
  return model

# %% [markdown]
# ### CNN Model with Weight Regularization and Batch Normalization

# %%
# define cnn model
def define_model_weight_regularization_batch_normalization(learning_rate):
  model = keras.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.01), input_shape=(128, 128, 3)))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Flatten())
  model.add(layers.Dense(128, activation='relu', kernel_initializer='he_uniform', kernel_regularizer=regularizers.l2(0.01)))
  model.add(layers.BatchNormalization())
  model.add(layers.Dense(2, activation='softmax'))  # compile model
  opt = optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
  model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
  return model

# %%
# define cnn model
def define_model_weight_regularization_batch_normalization2(learning_rate, regularization_lambda):
  model = keras.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(regularization_lambda), input_shape=(128, 128, 3)))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(regularization_lambda)))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(regularization_lambda)))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(regularization_lambda)))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(regularization_lambda)))
  model.add(layers.BatchNormalization())
  model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=regularizers.l2(regularization_lambda)))
  model.add(layers.BatchNormalization())
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Flatten())
  model.add(layers.Dense(128, activation='relu', kernel_initializer='he_uniform', kernel_regularizer=regularizers.l2(regularization_lambda)))
  model.add(layers.BatchNormalization())
  model.add(layers.Dense(2, activation='softmax'))  # compile model
  opt = optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
  model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
  return model

# %% [markdown]
# # Train Data
# Hyperparameters are inputted into the function

# %%
def train(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model(learning_rate)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
  # fit model
  history = model.fit(X_train, y_train, epochs=epochs, batch_size=64, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test, accuracy = train(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 75)
print(accuracy)
y_pred = model_test.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %% [markdown]
# ## Train Data w/ Cross Validation

# %%
def benchmark_model(X_all, y_all, split):
    X_train_cv, y_train_cv = X_all[split[0]], y_all[split[0]]
    X_val_cv, y_val_cv = X_all[split[1]], y_all[split[1]]
    model, accuracy = train(X_train_cv, X_val_cv, X_val_cv, y_train_cv, y_val_cv, y_val_cv, 0.001, 75) 
    results = {}
#     results["model"] = model
    results["accuracy"] = accuracy
    results["confusion_matrix"] = find_confusion_matrix(model, X_val_cv, y_val_cv)
    tn, fp, fn, tp = results["confusion_matrix"].ravel()
    results["tn"] = tn
    results["fp"] = fp
    results["fn"] = fn
    results["tp"] = tp
    results["TPR/Recall"] = tp/(tp+fn)
    results["TNR/Specificity"] = tn/(tn+fp)
    results["PPV/Precision"] = tp/(tp+fp)
    results["NPV"] = tn/(tn+fn)
    return results

# %%
kf = KFold(n_splits=5)
folds = list(kf.split(X_all, y_all))

# %%
output_as_csv("normal_fold_1", benchmark_model(X_all, y_all, folds[0]))

# %%
output_as_csv("normal_fold_2", benchmark_model(X_all, y_all, folds[1]))

# %%
output_as_csv("normal_fold_3", benchmark_model(X_all, y_all, folds[2]))

# %%
output_as_csv("normal_fold_4", benchmark_model(X_all, y_all, folds[3]))

# %%
output_as_csv("normal_fold_5", benchmark_model(X_all, y_all, folds[4]))

# %%
# results_list is a list of dictionaries
results_list = []
for i in range(1,6):
    path = "../input/hurricane-normal-cv/normal_fold_" + str(i) + ".csv"
    results_list.append(input_csv(path))

# results_dict is a dictionary of lists
results_dict = {}
results_dict["accuracy"] = [(float)(i["accuracy"]) for i in results_list]
results_dict["TPR/Recall"] = [(float)(i["TPR/Recall"]) for i in results_list]
results_dict["TNR/Specificity"] = [(float)(i["TNR/Specificity"]) for i in results_list]
results_dict["PPV/Precision"] = [(float)(i["PPV/Precision"]) for i in results_list]
results_dict["NPV"] = [(float)(i["NPV"]) for i in results_list]

print_confusion_matrix_results(results_dict)

# %%
# find confusion matrices
results_dict["tn"] = [(int)(i["tn"]) for i in results_list]
results_dict["fp"] = [(int)(i["fp"]) for i in results_list]
results_dict["fn"] = [(int)(i["fn"]) for i in results_list]
results_dict["tp"] = [(int)(i["tp"]) for i in results_list]
results_dict["confusion_matrix"] = []
# append confusion matrix for each cross-validation fold
for i in range(len(folds)):
    results_dict["confusion_matrix"].append(find_confusion_matrix_2(results_dict["tn"][i], results_dict["fp"][i], results_dict["fn"][i], results_dict["tp"][i]))
                                            
# total confusion matrix summed together
confusion_matrix_list = []
confusion_matrix_list = results_dict["confusion_matrix"]
confusion_matrix_comb = np.sum(confusion_matrix_list, axis=0)
heatmap(confusion_matrix_comb)

# %%
# normalized confusion matrix
confusion_matrix_norm = normalize_confusion_matrix(confusion_matrix_comb)
heatmap(confusion_matrix_norm)

# %% [markdown]
# ## Train Data with Batch Normalization

# %%
def train_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model_batch_normalization(learning_rate)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
  # fit model
  history = model.fit(X_train, y_train, epochs=epochs, batch_size=64, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_batch_normalization, accuracy = train_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 75)
print(accuracy)
y_pred = model_test_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))
# Out:
# Epoch 1/75
# 157/157 [==============================] - 680s 4s/step - loss: 0.4033 - accuracy: 0.8368 - val_loss: 2.4852 - val_accuracy: 0.5000
# Epoch 2/75
# 139/157 [=========================>....] - ETA: 1:13 - loss: 0.1080 - accuracy: 0.9624

# %% [markdown]
# ### Tune Hyperparameters - learning rate

# %%
model_test_batch_normalization, accuracy = train_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, 0.0005, 75)
print(accuracy)
y_pred = model_test_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_batch_normalization, accuracy = train_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, 0.005, 40)
print(accuracy)
y_pred = model_test_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_batch_normalization, accuracy = train_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, 0.01, 40)
print(accuracy)
y_pred = model_test_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_batch_normalization, accuracy = train_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, 0.1, 40)
print(accuracy)
y_pred = model_test_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %% [markdown]
# ### Tune Hyperparameters - batch size

# %%
def train_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, batch_size, epochs):
  # define model
  model = define_model_batch_normalization(learning_rate)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
  # fit model
  history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_batch_normalization, accuracy = train_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, 0.005, 128, 40)
print(accuracy)
y_pred = model_test_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_batch_normalization, accuracy = train_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, 0.005, 32, 40)
print(accuracy)
y_pred = model_test_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_batch_normalization, accuracy = train_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, 0.005, 256, 40)
print(accuracy)
y_pred = model_test_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %% [markdown]
# ### Train Data with Batch Normalization and Cross Validation

# %%
def benchmark_model_batch_normalization(X_all, y_all, split):
    X_train_cv, y_train_cv = X_all[split[0]], y_all[split[0]]
    X_val_cv, y_val_cv = X_all[split[1]], y_all[split[1]]
    model, accuracy = train_batch_normalization(X_train_cv, X_val_cv, X_val_cv, y_train_cv, y_val_cv, y_val_cv, 0.001, 40) 
    results = {}
#     results["model"] = model
    results["accuracy"] = accuracy
    results["confusion_matrix"] = find_confusion_matrix(model, X_val_cv, y_val_cv)
    tn, fp, fn, tp = results["confusion_matrix"].ravel()
    results["tn"] = tn
    results["fp"] = fp
    results["fn"] = fn
    results["tp"] = tp
    results["TPR/Recall"] = tp/(tp+fn)
    results["TNR/Specificity"] = tn/(tn+fp)
    results["PPV/Precision"] = tp/(tp+fp)
    results["NPV"] = tn/(tn+fn)
    return results

# %%
kf = KFold(n_splits=5)
folds = list(kf.split(X_all, y_all))

# %%
output_as_csv("batch normalization fold 1", benchmark_model_batch_normalization(X_all, y_all, folds[0]))

# %%
output_as_csv("batch normalization fold 2", benchmark_model_batch_normalization(X_all, y_all, folds[1]))

# %%
output_as_csv("batch normalization fold 3", benchmark_model_batch_normalization(X_all, y_all, folds[2]))
# Out:
# Epoch 1/40
# 150/150 [==============================] - 710s 5s/step - loss: 0.3873 - accuracy: 0.8515 - val_loss: 2.6192 - val_accuracy: 0.5013
# Epoch 2/40
# 150/150 [==============================] - 698s 5s/step - loss: 0.1163 - accuracy: 0.9594 - val_loss: 2.8017 - val_accuracy: 0.5017
# Epoch 3/40
# 150/150 [==============================] - 703s 5s/step - loss: 0.0759 - accuracy: 0.9761 - val_loss: 1.3615 - val_accuracy: 0.5704
# Epoch 4/40
# 150/150 [==============================] - 699s 5s/step - loss: 0.0573 - accuracy: 0.9835 - val_loss: 0.2299 - val_accuracy: 0.9067
# Epoch 5/40
# 150/150 [==============================] - 700s 5s/step - loss: 0.0430 - accuracy: 0.9910 - val_loss: 0.1221 - val_accuracy: 0.9558
# Epoch 6/40
# 150/150 [==============================] - 700s 5s/step - loss: 0.0290 - accuracy: 0.9957 - val_loss: 0.0942 - val_accuracy: 0.9667
# Epoch 7/40
# 150/150 [==============================] - 693s 5s/step - loss: 0.0241 - accuracy: 0.9976 - val_loss: 0.0843 - val_accuracy: 0.9712
# Epoch 8/40
# 150/150 [==============================] - 694s 5s/step - loss: 0.0186 - accuracy: 0.9978 - val_loss: 0.0835 - val_accuracy: 0.9704
# Epoch 9/40
# 150/150 [==============================] - 702s 5s/step - loss: 0.0182 - accuracy: 0.9978 - val_loss: 0.0817 - val_accuracy: 0.9692
# Epoch 10/40
# 150/150 [==============================] - 703s 5s/step - loss: 0.0120 - accuracy: 0.9989 - val_loss: 0.0834 - val_accuracy: 0.9696
# Epoch 11/40
# 150/150 [==============================] - 707s 5s/step - loss: 0.0119 - accuracy: 0.9995 - val_loss: 0.0906 - val_accuracy: 0.9658
# Epoch 12/40
# 150/150 [==============================] - 707s 5s/step - loss: 0.0099 - accuracy: 0.9997 - val_loss: 0.0814 - val_accuracy: 0.9704
# Epoch 13/40
# 150/150 [==============================] - 699s 5s/step - loss: 0.0084 - accuracy: 0.9998 - val_loss: 0.0827 - val_accuracy: 0.9692
# Epoch 14/40
# 150/150 [==============================] - 692s 5s/step - loss: 0.0070 - accuracy: 0.9997 - val_loss: 0.0764 - val_accuracy: 0.9733
# Epoch 15/40
# 150/150 [==============================] - 694s 5s/step - loss: 0.0069 - accuracy: 0.9994 - val_loss: 0.0813 - val_accuracy: 0.9721
# Epoch 16/40
# 150/150 [==============================] - 700s 5s/step - loss: 0.0069 - accuracy: 0.9992 - val_loss: 0.0817 - val_accuracy: 0.9700
# Epoch 17/40
# 150/150 [==============================] - 701s 5s/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0800 - val_accuracy: 0.9729
# Epoch 18/40
# 150/150 [==============================] - 698s 5s/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.0745 - val_accuracy: 0.9725
# Epoch 19/40
# 150/150 [==============================] - 699s 5s/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0743 - val_accuracy: 0.9733
# Epoch 20/40
# 150/150 [==============================] - 704s 5s/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0828 - val_accuracy: 0.9721
# Epoch 21/40
# 150/150 [==============================] - 703s 5s/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0812 - val_accuracy: 0.9725
# Epoch 22/40
# 150/150 [==============================] - 700s 5s/step - loss: 0.0051 - accuracy: 0.9994 - val_loss: 0.0794 - val_accuracy: 0.9717
# Epoch 23/40
# 150/150 [==============================] - 700s 5s/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0788 - val_accuracy: 0.9721
# Epoch 24/40
# 150/150 [==============================] - 689s 5s/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0773 - val_accuracy: 0.9737
# Epoch 00024: early stopping
# 75/75 [==============================] - 41s 538ms/step - loss: 0.0773 - accuracy: 0.9737

# %%
output_as_csv("batch normalization fold 4", benchmark_model_batch_normalization(X_all, y_all, folds[3]))
# Out:
# Epoch 1/40
# 150/150 [==============================] - 709s 5s/step - loss: 0.3893 - accuracy: 0.8482 - val_loss: 3.2578 - val_accuracy: 0.5017
# Epoch 2/40
# 150/150 [==============================] - 708s 5s/step - loss: 0.1135 - accuracy: 0.9632 - val_loss: 1.5931 - val_accuracy: 0.5304
# Epoch 3/40
# 150/150 [==============================] - 707s 5s/step - loss: 0.0775 - accuracy: 0.9776 - val_loss: 0.3780 - val_accuracy: 0.8250
# Epoch 4/40
# 150/150 [==============================] - 704s 5s/step - loss: 0.0514 - accuracy: 0.9884 - val_loss: 0.1279 - val_accuracy: 0.9492
# Epoch 5/40
# 150/150 [==============================] - 703s 5s/step - loss: 0.0333 - accuracy: 0.9945 - val_loss: 0.0989 - val_accuracy: 0.9629
# Epoch 6/40
# 150/150 [==============================] - 701s 5s/step - loss: 0.0313 - accuracy: 0.9944 - val_loss: 0.1006 - val_accuracy: 0.9667
# Epoch 7/40
# 150/150 [==============================] - 701s 5s/step - loss: 0.0212 - accuracy: 0.9974 - val_loss: 0.0870 - val_accuracy: 0.9642
# Epoch 8/40
# 150/150 [==============================] - 706s 5s/step - loss: 0.0199 - accuracy: 0.9982 - val_loss: 0.0918 - val_accuracy: 0.9646
# Epoch 9/40
# 150/150 [==============================] - 698s 5s/step - loss: 0.0151 - accuracy: 0.9984 - val_loss: 0.0846 - val_accuracy: 0.9671
# Epoch 10/40
# 150/150 [==============================] - 700s 5s/step - loss: 0.0127 - accuracy: 0.9992 - val_loss: 0.0942 - val_accuracy: 0.9646
# Epoch 11/40
# 150/150 [==============================] - 703s 5s/step - loss: 0.0151 - accuracy: 0.9982 - val_loss: 0.0826 - val_accuracy: 0.9704
# Epoch 12/40
# 150/150 [==============================] - 703s 5s/step - loss: 0.0089 - accuracy: 0.9996 - val_loss: 0.0931 - val_accuracy: 0.9642
# Epoch 13/40
# 150/150 [==============================] - 700s 5s/step - loss: 0.0093 - accuracy: 0.9993 - val_loss: 0.0865 - val_accuracy: 0.9679
# Epoch 14/40
# 150/150 [==============================] - 698s 5s/step - loss: 0.0084 - accuracy: 0.9998 - val_loss: 0.0801 - val_accuracy: 0.9692
# Epoch 15/40
# 150/150 [==============================] - 700s 5s/step - loss: 0.0067 - accuracy: 0.9996 - val_loss: 0.0819 - val_accuracy: 0.9704
# Epoch 16/40
# 150/150 [==============================] - 695s 5s/step - loss: 0.0058 - accuracy: 0.9998 - val_loss: 0.0791 - val_accuracy: 0.9712
# Epoch 17/40
# 150/150 [==============================] - 697s 5s/step - loss: 0.0053 - accuracy: 0.9999 - val_loss: 0.0847 - val_accuracy: 0.9675
# Epoch 18/40
# 150/150 [==============================] - 696s 5s/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.0777 - val_accuracy: 0.9688
# Epoch 19/40
# 150/150 [==============================] - 702s 5s/step - loss: 0.0049 - accuracy: 0.9999 - val_loss: 0.0888 - val_accuracy: 0.9679
# Epoch 20/40
# 150/150 [==============================] - 699s 5s/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.0789 - val_accuracy: 0.9688
# Epoch 21/40
# 150/150 [==============================] - 703s 5s/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0828 - val_accuracy: 0.9683
# Epoch 22/40
# 150/150 [==============================] - 702s 5s/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0791 - val_accuracy: 0.9717
# Epoch 23/40
# 150/150 [==============================] - 697s 5s/step - loss: 0.0036 - accuracy: 0.9999 - val_loss: 0.0819 - val_accuracy: 0.9679
# Epoch 00023: early stopping
# 75/75 [==============================] - 41s 547ms/step - loss: 0.0819 - accuracy: 0.9679

# %%
output_as_csv("batch normalization fold 5", benchmark_model_batch_normalization(X_all, y_all, folds[4]))
# Out:
# Epoch 1/40
# 150/150 [==============================] - 657s 4s/step - loss: 0.4069 - accuracy: 0.8403 - val_loss: 2.4030 - val_accuracy: 0.5046
# Epoch 2/40
# 150/150 [==============================] - 657s 4s/step - loss: 0.1196 - accuracy: 0.9589 - val_loss: 1.6775 - val_accuracy: 0.5146
# Epoch 3/40
# 150/150 [==============================] - 653s 4s/step - loss: 0.0848 - accuracy: 0.9728 - val_loss: 0.2208 - val_accuracy: 0.9167
# Epoch 4/40
# 150/150 [==============================] - 654s 4s/step - loss: 0.0619 - accuracy: 0.9857 - val_loss: 0.1291 - val_accuracy: 0.9529
# Epoch 5/40
# 150/150 [==============================] - 656s 4s/step - loss: 0.0446 - accuracy: 0.9896 - val_loss: 0.1014 - val_accuracy: 0.9625
# Epoch 6/40
# 150/150 [==============================] - 656s 4s/step - loss: 0.0312 - accuracy: 0.9957 - val_loss: 0.1603 - val_accuracy: 0.9337
# Epoch 7/40
# 150/150 [==============================] - 657s 4s/step - loss: 0.0279 - accuracy: 0.9957 - val_loss: 0.0974 - val_accuracy: 0.9663
# Epoch 8/40
# 150/150 [==============================] - 656s 4s/step - loss: 0.0211 - accuracy: 0.9969 - val_loss: 0.0937 - val_accuracy: 0.9638
# Epoch 9/40
# 150/150 [==============================] - 662s 4s/step - loss: 0.0167 - accuracy: 0.9985 - val_loss: 0.0937 - val_accuracy: 0.9654
# Epoch 10/40
# 150/150 [==============================] - 656s 4s/step - loss: 0.0138 - accuracy: 0.9990 - val_loss: 0.1044 - val_accuracy: 0.9642
# Epoch 11/40
# 150/150 [==============================] - 656s 4s/step - loss: 0.0106 - accuracy: 0.9995 - val_loss: 0.0930 - val_accuracy: 0.9683
# Epoch 12/40
# 150/150 [==============================] - 657s 4s/step - loss: 0.0104 - accuracy: 0.9994 - val_loss: 0.0947 - val_accuracy: 0.9683
# Epoch 13/40
# 150/150 [==============================] - 659s 4s/step - loss: 0.0106 - accuracy: 0.9986 - val_loss: 0.0965 - val_accuracy: 0.9667
# Epoch 14/40
# 150/150 [==============================] - 657s 4s/step - loss: 0.0081 - accuracy: 0.9994 - val_loss: 0.0917 - val_accuracy: 0.9650
# Epoch 15/40
# 150/150 [==============================] - 661s 4s/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.0930 - val_accuracy: 0.9671
# Epoch 16/40
# 150/150 [==============================] - 658s 4s/step - loss: 0.0070 - accuracy: 0.9997 - val_loss: 0.0892 - val_accuracy: 0.9688
# Epoch 17/40
# 150/150 [==============================] - 662s 4s/step - loss: 0.0054 - accuracy: 0.9999 - val_loss: 0.0880 - val_accuracy: 0.9688
# Epoch 18/40
# 150/150 [==============================] - 662s 4s/step - loss: 0.0053 - accuracy: 0.9999 - val_loss: 0.0919 - val_accuracy: 0.9683
# Epoch 19/40
# 150/150 [==============================] - 661s 4s/step - loss: 0.0048 - accuracy: 0.9999 - val_loss: 0.0938 - val_accuracy: 0.9675
# Epoch 20/40
# 150/150 [==============================] - 663s 4s/step - loss: 0.0044 - accuracy: 0.9997 - val_loss: 0.0942 - val_accuracy: 0.9663
# Epoch 21/40
# 150/150 [==============================] - 660s 4s/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0901 - val_accuracy: 0.9683
# Epoch 22/40
# 150/150 [==============================] - 658s 4s/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0903 - val_accuracy: 0.9708
# Epoch 00022: early stopping
# 75/75 [==============================] - 37s 493ms/step - loss: 0.0903 - accuracy: 0.9708

# %%
# results_list is a list of dictionaries
results_list = []
for i in range(1,6):
    path = "../input/hurricane-vgg-batch-cv/batch normalization fold " + str(i) + ".csv"
    results_list.append(input_csv(path))

# results_dict is a dictionary of lists
results_dict = {}
results_dict["accuracy"] = [(float)(i["accuracy"]) for i in results_list]
results_dict["TPR/Recall"] = [(float)(i["TPR/Recall"]) for i in results_list]
results_dict["TNR/Specificity"] = [(float)(i["TNR/Specificity"]) for i in results_list]
results_dict["PPV/Precision"] = [(float)(i["PPV/Precision"]) for i in results_list]
results_dict["NPV"] = [(float)(i["NPV"]) for i in results_list]

print_confusion_matrix_results(results_dict)
# Out:
# accuracy mean: 0.9689166665077209
# accuracy std: 0.0033187192837331437
# TPR/Recall mean: 0.9677311238255545
# TPR/Recall std: 0.002983778373286682
# TNR/Specificity mean: 0.9701426525472175
# TNR/Specificity std: 0.005381008154642171
# PPV/Precision mean: 0.9698174684873202
# PPV/Precision std: 0.005849372313512931
# NPV mean: 0.9680072678272849
# NPV std: 0.002950451515377476

# %%
# find confusion matrices
results_dict["tn"] = [(int)(i["tn"]) for i in results_list]
results_dict["fp"] = [(int)(i["fp"]) for i in results_list]
results_dict["fn"] = [(int)(i["fn"]) for i in results_list]
results_dict["tp"] = [(int)(i["tp"]) for i in results_list]
results_dict["confusion_matrix"] = []
# append confusion matrix for each cross-validation fold
for i in range(len(folds)):
    results_dict["confusion_matrix"].append(find_confusion_matrix_2(results_dict["tn"][i], results_dict["fp"][i], results_dict["fn"][i], results_dict["tp"][i]))
                                            
# total confusion matrix summed together
confusion_matrix_list = []
confusion_matrix_list = results_dict["confusion_matrix"]
confusion_matrix_comb = np.sum(confusion_matrix_list, axis=0)
heatmap(confusion_matrix_comb)

# %%
# normalized confusion matrix
confusion_matrix_norm = normalize_confusion_matrix(confusion_matrix_comb)
heatmap(confusion_matrix_norm)

# %% [markdown]
# ## Train Data with Data Augmentation

# %%
def train_data_augmentation(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model(learning_rate)
  # create data generator
  datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
  # prepare iterator
  it_train = datagen.flow(X_train, y_train, batch_size=64)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=8, verbose=1)
	# fit model
  steps = int(X_train.shape[0] / 64)
  history = model.fit(it_train, epochs=epochs, steps_per_epoch=steps, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_data, accuracy = train_data_augmentation(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 50)
print(accuracy)
y_pred = model_test_data.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %% [markdown]
# ### Train Data with Data Augmentation and Batch Normalization

# %%
def train_data_augmentation_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model_batch_normalization(learning_rate)
  # create data generator
  datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
  # prepare iterator
  it_train = datagen.flow(X_train, y_train, batch_size=64)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
	# fit model  
  steps = int(X_train.shape[0] / 64)
  history = model.fit(it_train, epochs=epochs, steps_per_epoch=steps, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_data_augmentation_batch_normalization, accuracy = train_data_augmentation_batch_normalization(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 100)
print(accuracy)
y_pred = model_test_data_augmentation_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %% [markdown]
# ## Train Data with Dropout Regularization and Batch Normalization

# %%
def train_data_dropout_batch(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model_dropout_regularization_batch_normalization(learning_rate)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
  # fit model
  history = model.fit(X_train, y_train, epochs=epochs, batch_size=64, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_data_dropout_batch_normalization, accuracy = train_data_dropout_batch(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 40)
print(accuracy)
y_pred = model_test_data_dropout_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %% [markdown]
# ### Train Data with Data Augmentation, Dropout Regularization and Batch Normalization

# %%
def train_data_augmentation_dropout_batch(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model_weight_regularization_batch_normalization(learning_rate)
  # create data generator
  datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
  # prepare iterator
  it_train = datagen.flow(X_train, y_train, batch_size=64)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
	# fit model  
  steps = int(X_train.shape[0] / 64)
  history = model.fit(it_train, epochs=epochs, steps_per_epoch=steps, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_data_dropout_batch_normalization, accuracy = train_data_augmentation_dropout_batch(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 25)
print(accuracy)
y_pred = model_test_data_dropout_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %% [markdown]
# ## Train Data with Weight Regularization and Batch Normalization

# %%
def train_data_weight_batch(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model_weight_regularization_batch_normalization(learning_rate)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
  # fit model
  history = model.fit(X_train, y_train, epochs=epochs, batch_size=64, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_weight_batch_normalization, accuracy = train_data_weight_batch(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 40)
print(accuracy)
y_pred = model_test_weight_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_weight_batch_normalization, accuracy = train_data_weight_batch(X_train, X_val, X_test, y_train, y_val, y_test, 0.01, 40)
print(accuracy)
y_pred = model_test_weight_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_weight_batch_normalization, accuracy = train_data_weight_batch(X_train, X_val, X_test, y_train, y_val, y_test, 0.003, 40)
print(accuracy)
y_pred = model_test_weight_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_weight_batch_normalization, accuracy = train_data_weight_batch(X_train, X_val, X_test, y_train, y_val, y_test, 0.002, 40)
print(accuracy)
y_pred = model_test_weight_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_weight_batch_normalization, accuracy = train_data_weight_batch(X_train, X_val, X_test, y_train, y_val, y_test, 0.0009, 40)
print(accuracy)
y_pred = model_test_weight_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))
# Out:
# Epoch 1/40
# 157/157 [==============================] - 687s 4s/step - loss: 11.7341 - accuracy: 0.8613 - val_loss: 13.8267 - val_accuracy: 0.5000
# Epoch 2/40
# 157/157 [==============================] - 673s 4s/step - loss: 10.8701 - accuracy: 0.9625 - val_loss: 12.5777 - val_accuracy: 0.5055
# Epoch 3/40
# 157/157 [==============================] - 674s 4s/step - loss: 10.2517 - accuracy: 0.9721 - val_loss: 10.2359 - val_accuracy: 0.7685
# Epoch 4/40
# 157/157 [==============================] - 683s 4s/step - loss: 9.6708 - accuracy: 0.9822 - val_loss: 9.4022 - val_accuracy: 0.9270
# Epoch 5/40
# 157/157 [==============================] - 680s 4s/step - loss: 9.1231 - accuracy: 0.9917 - val_loss: 8.8119 - val_accuracy: 0.9645
# Epoch 6/40
# 157/157 [==============================] - 676s 4s/step - loss: 8.6150 - accuracy: 0.9932 - val_loss: 8.3295 - val_accuracy: 0.9580
# Epoch 7/40
# 157/157 [==============================] - 679s 4s/step - loss: 8.1329 - accuracy: 0.9969 - val_loss: 7.9166 - val_accuracy: 0.9525
# Epoch 8/40
# 157/157 [==============================] - 682s 4s/step - loss: 7.6806 - accuracy: 0.9984 - val_loss: 7.4522 - val_accuracy: 0.9610
# Epoch 9/40
# 157/157 [==============================] - 685s 4s/step - loss: 7.2561 - accuracy: 0.9990 - val_loss: 7.0581 - val_accuracy: 0.9605
# Epoch 10/40
# 157/157 [==============================] - 678s 4s/step - loss: 6.8551 - accuracy: 0.9991 - val_loss: 6.6637 - val_accuracy: 0.9665
# Epoch 11/40
# 157/157 [==============================] - 674s 4s/step - loss: 6.4770 - accuracy: 0.9991 - val_loss: 6.3094 - val_accuracy: 0.9585
# Epoch 12/40
# 157/157 [==============================] - 676s 4s/step - loss: 6.1278 - accuracy: 0.9981 - val_loss: 5.9584 - val_accuracy: 0.9645
# Epoch 13/40
# 157/157 [==============================] - 677s 4s/step - loss: 5.7853 - accuracy: 0.9998 - val_loss: 5.6389 - val_accuracy: 0.9680
# Epoch 14/40
# 157/157 [==============================] - 678s 4s/step - loss: 5.4666 - accuracy: 0.9996 - val_loss: 5.3259 - val_accuracy: 0.9700
# Epoch 15/40
# 157/157 [==============================] - 679s 4s/step - loss: 5.1629 - accuracy: 1.0000 - val_loss: 5.0370 - val_accuracy: 0.9695
# Epoch 16/40
# 157/157 [==============================] - 674s 4s/step - loss: 4.8817 - accuracy: 0.9994 - val_loss: 4.7665 - val_accuracy: 0.9650
# Epoch 17/40
# 157/157 [==============================] - 677s 4s/step - loss: 4.6105 - accuracy: 1.0000 - val_loss: 4.5055 - val_accuracy: 0.9690
# Epoch 18/40
# 157/157 [==============================] - 678s 4s/step - loss: 4.3572 - accuracy: 0.9999 - val_loss: 4.2576 - val_accuracy: 0.9690
# Epoch 19/40
# 157/157 [==============================] - 674s 4s/step - loss: 4.1166 - accuracy: 1.0000 - val_loss: 4.0348 - val_accuracy: 0.9700
# Epoch 20/40
# 157/157 [==============================] - 678s 4s/step - loss: 3.8925 - accuracy: 0.9995 - val_loss: 3.8231 - val_accuracy: 0.9665
# Epoch 21/40
# 157/157 [==============================] - 677s 4s/step - loss: 3.6841 - accuracy: 0.9988 - val_loss: 3.6069 - val_accuracy: 0.9685
# Epoch 22/40
# 157/157 [==============================] - 678s 4s/step - loss: 3.4751 - accuracy: 0.9999 - val_loss: 3.4156 - val_accuracy: 0.9710
# Epoch 23/40
# 157/157 [==============================] - 679s 4s/step - loss: 3.2832 - accuracy: 1.0000 - val_loss: 3.2519 - val_accuracy: 0.9705
# Epoch 24/40
# 157/157 [==============================] - 674s 4s/step - loss: 3.1040 - accuracy: 1.0000 - val_loss: 3.0812 - val_accuracy: 0.9665
# Epoch 25/40
# 157/157 [==============================] - 679s 4s/step - loss: 2.9327 - accuracy: 1.0000 - val_loss: 2.9056 - val_accuracy: 0.9690
# Epoch 26/40
# 157/157 [==============================] - 677s 4s/step - loss: 2.7715 - accuracy: 1.0000 - val_loss: 2.7409 - val_accuracy: 0.9680
# Epoch 27/40
# 157/157 [==============================] - 675s 4s/step - loss: 2.6189 - accuracy: 1.0000 - val_loss: 2.5911 - val_accuracy: 0.9715
# Epoch 28/40
# 157/157 [==============================] - 670s 4s/step - loss: 2.4738 - accuracy: 1.0000 - val_loss: 2.4476 - val_accuracy: 0.9705
# Epoch 29/40
# 157/157 [==============================] - 674s 4s/step - loss: 2.3379 - accuracy: 1.0000 - val_loss: 2.3206 - val_accuracy: 0.9690
# Epoch 30/40
# 157/157 [==============================] - 681s 4s/step - loss: 2.2093 - accuracy: 1.0000 - val_loss: 2.2164 - val_accuracy: 0.9700
# Epoch 31/40
# 157/157 [==============================] - 685s 4s/step - loss: 2.0875 - accuracy: 1.0000 - val_loss: 2.0763 - val_accuracy: 0.9715
# Epoch 32/40
# 157/157 [==============================] - 684s 4s/step - loss: 1.9733 - accuracy: 1.0000 - val_loss: 1.9752 - val_accuracy: 0.9710
# Epoch 33/40
# 157/157 [==============================] - 681s 4s/step - loss: 1.8641 - accuracy: 1.0000 - val_loss: 1.8728 - val_accuracy: 0.9660
# Epoch 34/40
# 157/157 [==============================] - 694s 4s/step - loss: 1.7652 - accuracy: 0.9994 - val_loss: 1.8390 - val_accuracy: 0.9490
# Epoch 35/40
# 157/157 [==============================] - 697s 4s/step - loss: 1.6898 - accuracy: 0.9932 - val_loss: 1.6985 - val_accuracy: 0.9675
# Epoch 36/40
# 157/157 [==============================] - 677s 4s/step - loss: 1.6087 - accuracy: 0.9904 - val_loss: 1.8907 - val_accuracy: 0.8545
# Epoch 37/40
# 157/157 [==============================] - 689s 4s/step - loss: 1.5408 - accuracy: 0.9860 - val_loss: 1.5855 - val_accuracy: 0.9455
# Epoch 38/40
# 157/157 [==============================] - 689s 4s/step - loss: 1.4296 - accuracy: 0.9973 - val_loss: 1.4696 - val_accuracy: 0.9605
# Epoch 39/40
# 157/157 [==============================] - 678s 4s/step - loss: 1.3464 - accuracy: 0.9996 - val_loss: 1.4150 - val_accuracy: 0.9565
# Epoch 40/40
# 157/157 [==============================] - 685s 4s/step - loss: 1.3197 - accuracy: 0.9819 - val_loss: 1.3506 - val_accuracy: 0.9520
# 63/63 [==============================] - 31s 489ms/step - loss: 1.3124 - accuracy: 0.9655
# 0.965499997138977
# 964 36 33 967
# TPR/Recall: 0.967
# TNR/Specificity: 0.964
# PPV/Precision: 0.9641076769690927
# NPV: 0.966900702106319

# %%
def train_data_weight_batch2(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, regularization_lambda, epochs):
  # define model
  model = define_model_weight_regularization_batch_normalization2(learning_rate, regularization_lambda)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
  # fit model
  history = model.fit(X_train, y_train, epochs=epochs, batch_size=64, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_weight_batch_normalization, accuracy = train_data_weight_batch2(X_train, X_val, X_test, y_train, y_val, y_test, 0.0009, 0.001, 40)
print(accuracy)
y_pred = model_test_weight_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))
# Out:
# Epoch 1/40
# 157/157 [==============================] - 752s 5s/step - loss: 1.5632 - accuracy: 0.8315 - val_loss: 2.7754 - val_accuracy: 0.5000
# Epoch 2/40
# 157/157 [==============================] - 743s 5s/step - loss: 1.2624 - accuracy: 0.9637 - val_loss: 1.5865 - val_accuracy: 0.7715
# Epoch 3/40
# 157/157 [==============================] - 745s 5s/step - loss: 1.2219 - accuracy: 0.9749 - val_loss: 1.3477 - val_accuracy: 0.9145
# Epoch 4/40
# 157/157 [==============================] - 752s 5s/step - loss: 1.1948 - accuracy: 0.9831 - val_loss: 1.2531 - val_accuracy: 0.9605
# Epoch 5/40
# 157/157 [==============================] - 753s 5s/step - loss: 1.1734 - accuracy: 0.9884 - val_loss: 1.2125 - val_accuracy: 0.9645
# Epoch 6/40
# 157/157 [==============================] - 752s 5s/step - loss: 1.1552 - accuracy: 0.9922 - val_loss: 1.3399 - val_accuracy: 0.9210
# Epoch 7/40
# 157/157 [==============================] - 761s 5s/step - loss: 1.1416 - accuracy: 0.9944 - val_loss: 1.2042 - val_accuracy: 0.9650
# Epoch 8/40
# 157/157 [==============================] - 754s 5s/step - loss: 1.1292 - accuracy: 0.9970 - val_loss: 1.2025 - val_accuracy: 0.9635
# Epoch 9/40
# 157/157 [==============================] - 754s 5s/step - loss: 1.1194 - accuracy: 0.9979 - val_loss: 1.1998 - val_accuracy: 0.9605
# Epoch 10/40
# 157/157 [==============================] - 753s 5s/step - loss: 1.1099 - accuracy: 0.9983 - val_loss: 1.1936 - val_accuracy: 0.9640
# Epoch 11/40
# 157/157 [==============================] - 749s 5s/step - loss: 1.1043 - accuracy: 0.9980 - val_loss: 1.1931 - val_accuracy: 0.9675
# Epoch 12/40
# 157/157 [==============================] - 750s 5s/step - loss: 1.0949 - accuracy: 0.9984 - val_loss: 1.1614 - val_accuracy: 0.9730
# Epoch 13/40
# 157/157 [==============================] - 750s 5s/step - loss: 1.0859 - accuracy: 0.9992 - val_loss: 1.1681 - val_accuracy: 0.9685
# Epoch 14/40
# 157/157 [==============================] - 751s 5s/step - loss: 1.0806 - accuracy: 0.9987 - val_loss: 1.1642 - val_accuracy: 0.9700
# Epoch 15/40
# 157/157 [==============================] - 751s 5s/step - loss: 1.0710 - accuracy: 0.9996 - val_loss: 1.1546 - val_accuracy: 0.9665
# Epoch 16/40
# 157/157 [==============================] - 751s 5s/step - loss: 1.0696 - accuracy: 0.9984 - val_loss: 1.1470 - val_accuracy: 0.9735
# Epoch 17/40
# 157/157 [==============================] - 752s 5s/step - loss: 1.0582 - accuracy: 1.0000 - val_loss: 1.1453 - val_accuracy: 0.9730
# Epoch 18/40
# 157/157 [==============================] - 750s 5s/step - loss: 1.0603 - accuracy: 0.9974 - val_loss: 1.1283 - val_accuracy: 0.9725
# Epoch 19/40
# 157/157 [==============================] - 751s 5s/step - loss: 1.0457 - accuracy: 1.0000 - val_loss: 1.1151 - val_accuracy: 0.9725
# Epoch 20/40
# 157/157 [==============================] - 757s 5s/step - loss: 1.0407 - accuracy: 0.9998 - val_loss: 1.1118 - val_accuracy: 0.9680
# Epoch 21/40
# 157/157 [==============================] - 764s 5s/step - loss: 1.0377 - accuracy: 0.9989 - val_loss: 1.1159 - val_accuracy: 0.9705
# Epoch 22/40
# 157/157 [==============================] - 754s 5s/step - loss: 1.0274 - accuracy: 1.0000 - val_loss: 1.1041 - val_accuracy: 0.9735
# Epoch 23/40
# 157/157 [==============================] - 763s 5s/step - loss: 1.0216 - accuracy: 0.9999 - val_loss: 1.1027 - val_accuracy: 0.9730
# Epoch 24/40
# 157/157 [==============================] - 759s 5s/step - loss: 1.0151 - accuracy: 1.0000 - val_loss: 1.0920 - val_accuracy: 0.9715
# Epoch 25/40
# 157/157 [==============================] - 756s 5s/step - loss: 1.0114 - accuracy: 0.9997 - val_loss: 1.0807 - val_accuracy: 0.9735
# Epoch 26/40
# 157/157 [==============================] - 755s 5s/step - loss: 1.0033 - accuracy: 1.0000 - val_loss: 1.0722 - val_accuracy: 0.9725
# Epoch 27/40
# 157/157 [==============================] - 752s 5s/step - loss: 0.9977 - accuracy: 0.9999 - val_loss: 1.0736 - val_accuracy: 0.9705
# Epoch 28/40
# 157/157 [==============================] - 757s 5s/step - loss: 0.9922 - accuracy: 1.0000 - val_loss: 1.0753 - val_accuracy: 0.9740
# Epoch 29/40
# 157/157 [==============================] - 757s 5s/step - loss: 0.9873 - accuracy: 0.9999 - val_loss: 1.0603 - val_accuracy: 0.9740
# Epoch 30/40
# 157/157 [==============================] - 755s 5s/step - loss: 0.9799 - accuracy: 1.0000 - val_loss: 1.0549 - val_accuracy: 0.9760
# Epoch 31/40
# 157/157 [==============================] - 754s 5s/step - loss: 0.9745 - accuracy: 1.0000 - val_loss: 1.0481 - val_accuracy: 0.9750
# Epoch 32/40
# 157/157 [==============================] - 764s 5s/step - loss: 0.9698 - accuracy: 1.0000 - val_loss: 1.0418 - val_accuracy: 0.9745
# Epoch 33/40
# 157/157 [==============================] - 760s 5s/step - loss: 0.9636 - accuracy: 1.0000 - val_loss: 1.0365 - val_accuracy: 0.9750
# Epoch 34/40
# 157/157 [==============================] - 754s 5s/step - loss: 0.9582 - accuracy: 1.0000 - val_loss: 1.0302 - val_accuracy: 0.9740
# Epoch 35/40
# 157/157 [==============================] - 757s 5s/step - loss: 0.9531 - accuracy: 1.0000 - val_loss: 1.0226 - val_accuracy: 0.9755
# Epoch 36/40
# 157/157 [==============================] - 754s 5s/step - loss: 0.9476 - accuracy: 1.0000 - val_loss: 1.0204 - val_accuracy: 0.9735
# Epoch 37/40
# 157/157 [==============================] - 758s 5s/step - loss: 0.9416 - accuracy: 1.0000 - val_loss: 1.0199 - val_accuracy: 0.9720
# Epoch 38/40
# 157/157 [==============================] - 760s 5s/step - loss: 0.9368 - accuracy: 1.0000 - val_loss: 1.0146 - val_accuracy: 0.9740
# Epoch 39/40
# 157/157 [==============================] - 755s 5s/step - loss: 0.9395 - accuracy: 0.9973 - val_loss: 1.0158 - val_accuracy: 0.9710
# Epoch 40/40
# 157/157 [==============================] - 758s 5s/step - loss: 0.9261 - accuracy: 1.0000 - val_loss: 1.0053 - val_accuracy: 0.9740
# 63/63 [==============================] - 35s 562ms/step - loss: 0.9698 - accuracy: 0.9810
# 0.9810000061988831
# 991 9 29 971
# TPR/Recall: 0.971
# TNR/Specificity: 0.991
# PPV/Precision: 0.9908163265306122
# NPV: 0.9715686274509804

# %% [markdown]
# ### Train Data with Data Augmentation, Weight Regularization and Batch Normalization

# %%
def train_data_augmentation_weight_batch(X_train, X_val, X_test, y_train, y_val, y_test, learning_rate, epochs):
  # define model
  model = define_model_weight_regularization_batch_normalization(learning_rate)
  # create data generator
  datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
  # prepare iterator
  it_train = datagen.flow(X_train, y_train, batch_size=64)
  # define early stopping
  es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='auto', min_delta=0, patience=5, verbose=1)
	# fit model  
  steps = int(X_train.shape[0] / 64)
  history = model.fit(it_train, epochs=epochs, steps_per_epoch=steps, validation_data=(X_val, y_val), verbose=1, callbacks=[es])
  # plot model diagnostics
  summarize_diagnostics(history)
  # evaluate model
  _, accuracy = model.evaluate(X_test, y_test, verbose=1)
  return model, accuracy

# %%
model_test_data_weight_batch_normalization, accuracy = train_data_augmentation_weight_batch(X_train, X_val, X_test, y_train, y_val, y_test, 0.001, 30)
print(accuracy)
y_pred = model_test_data_weight_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_data_weight_batch_normalization, accuracy = train_data_augmentation_weight_batch(X_train, X_val, X_test, y_train, y_val, y_test, 0.01, 40)
print(accuracy)
y_pred = model_test_data_weight_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))

# %%
model_test_data_weight_batch_normalization, accuracy = train_data_augmentation_weight_batch(X_train, X_val, X_test, y_train, y_val, y_test, 0.003, 40)
print(accuracy)
y_pred = model_test_data_weight_batch_normalization.predict(X_test)
y_pred_val = y_pred.argmax(axis=1)
y_test_val = y_test.argmax(axis=1)
tn, fp, fn, tp = confusion_matrix(y_test_val, y_pred_val).ravel()
print("{} {} {} {}".format(tn, fp, fn, tp))
print("TPR/Recall: {}".format(tp/(tp+fn)))
print("TNR/Specificity: {}".format(tn/(tn+fp)))
print("PPV/Precision: {}".format(tp/(tp+fp)))
print("NPV: {}".format(tn/(tn+fn)))
